# %% [markdown]
# ### Prepare phenoype for subtype analysis : wm task

# %% [markdown]
# - Build a scrubbing file to be used on subtype analysis for wm task
# - Add mean run1 and run1 for FD an FD_scrubbed
# - Visualize correlation between run 1 and 2 for FD and FD scrubbed
# - merge clustered phenotype with scrubbing

# %%
# Import pandas
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display

# %%
# %matplotlib inline

# %%
# Set path
path_root = "~/Drive/HCP/"
path_scrub = os.path.join(path_root,"subtypes_scores/26-10-2016/pheno/qc_scrubbing_group.csv")
# Read scrubbing file
scrub_raw = pd.read_csv(path_scrub)
scrub_raw.head(20)
# Out:
#                              frames_scrubbed   frames_OK        FD   \
# 0     HCP100206_sess1_wmRL                0.0       405.0  0.083342
# 1     HCP100206_sess1_wmLR                0.0       405.0  0.082368
# 2   HCP100206_sess1_gambRL                0.0       253.0  0.081728
# 3   HCP100206_sess1_gambLR                0.0       253.0  0.098565
# 4    HCP100206_sess1_motRL                0.0       284.0  0.090883
# 5    HCP100206_sess1_motLR                0.0       284.0  0.090883
# 6   HCP100206_sess2_langRL                0.0       316.0  0.088456
# 7   HCP100206_sess2_langLR                0.0       316.0  0.099963
# 8    HCP100206_sess2_socRL                0.0       274.0  0.084949
# 9    HCP100206_sess2_socLR                0.0       274.0  0.096656
# 10   HCP100206_sess2_relRL               13.0       219.0  0.098646
# 11   HCP100206_sess2_relLR                0.0       232.0  0.118289
# 12    HCP100206_sess2_emRL                0.0       176.0  0.083053
# 13    HCP100206_sess2_emLR                0.0       176.0  0.088776
# 14    HCP100307_sess1_wmRL                0.0       405.0  0.095924
# 15    HCP100307_sess1_wmLR                0.0       405.0  0.093332
# 16  HCP100307_sess1_gambRL                0.0       253.0  0.102024
# 17  HCP100307_sess1_gambLR                0.0       253.0  0.086469
# 18   HCP100307_sess1_motRL                0.0       284.0  0.108998
# 19   HCP100307_sess1_motLR                0.0       284.0  0.108998
#
#     FD_scrubbed
# 0      0.083342
# 1      0.082368
# 2      0.081728
# 3      0.098565
# 4      0.090883
# 5      0.090883
# 6      0.088456
# 7      0.099963
# 8      0.084949
# 9      0.096656
# 10     0.091387
# 11     0.118289
# 12     0.083053
# 13     0.088776
# 14     0.095924
# 15     0.093332
# 16     0.102024
# 17     0.086469
# 18     0.108998
# 19     0.108998

# %%
# Select specific task
# run1
scrub_select_RL = scrub_raw[scrub_raw[' '].str.contains("wmRL")]
scrub_select_RL.rename(columns={'FD_scrubbed':'FD_scrubbed_RL','FD ':'FD_RL'},inplace=True)
scrub_select_RL.loc[:,'ID'] = scrub_select_RL[' '].str.replace('_sess1_wmRL ','')

# run2 
scrub_select_LR = scrub_raw[scrub_raw[' '].str.contains("wmLR")]
scrub_select_LR.rename(columns={'FD_scrubbed':'FD_scrubbed_LR','FD ':'FD_LR'},inplace=True)
scrub_select_LR.loc[:,'ID'] = scrub_select_LR[' '].str.replace('_sess1_wmLR ','')

display(scrub_select_RL.head())
display(scrub_select_LR.head())
# Out:
# /usr/local/lib/python3.4/dist-packages/pandas/core/frame.py:2834: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)
# /usr/local/lib/python3.4/dist-packages/pandas/core/indexing.py:297: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /usr/local/lib/python3.4/dist-packages/pandas/core/indexing.py:477: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#                            frames_scrubbed   frames_OK      FD_RL  \
# 0   HCP100206_sess1_wmRL                0.0       405.0  0.083342
# 14  HCP100307_sess1_wmRL                0.0       405.0  0.095924
# 28  HCP100408_sess1_wmRL               14.0       391.0  0.133898
# 42  HCP100610_sess1_wmRL                0.0       405.0  0.155579
# 56  HCP101006_sess1_wmRL                0.0       405.0  0.111923
#
#     FD_scrubbed_RL         ID
# 0         0.083342  HCP100206
# 14        0.095924  HCP100307
# 28        0.129641  HCP100408
# 42        0.155579  HCP100610
# 56        0.111923  HCP101006
#                            frames_scrubbed   frames_OK      FD_LR  \
# 1   HCP100206_sess1_wmLR                0.0       405.0  0.082368
# 15  HCP100307_sess1_wmLR                0.0       405.0  0.093332
# 29  HCP100408_sess1_wmLR               52.0       353.0  0.150610
# 43  HCP100610_sess1_wmLR                0.0       405.0  0.143473
# 57  HCP101006_sess1_wmLR                0.0       405.0  0.133317
#
#     FD_scrubbed_LR         ID
# 1         0.082368  HCP100206
# 15        0.093332  HCP100307
# 29        0.139477  HCP100408
# 43        0.143473  HCP100610
# 57        0.133317  HCP101006

# %%
# Select interest variables
scrub_select_LR_merge = scrub_select_LR [[' ','FD_LR','FD_scrubbed_LR','ID']]
scrub_select_RL_merge = scrub_select_RL [[' ','FD_RL','FD_scrubbed_RL','ID']]
display(scrub_select_RL_merge.head())
display(scrub_select_LR_merge.head())
# Out:
#                               FD_RL  FD_scrubbed_RL         ID
# 0   HCP100206_sess1_wmRL   0.083342        0.083342  HCP100206
# 14  HCP100307_sess1_wmRL   0.095924        0.095924  HCP100307
# 28  HCP100408_sess1_wmRL   0.133898        0.129641  HCP100408
# 42  HCP100610_sess1_wmRL   0.155579        0.155579  HCP100610
# 56  HCP101006_sess1_wmRL   0.111923        0.111923  HCP101006
#                               FD_LR  FD_scrubbed_LR         ID
# 1   HCP100206_sess1_wmLR   0.082368        0.082368  HCP100206
# 15  HCP100307_sess1_wmLR   0.093332        0.093332  HCP100307
# 29  HCP100408_sess1_wmLR   0.150610        0.139477  HCP100408
# 43  HCP100610_sess1_wmLR   0.143473        0.143473  HCP100610
# 57  HCP101006_sess1_wmLR   0.133317        0.133317  HCP101006

# %%
# Merge the raw table 
if np.shape(scrub_select_RL_merge)[0] >= np.shape(scrub_select_LR_merge)[0]:
    merged_scrub_RL_LR = pd.merge(scrub_select_RL_merge, scrub_select_LR_merge, on='ID', how='left')
else:
    merged_scrub_RL_LR = pd.merge(scrub_select_RL_merge, scrub_select_LR_merge, on='ID', how='right')

# %%
merged_scrub_RL_LR.head()
# Out:
#                       _x     FD_RL  FD_scrubbed_RL         ID  \
# 0  HCP100206_sess1_wmRL   0.083342        0.083342  HCP100206
# 1  HCP100307_sess1_wmRL   0.095924        0.095924  HCP100307
# 2  HCP100408_sess1_wmRL   0.133898        0.129641  HCP100408
# 3  HCP100610_sess1_wmRL   0.155579        0.155579  HCP100610
# 4  HCP101006_sess1_wmRL   0.111923        0.111923  HCP101006
#
#                       _y     FD_LR  FD_scrubbed_LR
# 0  HCP100206_sess1_wmLR   0.082368        0.082368
# 1  HCP100307_sess1_wmLR   0.093332        0.093332
# 2  HCP100408_sess1_wmLR   0.150610        0.139477
# 3  HCP100610_sess1_wmLR   0.143473        0.143473
# 4  HCP101006_sess1_wmLR   0.133317        0.133317

# %%
merged_scrub_RL_LR_subset = merged_scrub_RL_LR[['ID','FD_RL','FD_scrubbed_RL','FD_LR','FD_scrubbed_LR']]

# %%
merged_scrub_RL_LR_subset.head()
# Out:
#           ID     FD_RL  FD_scrubbed_RL     FD_LR  FD_scrubbed_LR
# 0  HCP100206  0.083342        0.083342  0.082368        0.082368
# 1  HCP100307  0.095924        0.095924  0.093332        0.093332
# 2  HCP100408  0.133898        0.129641  0.150610        0.139477
# 3  HCP100610  0.155579        0.155579  0.143473        0.143473
# 4  HCP101006  0.111923        0.111923  0.133317        0.133317

# %%
# calculate the mean FD and FD scrubbed
merged_scrub_RL_LR_subset.loc[:,'FD_scrubbed_mean'] = merged_scrub_RL_LR_subset[['FD_scrubbed_RL','FD_scrubbed_LR']].mean(axis=1)
merged_scrub_RL_LR_subset.loc[:,'FD_mean'] = merged_scrub_RL_LR_subset[['FD_RL','FD_LR']].mean(axis=1)

# replace empty cell by nan
merged_scrub_RL_LR_subset.replace('',np.nan,inplace=True)

# remove the ID header for niak_read_csv
merged_scrub_RL_LR_subset.rename(columns={'ID':''},inplace=True)

# Save the file
merged_scrub_RL_LR_subset.to_csv(os.path.join(path_root,"subtypes_scores/26-10-2016/pheno/qc_scrubbing_group_wm.csv"), index=False)
# Out:
# /usr/local/lib/python3.4/dist-packages/pandas/core/indexing.py:297: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /usr/local/lib/python3.4/dist-packages/pandas/core/indexing.py:477: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# Show final table
merged_scrub_RL_LR_subset.head()
# Out:
#                  FD_RL  FD_scrubbed_RL     FD_LR  FD_scrubbed_LR  \
# 0  HCP100206  0.083342        0.083342  0.082368        0.082368
# 1  HCP100307  0.095924        0.095924  0.093332        0.093332
# 2  HCP100408  0.133898        0.129641  0.150610        0.139477
# 3  HCP100610  0.155579        0.155579  0.143473        0.143473
# 4  HCP101006  0.111923        0.111923  0.133317        0.133317
#
#    FD_scrubbed_mean   FD_mean
# 0          0.082855  0.082855
# 1          0.094628  0.094628
# 2          0.134559  0.142254
# 3          0.149526  0.149526
# 4          0.122620  0.122620

# %%
merged_scrub_RL_LR_subset.describe()
# Out:
#             FD_RL  FD_scrubbed_RL       FD_LR  FD_scrubbed_LR  \
# count  854.000000      854.000000  857.000000      857.000000
# mean     0.135531        0.126799    0.139276        0.127823
# std      0.046041        0.034626    0.054867        0.035465
# min      0.059240        0.059240    0.063550        0.063550
# 25%      0.102381        0.100345    0.103857        0.101148
# 50%      0.125175        0.120791    0.126694        0.121458
# 75%      0.157457        0.145533    0.160875        0.148380
# max      0.500791        0.296663    0.716237        0.267712
#
#        FD_scrubbed_mean     FD_mean
# count        857.000000  857.000000
# mean           0.127263    0.137443
# std            0.034086    0.047702
# min            0.063517    0.063517
# 25%            0.100613    0.103506
# 50%            0.121756    0.126761
# 75%            0.147249    0.159714
# max            0.278963    0.471144

# %%
# find out if variables are correlated
corr= merged_scrub_RL_LR_subset.corr()

# %%
sns.set(style="white")
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, cmap=cmap,vmax=0.9,vmin=0.7,
            square=True,mask=mask,
            linewidths=.5, cbar_kws={"shrink": .8}, ax=ax)

# %%
# FD_scrubbed correlation between runs
sns.set(color_codes=True)
sns.jointplot(x="FD_scrubbed_RL", y="FD_scrubbed_LR", data=merged_scrub_RL_LR_subset,kind="reg");

# %%
# FD correlation between runs
sns.set(color_codes=True)
sns.jointplot(x="FD_RL", y="FD_LR", data=merged_scrub_RL_LR_subset,kind="reg");

# %% [markdown]
# ### merge clustered pheno with age gender and handedness

# %%
## merge clustered pheno with age gender and handedness
pheno_raw = pd.read_csv(os.path.join(path_root,'subtypes_scores/26-10-2016/pheno/hcp_all_pheno.csv'))
pheno_raw = pheno_raw.rename(columns=lambda x: x.strip())
pheno_clust = pd.read_csv(os.path.join(path_root,'subtypes_scores/26-10-2016/pheno/hcp_bootstraped_pheno_nonan_norm.csv'))
pheno_clust = pheno_clust.rename(columns=lambda x: x.strip())

# %%
merged_pheno = pd.merge(pheno_raw[['Subject','Age_in_Yrs','Gender','Handedness','Twin_Stat','Zygosity','Mother_ID','BMI']],
                        pheno_clust, on='Subject', how='right')
merged_pheno.loc[:,'Subject'] = 'HCP' + merged_pheno['Subject'].astype(str)
merged_pheno.head()
# Out:
#      Subject  Age_in_Yrs Gender  Handedness Twin_Stat Zygosity  Mother_ID  \
# 0  HCP100004          24      M          95   NotTwin  NotTwin      52259
# 1  HCP100206          27      M          65   NotTwin  NotTwin      56037
# 2  HCP100307          27      F          95      Twin    NotMZ      51488
# 3  HCP100408          33      M          55      Twin       MZ      51730
# 4  HCP100610          27      M          85      Twin    NotMZ      52813
#
#      BMI  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  \
# 0  25.49  -1.052260  -0.536775   1.187782  -0.657450  -0.098656  -0.279903
# 1  26.64  -1.143794   1.304835   1.285918  -0.034336   0.205086   0.053396
# 2  22.96  -0.528411   0.493464   0.523816  -0.600763   0.386336  -0.953060
# 3  27.75  -0.236296   0.020266   0.092588   0.114286  -0.084017  -0.522003
# 4  36.91   2.022214   0.895451  -0.361691   1.234488   0.709151  -0.882736
#
#    cluster_7  cluster_8  cluster_9
# 0   0.608886  -1.532028   0.209060
# 1   0.090798  -0.512524  -0.118881
# 2  -0.958070  -0.143309  -0.722473
# 3   0.619392   0.219196   1.037169
# 4  -0.323026  -0.199254   0.459399

# %%
# check if there is any nan value
merged_pheno.isnull().values.any()
# Out:
# True

# %%
# remove missing 
missing = np.array([merged_pheno[col].isnull().values for col in merged_pheno.columns.get_values()]).any(0)
merged_pheno_clean = merged_pheno[~missing]
merged_pheno_clean.count()
# Out:
# Subject       932
# Age_in_Yrs    932
# Gender        932
# Handedness    932
# Twin_Stat     932
# Zygosity      932
# Mother_ID     932
# BMI           932
# cluster_1     932
# cluster_2     932
# cluster_3     932
# cluster_4     932
# cluster_5     932
# cluster_6     932
# cluster_7     932
# cluster_8     932
# cluster_9     932
# dtype: int64

# %%
# set gender to numerical
merged_pheno_clean.loc[:,'Gender']= merged_pheno_clean.Gender.replace({'M':1,'F':2})
# Out:
# /usr/local/lib/python3.4/dist-packages/pandas/core/indexing.py:477: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
merged_pheno_clean.head()
# Out:
#      Subject  Age_in_Yrs  Gender  Handedness Twin_Stat Zygosity  Mother_ID  \
# 0  HCP100004          24       1          95   NotTwin  NotTwin      52259
# 1  HCP100206          27       1          65   NotTwin  NotTwin      56037
# 2  HCP100307          27       2          95      Twin    NotMZ      51488
# 3  HCP100408          33       1          55      Twin       MZ      51730
# 4  HCP100610          27       1          85      Twin    NotMZ      52813
#
#      BMI  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  \
# 0  25.49  -1.052260  -0.536775   1.187782  -0.657450  -0.098656  -0.279903
# 1  26.64  -1.143794   1.304835   1.285918  -0.034336   0.205086   0.053396
# 2  22.96  -0.528411   0.493464   0.523816  -0.600763   0.386336  -0.953060
# 3  27.75  -0.236296   0.020266   0.092588   0.114286  -0.084017  -0.522003
# 4  36.91   2.022214   0.895451  -0.361691   1.234488   0.709151  -0.882736
#
#    cluster_7  cluster_8  cluster_9
# 0   0.608886  -1.532028   0.209060
# 1   0.090798  -0.512524  -0.118881
# 2  -0.958070  -0.143309  -0.722473
# 3   0.619392   0.219196   1.037169
# 4  -0.323026  -0.199254   0.459399

# %%
#put HCP prefix then merge with scrubing
merged_pheno_scrub = pd.merge(merged_scrub_RL_LR_subset,merged_pheno_clean,how='left',left_on='',right_on='Subject')

# %%
merged_pheno_scrub.count()
# Out:
#                     857
# FD_RL               854
# FD_scrubbed_RL      854
# FD_LR               857
# FD_scrubbed_LR      857
# FD_scrubbed_mean    857
# FD_mean             857
# Subject             828
# Age_in_Yrs          828
# Gender              828
# Handedness          828
# Twin_Stat           828
# Zygosity            828
# Mother_ID           828
# BMI                 828
# cluster_1           828
# cluster_2           828
# cluster_3           828
# cluster_4           828
# cluster_5           828
# cluster_6           828
# cluster_7           828
# cluster_8           828
# cluster_9           828
# dtype: int64

# %%
# remove subject with missing data
missing_merged = np.array([merged_pheno_scrub[col].isnull().values for col in merged_pheno_scrub.columns.get_values()]).any(0)
merged_pheno_scrub_clean = merged_pheno_scrub[~missing_merged]

# %%
merged_pheno_scrub_clean.count()
# Out:
#                     825
# FD_RL               825
# FD_scrubbed_RL      825
# FD_LR               825
# FD_scrubbed_LR      825
# FD_scrubbed_mean    825
# FD_mean             825
# Subject             825
# Age_in_Yrs          825
# Gender              825
# Handedness          825
# Twin_Stat           825
# Zygosity            825
# Mother_ID           825
# BMI                 825
# cluster_1           825
# cluster_2           825
# cluster_3           825
# cluster_4           825
# cluster_5           825
# cluster_6           825
# cluster_7           825
# cluster_8           825
# cluster_9           825
# dtype: int64

# %%
merged_pheno_scrub_clean.head(10)
# Out:
#                  FD_RL  FD_scrubbed_RL     FD_LR  FD_scrubbed_LR  \
# 0  HCP100206  0.083342        0.083342  0.082368        0.082368
# 1  HCP100307  0.095924        0.095924  0.093332        0.093332
# 2  HCP100408  0.133898        0.129641  0.150610        0.139477
# 3  HCP100610  0.155579        0.155579  0.143473        0.143473
# 4  HCP101006  0.111923        0.111923  0.133317        0.133317
# 5  HCP101107  0.120820        0.068095  0.076125        0.076125
# 6  HCP101309  0.086692        0.086692  0.092831        0.089575
# 7  HCP101410  0.145737        0.145737  0.137565        0.137565
# 8  HCP101915  0.101955        0.101955  0.098969        0.098969
# 9  HCP102008  0.098808        0.098808  0.108268        0.108268
#
#    FD_scrubbed_mean   FD_mean    Subject  Age_in_Yrs  Gender    ...      \
# 0          0.082855  0.082855  HCP100206        27.0     1.0    ...
# 1          0.094628  0.094628  HCP100307        27.0     2.0    ...
# 2          0.134559  0.142254  HCP100408        33.0     1.0    ...
# 3          0.149526  0.149526  HCP100610        27.0     1.0    ...
# 4          0.122620  0.122620  HCP101006        35.0     2.0    ...
# 5          0.072110  0.098473  HCP101107        22.0     1.0    ...
# 6          0.088134  0.089761  HCP101309        29.0     1.0    ...
# 7          0.141651  0.141651  HCP101410        29.0     1.0    ...
# 8          0.100462  0.100462  HCP101915        35.0     2.0    ...
# 9          0.103538  0.103538  HCP102008        24.0     1.0    ...
#
#      BMI cluster_1 cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  \
# 0  26.64 -1.143794  1.304835   1.285918  -0.034336   0.205086   0.053396
# 1  22.96 -0.528411  0.493464   0.523816  -0.600763   0.386336  -0.953060
# 2  27.75 -0.236296  0.020266   0.092588   0.114286  -0.084017  -0.522003
# 3  36.91  2.022214  0.895451  -0.361691   1.234488   0.709151  -0.882736
# 4  30.27  0.591952 -1.191472   0.037988  -0.682910  -0.516141   0.056823
# 5  21.13 -0.236587 -0.055247   0.202737   0.108271  -0.816365   0.164527
# 6  22.20  2.460648 -0.639590  -1.056096  -0.458966  -0.579394  -0.306816
# 7  24.27 -0.737608 -0.286803  -0.213357   0.012024  -0.830777  -0.408648
# 8  20.42  1.461551 -1.096840  -0.838275   1.016038   0.083408  -0.056452
# 9  31.42 -0.891228  0.787911  -0.101854   0.511281   0.198667   0.152497
#
#    cluster_7  cluster_8  cluster_9
# 0   0.090798  -0.512524  -0.118881
# 1  -0.958070  -0.143309  -0.722473
# 2   0.619392   0.219196   1.037169
# 3  -0.323026  -0.199254   0.459399
# 4  -0.275139  -0.310782   0.308365
# 5   1.259271   0.350204   0.123138
# 6  -0.491635   0.396082  -0.336725
# 7   0.020646   0.388261   0.779067
# 8   0.159738   1.173397  -0.532920
# 9  -0.006320   0.653874   0.721998
#
# [10 rows x 24 columns]

# %%
##save to csv
# for solar
merged_pheno_scrub_clean.to_csv(os.path.join(path_root,"subtypes_scores/26-10-2016/pheno/hcp_pheno_wm_raw.csv"), index=False)
# for subtype
merged_pheno_scrub_clean.drop(['Subject','Twin_Stat', 'Zygosity'], axis=1).to_csv(os.path.join(path_root,"subtypes_scores/26-10-2016/pheno/hcp_pheno_wm.csv"), index=False)
