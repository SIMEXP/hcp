# %% [markdown]
# ### Build onset file for working memory task

# %% [markdown]
# - this script read raw onset file and format them to be fed on the spm pipeline

# %%
# Import
import os
import pandas as pd

# %%
# %matplotlib inline

# %%
# Set path
path_root = "/home/yassinebha/Drive/HCP/subtypes_scores/26-10-2016/"
path_eprime = os.path.join(path_root,"pheno/tmp_wm_eprime/LINKED_DATA/EPRIME/EVs/")
trial_files = os.listdir(path_eprime)
dump_tmp =[trial_files.remove(ii) for ii in ('WM_Stats.csv','Sync.txt','0bk_nlr.txt','2bk_nlr.txt','0bk_err.txt',
 '0bk_cor.txt','2bk_err.txt','2bk_cor.txt','all_bk_err.txt')]
list_tmp = [x[:-4] for x in trial_files]
list_tmp
# Out:
# ['all_bk_cor',
#  '2bk_faces',
#  '0bk_body',
#  '0bk_faces',
#  '2bk_places',
#  '0bk_places',
#  '2bk_body',
#  '0bk_tools',
#  '2bk_tools']

# %%
#Loop over trials and buid onset file
eprime_final = pd.DataFrame()
for trial_f in trial_files :
    trial = trial_f[:-4] 
    eprime = pd.read_csv(os.path.join(path_eprime,trial_f), sep='\t',header=None)

    # Add onset_trial name
    onset_list = [trial.format(row) for ind, row in eprime.iterrows()]
    eprime.loc[:,''] = onset_list

    # re-arrange colomns
    cols = eprime.columns.tolist()
    cols = cols[-1:] + cols[:-1]
    eprime = eprime[cols]

    # append to other trial
    eprime_final = eprime_final.append(eprime)
    eprime_final

# Put header
eprime_final.rename(columns={0:'start',1:'duration',2:'repetition'},inplace=True)

# Save final onset file 
eprime_final.to_csv(os.path.join(path_root,'pheno/tmp_wm_eprime/LINKED_DATA/EPRIME/wm_onset.csv'),index=False)

# %%
eprime_final
# Out:
#                   start  duration  repetition
# 0   all_bk_cor   10.569       2.5           1
# 1   all_bk_cor   13.128       2.5           1
# 2   all_bk_cor   15.687       2.5           1
# 3   all_bk_cor   20.831       2.5           1
# 4   all_bk_cor   23.390       2.5           1
# 5   all_bk_cor   25.949       2.5           1
# 6   all_bk_cor   28.508       2.5           1
# 7   all_bk_cor   31.067       2.5           1
# 8   all_bk_cor   38.677       2.5           1
# 9   all_bk_cor   41.236       2.5           1
# 10  all_bk_cor   43.795       2.5           1
# 11  all_bk_cor   46.354       2.5           1
# 12  all_bk_cor   51.472       2.5           1
# 13  all_bk_cor   54.044       2.5           1
# 14  all_bk_cor   56.616       2.5           1
# 15  all_bk_cor   59.175       2.5           1
# 16  all_bk_cor   61.734       2.5           1
# 17  all_bk_cor   81.806       2.5           1
# 18  all_bk_cor   84.378       2.5           1
# 19  all_bk_cor   86.950       2.5           1
# 20  all_bk_cor   89.522       2.5           1
# 21  all_bk_cor   92.095       2.5           1
# 22  all_bk_cor   94.667       2.5           1
# 23  all_bk_cor   97.239       2.5           1
# 24  all_bk_cor   99.812       2.5           1
# 25  all_bk_cor  102.384       2.5           1
# 26  all_bk_cor  104.956       2.5           1
# 27  all_bk_cor  110.007       2.5           1
# 28  all_bk_cor  112.566       2.5           1
# 29  all_bk_cor  115.125       2.5           1
# ..         ...      ...       ...         ...
# 54  all_bk_cor  199.210       2.5           1
# 55  all_bk_cor  201.782       2.5           1
# 56  all_bk_cor  204.354       2.5           1
# 57  all_bk_cor  224.426       2.5           1
# 58  all_bk_cor  226.998       2.5           1
# 59  all_bk_cor  229.571       2.5           1
# 60  all_bk_cor  232.143       2.5           1
# 61  all_bk_cor  234.715       2.5           1
# 62  all_bk_cor  237.287       2.5           1
# 63  all_bk_cor  239.860       2.5           1
# 64  all_bk_cor  242.432       2.5           1
# 65  all_bk_cor  245.004       2.5           1
# 66  all_bk_cor  247.576       2.5           1
# 67  all_bk_cor  252.641       2.5           1
# 68  all_bk_cor  255.213       2.5           1
# 69  all_bk_cor  257.786       2.5           1
# 70  all_bk_cor  260.358       2.5           1
# 71  all_bk_cor  265.502       2.5           1
# 72  all_bk_cor  268.075       2.5           1
# 73  all_bk_cor  270.647       2.5           1
# 74  all_bk_cor  273.219       2.5           1
# 75  all_bk_cor  275.791       2.5           1
# 0    2bk_faces   79.247      27.5           1
# 0     0bk_body   36.145      27.5           1
# 0    0bk_faces  221.880      27.5           1
# 0   2bk_places  178.645      27.5           1
# 0   0bk_places  250.095      27.5           1
# 0     2bk_body  150.550      27.5           1
# 0    0bk_tools  107.475      27.5           1
# 0    2bk_tools    7.997      27.5           1
#
# [84 rows x 4 columns]
