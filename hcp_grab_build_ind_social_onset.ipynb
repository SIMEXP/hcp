# %%
# Build individual onset file for spm analysis and save it in fmri preprocess folder
# Import
import os
import pandas as pd

# Set path
path_root = "/gs/project/gsf-624-aa/HCP/HCP_raw_data_900R"
path_out = "/gs/project/gsf-624-aa/HCP/fmri_preprocess_all_tasks_niak-fix-scrub_900R"

# Loop over subject and runs and create individual onset
list_subj = os.listdir(path_root)
# loop over runs
for run in 'LR','RL':
    for index, subj in enumerate(list_subj):
        path_eprime = os.path.join(path_root,subj,"unprocessed/3T/tfMRI_SOCIAL_{}/LINKED_DATA/EPRIME/EVs".format(run))
        if not os.path.exists(path_eprime):
            print('Subject %s has no Eprime folder for SOCIAL_%s task' % (subj, run))
            continue
        
        # get trial files
        trial_files = os.listdir(path_eprime)
        dump_tmp = [trial_files.remove(ii) for ii in ('SOCIAL_Stats.csv','Sync.txt','other_resp.txt','mental_resp.txt')]
        
        # Create subject EVs folder
        eprime_out = os.path.join(path_out,'EVs','HCP{}'.format(subj),'SOCIAL_{}'.format(run))
        if not os.path.exists(eprime_out):
            os.makedirs(eprime_out)
        
        #Loop over trials and buid onset file
        eprime_final = pd.DataFrame()
        for trial_f in trial_files :
            trial = trial_f[:-4] 
            eprime = pd.read_csv(os.path.join(path_eprime,trial_f), sep='\t',header=None)
            
            # Add onset_trial name
            onset_list = [trial.format(row) for ind, row in eprime.iterrows()]
            eprime.loc[:,''] = onset_list
            
            # re-arrange colomns
            cols = eprime.columns.tolist()
            cols = cols[-1:] + cols[:-1]
            eprime = eprime[cols]
            
            # append to other trial
            eprime_final = eprime_final.append(eprime)
        
        # Put header
        eprime_final.rename(columns={0:'start',1:'duration',2:'repetition'},inplace=True)
        
        # Save final onset file
        eprime_final.to_csv(os.path.join(eprime_out,"SOCIAL_{}_spm_onset.csv".format(run)),index=False)

# %%
Subject 192439 has miss rated mental interaction for SOCIAL_RL task
Subject 579665 has miss rated mental interaction for SOCIAL_RL task
Subject 792766 has miss rated mental interaction for SOCIAL_RL task
Subject 101006 has miss rated mental interaction for SOCIAL_RL task
Subject 108525 has miss rated mental interaction for SOCIAL_RL task
Subject 116524 has miss rated mental interaction for SOCIAL_RL task
Subject 125525 has miss rated mental interaction for SOCIAL_RL task
Subject 133827 has miss rated mental interaction for SOCIAL_RL task
Subject 192439 has miss rated mental interaction for SOCIAL_RL task
Subject 579665 has miss rated mental interaction for SOCIAL_RL task
Subject 792766 has miss rated mental interaction for SOCIAL_RL task
Subject 101006 has miss rated mental interaction for SOCIAL_RL task
Subject 108525 has miss rated mental interaction for SOCIAL_RL task
Subject 116524 has miss rated mental interaction for SOCIAL_RL task
Subject 125525 has miss rated mental interaction for SOCIAL_RL task
Subject 133827 has miss rated mental interaction for SOCIAL_RL task

# %%
# log for path_root = "/gs/project/gsf-624-aa/HCP/HCP_raw_data_900R"
Subject 613235 has no Eprime folder for SOCIAL_LR task
Subject 168038 has no Eprime folder for SOCIAL_LR task
Subject 734247 has no Eprime folder for SOCIAL_LR task
Subject 953764 has no Eprime folder for SOCIAL_LR task
Subject 110613 has no Eprime folder for SOCIAL_LR task
Subject 177342 has no Eprime folder for SOCIAL_LR task
Subject 121820 has no Eprime folder for SOCIAL_LR task
Subject 201717 has no Eprime folder for SOCIAL_LR task
Subject 584355 has no Eprime folder for SOCIAL_LR task
Subject 221218 has no Eprime folder for SOCIAL_LR task
Subject 159845 has no Eprime folder for SOCIAL_LR task
Subject 179952 has no Eprime folder for SOCIAL_LR task
Subject 810439 has no Eprime folder for SOCIAL_LR task
Subject 706040 has no Eprime folder for SOCIAL_LR task
Subject 766563 has no Eprime folder for SOCIAL_LR task
Subject 190132 has no Eprime folder for SOCIAL_LR task
Subject 193441 has no Eprime folder for SOCIAL_LR task
Subject 693461 has no Eprime folder for SOCIAL_LR task
Subject 613235 has no Eprime folder for SOCIAL_RL task
Subject 168038 has no Eprime folder for SOCIAL_RL task
Subject 734247 has no Eprime folder for SOCIAL_RL task
Subject 953764 has no Eprime folder for SOCIAL_RL task
Subject 110613 has no Eprime folder for SOCIAL_RL task
Subject 177342 has no Eprime folder for SOCIAL_RL task
Subject 121820 has no Eprime folder for SOCIAL_RL task
Subject 201717 has no Eprime folder for SOCIAL_RL task
Subject 584355 has no Eprime folder for SOCIAL_RL task
Subject 221218 has no Eprime folder for SOCIAL_RL task
Subject 159845 has no Eprime folder for SOCIAL_RL task
Subject 179952 has no Eprime folder for SOCIAL_RL task
Subject 810439 has no Eprime folder for SOCIAL_RL task
Subject 706040 has no Eprime folder for SOCIAL_RL task
Subject 766563 has no Eprime folder for SOCIAL_RL task
Subject 190132 has no Eprime folder for SOCIAL_RL task
Subject 193441 has no Eprime folder for SOCIAL_RL task
Subject 693461 has no Eprime folder for SOCIAL_RL task

# %%
# log for path_root = "/gs/project/gsf-624-aa/HCP/HCP_raw_data"
Subject 142424 has no Eprime folder for SOCIAL_LR task
Subject 143527 has no Eprime folder for SOCIAL_LR task
Subject 145531 has no Eprime folder for SOCIAL_LR task
Subject 165234 has no Eprime folder for SOCIAL_LR task
Subject 169141 has no Eprime folder for SOCIAL_LR task
Subject 171431 has no Eprime folder for SOCIAL_LR task
Subject 173132 has no Eprime folder for SOCIAL_LR task
Subject 197449 has no Eprime folder for SOCIAL_LR task
Subject 207628 has no Eprime folder for SOCIAL_LR task
Subject 355542 has no Eprime folder for SOCIAL_LR task
Subject 521331 has no Eprime folder for SOCIAL_LR task
Subject 611231 has no Eprime folder for SOCIAL_LR task
Subject 650746 has no Eprime folder for SOCIAL_LR task
Subject 745555 has no Eprime folder for SOCIAL_LR task
Subject 782157 has no Eprime folder for SOCIAL_LR task
Subject 112819 has no Eprime folder for SOCIAL_LR task
Subject 113821 has no Eprime folder for SOCIAL_LR task
Subject 116120 has no Eprime folder for SOCIAL_LR task
Subject 121315 has no Eprime folder for SOCIAL_LR task
Subject 126931 has no Eprime folder for SOCIAL_LR task
Subject 128329 has no Eprime folder for SOCIAL_LR task
Subject 129432 has no Eprime folder for SOCIAL_LR task
Subject 129533 has no Eprime folder for SOCIAL_LR task
Subject 131621 has no Eprime folder for SOCIAL_LR task
Subject 132118 has no Eprime folder for SOCIAL_LR task
Subject 142424 has no Eprime folder for SOCIAL_RL task
Subject 143527 has no Eprime folder for SOCIAL_RL task
Subject 145531 has no Eprime folder for SOCIAL_RL task
Subject 165234 has no Eprime folder for SOCIAL_RL task
Subject 169141 has no Eprime folder for SOCIAL_RL task
Subject 171431 has no Eprime folder for SOCIAL_RL task
Subject 173132 has no Eprime folder for SOCIAL_RL task
Subject 197449 has no Eprime folder for SOCIAL_RL task
Subject 207628 has no Eprime folder for SOCIAL_RL task
Subject 355542 has no Eprime folder for SOCIAL_RL task
Subject 521331 has no Eprime folder for SOCIAL_RL task
Subject 611231 has no Eprime folder for SOCIAL_RL task
Subject 650746 has no Eprime folder for SOCIAL_RL task
Subject 745555 has no Eprime folder for SOCIAL_RL task
Subject 782157 has no Eprime folder for SOCIAL_RL task
Subject 112819 has no Eprime folder for SOCIAL_RL task
Subject 113821 has no Eprime folder for SOCIAL_RL task
Subject 116120 has no Eprime folder for SOCIAL_RL task
Subject 121315 has no Eprime folder for SOCIAL_RL task
Subject 126931 has no Eprime folder for SOCIAL_RL task
Subject 128329 has no Eprime folder for SOCIAL_RL task
Subject 129432 has no Eprime folder for SOCIAL_RL task
Subject 129533 has no Eprime folder for SOCIAL_RL task
Subject 131621 has no Eprime folder for SOCIAL_RL task
Subject 132118 has no Eprime folder for SOCIAL_RL task
