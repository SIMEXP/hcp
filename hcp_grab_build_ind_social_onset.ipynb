# %%
# Build individual onset file for spm analysis and save it in fmri preprocess folder
# Import
import os
import pandas as pd

# Set path
path_root = "/gs/project/gsf-624-aa/HCP/HCP_raw_data_900R"
path_out = "/gs/project/gsf-624-aa/HCP/fmri_preprocess_all_tasks_niak-fix-scrub_900R"

# Loop over subject and runs and create individual onset
list_subj = os.listdir(path_root)
# loop over runs
for run in 'LR','RL':
    for index, subj in enumerate(list_subj):
        path_eprime = os.path.join(path_root,subj,"unprocessed/3T/tfMRI_SOCIAL_{}/LINKED_DATA/EPRIME/EVs".format(run))
        if not os.path.exists(path_eprime):
            print('Subject %s has no Eprime folder for SOCIAL_%s task' % (subj, run))
            continue
        
        # Create subject EVs folder
        eprime_out = os.path.join(path_out,'EVs','HCP{}'.format(subj),'SOCIAL_{}'.format(run))
        if not os.path.exists(eprime_out):
            os.makedirs(eprime_out)
        
        # Read mental eprime files
        eprime_mental = pd.read_csv(os.path.join(path_eprime,"mental.txt"), sep='\t',header=None)
        eprime_mental_resp = pd.read_csv(os.path.join(path_eprime,"mental_resp.txt"), sep='\t',header=None)
        
        # Add onset_trial name
        onset_list = ["mental".format(row) for ind, row in eprime_mental.iterrows()]
        eprime_mental.loc[:,'']=onset_list
        onset_list_resp = ["mental_resp".format(row) for ind, row in eprime_mental_resp.iterrows()]
        eprime_mental_resp.loc[:,'']=onset_list_resp
        
        # re-arrange colomns
        
        cols = eprime_mental.columns.tolist()
        cols = cols[-1:] + cols[:-1]
        eprime_mental = eprime_mental[cols]
        cols = eprime_mental_resp.columns.tolist()
        cols = cols[-1:] + cols[:-1]
        eprime_mental_resp = eprime_mental_resp[cols]
        
        # Read random eprime files
        eprime_rnd = pd.read_csv(os.path.join(path_eprime,"rnd.txt"), sep='\t',header=None)
        eprime_rnd_resp = pd.read_csv(os.path.join(path_eprime,"other_resp.txt"), sep='\t',header=None)
        
        # Add onset_trial name
        onset_list = ["rnd".format(row) for ind, row in eprime_rnd.iterrows()]
        eprime_rnd.loc[:,'']=onset_list
        
        onset_list = ["rnd_resp".format(row) for ind, row in eprime_rnd.iterrows()]
        eprime_rnd_resp.loc[:,'']=onset_list
        
        # re-arrange colomns
        cols = eprime_rnd.columns.tolist()
        cols = cols[-1:] + cols[:-1]
        eprime_rnd = eprime_rnd[cols]
        
        cols = eprime_rnd_resp.columns.tolist()
        cols = cols[-1:] + cols[:-1]
        eprime_rnd_resp = eprime_rnd_resp[cols]
        
        # append mental to metal_resp
        eprime_mental_final = eprime_mental.append(eprime_mental_resp)
        # append random to rnd_resp
        eprime_random_final = eprime_rnd.append(eprime_rnd_resp)
        # append mental to random
        eprime_final = eprime_mental_final.append(eprime_random_final)
        
        # Put header
        eprime_final.rename(columns={0:'start',1:'duration',2:'repetition'},inplace=True)
        
        # Save file 
        eprime_final.to_csv(os.path.join(eprime_out,"SOCIAL_{}_spm_onset.csv".format(run)),index=False)

# %%
# log for path_root = "/gs/project/gsf-624-aa/HCP/HCP_raw_data_900R"
Subject 613235 has no Eprime folder for EMOTION_LR task
Subject 168038 has no Eprime folder for EMOTION_LR task
Subject 734247 has no Eprime folder for EMOTION_LR task
Subject 953764 has no Eprime folder for EMOTION_LR task
Subject 110613 has no Eprime folder for EMOTION_LR task
Subject 177342 has no Eprime folder for EMOTION_LR task
Subject 121820 has no Eprime folder for EMOTION_LR task
Subject 201717 has no Eprime folder for EMOTION_LR task
Subject 584355 has no Eprime folder for EMOTION_LR task
Subject 221218 has no Eprime folder for EMOTION_LR task
Subject 159845 has no Eprime folder for EMOTION_LR task
Subject 179952 has no Eprime folder for EMOTION_LR task
Subject 810439 has no Eprime folder for EMOTION_LR task
Subject 706040 has no Eprime folder for EMOTION_LR task
Subject 766563 has no Eprime folder for EMOTION_LR task
Subject 190132 has no Eprime folder for EMOTION_LR task
Subject 193441 has no Eprime folder for EMOTION_LR task
Subject 693461 has no Eprime folder for EMOTION_LR task
Subject 613235 has no Eprime folder for EMOTION_RL task
Subject 168038 has no Eprime folder for EMOTION_RL task
Subject 734247 has no Eprime folder for EMOTION_RL task
Subject 953764 has no Eprime folder for EMOTION_RL task
Subject 110613 has no Eprime folder for EMOTION_RL task
Subject 177342 has no Eprime folder for EMOTION_RL task
Subject 121820 has no Eprime folder for EMOTION_RL task
Subject 201717 has no Eprime folder for EMOTION_RL task
Subject 584355 has no Eprime folder for EMOTION_RL task
Subject 221218 has no Eprime folder for EMOTION_RL task
Subject 159845 has no Eprime folder for EMOTION_RL task
Subject 179952 has no Eprime folder for EMOTION_RL task
Subject 810439 has no Eprime folder for EMOTION_RL task
Subject 706040 has no Eprime folder for EMOTION_RL task
Subject 766563 has no Eprime folder for EMOTION_RL task
Subject 190132 has no Eprime folder for EMOTION_RL task
Subject 193441 has no Eprime folder for EMOTION_RL task
Subject 693461 has no Eprime folder for EMOTION_RL task

# %%
# log for path_root = "/gs/project/gsf-624-aa/HCP/HCP_raw_data"
Subject 142424 has no Eprime folder for EMOTION_LR task
Subject 143527 has no Eprime folder for EMOTION_LR task
Subject 144226 has no Eprime folder for EMOTION_LR task
Subject 145531 has no Eprime folder for EMOTION_LR task
Subject 165234 has no Eprime folder for EMOTION_LR task
Subject 169141 has no Eprime folder for EMOTION_LR task
Subject 171431 has no Eprime folder for EMOTION_LR task
Subject 173132 has no Eprime folder for EMOTION_LR task
Subject 177746 has no Eprime folder for EMOTION_LR task
Subject 182840 has no Eprime folder for EMOTION_LR task
Subject 197449 has no Eprime folder for EMOTION_LR task
Subject 207628 has no Eprime folder for EMOTION_LR task
Subject 355542 has no Eprime folder for EMOTION_LR task
Subject 521331 has no Eprime folder for EMOTION_LR task
Subject 611231 has no Eprime folder for EMOTION_LR task
Subject 650746 has no Eprime folder for EMOTION_LR task
Subject 745555 has no Eprime folder for EMOTION_LR task
Subject 782157 has no Eprime folder for EMOTION_LR task
Subject 112819 has no Eprime folder for EMOTION_LR task
Subject 113821 has no Eprime folder for EMOTION_LR task
Subject 116120 has no Eprime folder for EMOTION_LR task
Subject 121315 has no Eprime folder for EMOTION_LR task
Subject 126931 has no Eprime folder for EMOTION_LR task
Subject 128329 has no Eprime folder for EMOTION_LR task
Subject 129432 has no Eprime folder for EMOTION_LR task
Subject 129533 has no Eprime folder for EMOTION_LR task
Subject 131621 has no Eprime folder for EMOTION_LR task
Subject 132118 has no Eprime folder for EMOTION_LR task
Subject 142424 has no Eprime folder for EMOTION_RL task
Subject 143527 has no Eprime folder for EMOTION_RL task
Subject 144226 has no Eprime folder for EMOTION_RL task
Subject 145531 has no Eprime folder for EMOTION_RL task
Subject 165234 has no Eprime folder for EMOTION_RL task
Subject 169141 has no Eprime folder for EMOTION_RL task
Subject 171431 has no Eprime folder for EMOTION_RL task
Subject 173132 has no Eprime folder for EMOTION_RL task
Subject 197449 has no Eprime folder for EMOTION_RL task
Subject 207628 has no Eprime folder for EMOTION_RL task
Subject 355542 has no Eprime folder for EMOTION_RL task
Subject 611231 has no Eprime folder for EMOTION_RL task
Subject 650746 has no Eprime folder for EMOTION_RL task
Subject 745555 has no Eprime folder for EMOTION_RL task
Subject 782157 has no Eprime folder for EMOTION_RL task
Subject 112819 has no Eprime folder for EMOTION_RL task
Subject 113821 has no Eprime folder for EMOTION_RL task
Subject 116120 has no Eprime folder for EMOTION_RL task
Subject 121315 has no Eprime folder for EMOTION_RL task
Subject 126931 has no Eprime folder for EMOTION_RL task
Subject 128329 has no Eprime folder for EMOTION_RL task
Subject 129432 has no Eprime folder for EMOTION_RL task
Subject 129533 has no Eprime folder for EMOTION_RL task
Subject 131621 has no Eprime folder for EMOTION_RL task
Subject 132118 has no Eprime folder for EMOTION_RL task
