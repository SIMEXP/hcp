# %% [markdown]
# # Pleiothropy all tasks

# %% [markdown]
# #### Data Preprocessing:
# - merge all pedgree ID's
# - build a unique Pedigree
# - merge all pheno files according the unique pedgree
#
# #### Pleiothropy estimate:
# - loop over pheno and estimate pleiothropy between each pair of pheno
# - collect results in a dictionary of matrix:
#     - pleio Matrix rhoG
#     - P-value Matrix of rhoG different from 0
#     - P-value Matrix of rhoG d
#     ifferent from 1
#     - pleio Matrix RhoE
#     - P-value Matrix of RhoE different from 0
#     - P-value Matrix of RhoE different from 1
#
# #### Clutering Rho Matrices :
# - cluster pleio Matrix rhoG
# - plot clustered pleio Matrix rhoG
# - plot clustered P-value Matrix of rhoG different from 0
# - plot clustered P-value Matrix of rhoG different from 1
# - cluster pleio Matrix RhoE
# - plot clustered pleio Matrix RhoE
# - plot clustered P-value Matrix of RhoE different from 0
# - plot clustered P-value Matrix of RhoE different from 1

# %%
# Imports
import os
import pandas as pd
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
import time
import seaborn as sns
import functools
import subprocess as subp
from nilearn import plotting as nlp
from scipy import cluster as scl
from scipy import io as sio
import matplotlib as mpl
from matplotlib import pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from matplotlib import gridspec as gs
import itertools

# %%
def make_boxes(mat, cl_def, pad=1, edge=False):
    """
    mat:    the matrix you want to do stuff to
    cl_def: a list of tuples where the first position is the 
            index of the first element in the cluster. the 
            second position is the index of the last element 
            in the cluster
    pad:    an integer value for the number of zero spaces to add
            around clusters
    edge:   boolean argument. If True, clusters at the corners will
            be drawn full. If False, clusters will be only drawn on
            the inside edge (no white line around the matrix).
            
    returns:
    omat:   the input matrix with the spaces added
    cmat_m: the overlayed cluster boxes in a masked array
    lmat_m: a mask of the added empty spaces
    ind:    the new index positions for the data (for x_ticks...)
    """
    # Extract the values
    starts = [i[0] for i in cl_def if not i[0]==0]
    if edge:
        starts = [i[0] for i in cl_def]
        stops = [i[1]+1 for i in cl_def]
    else:
        starts = [i[0] for i in cl_def if not i[0]==0]
        stops = [i[1]+1 for i in cl_def if not i[1]+1>=mat.shape[0]]
    # Find the breakpoints
    bkp = list(np.unique(starts + stops))
    n_bkp = len(bkp)
    # Convert to new indices
    run = 0
    ind = list()
    for i in np.arange(mat.shape[0]):
        if i in bkp:
            run += pad
        ind.append(i+run)

    # Make indices
    x = [i[0] for i in itertools.product(ind, ind)]
    y = [i[1] for i in itertools.product(ind, ind)]

    # Make new matrix
    omat = np.zeros([i+n_bkp*pad for i in mat.shape])
    omat[x, y] = mat.flatten()

    # Make a matrix for the clusters
    cmat = np.zeros_like(omat)
    # Make a matrix for the empty lines
    lmat = np.zeros_like(omat, dtype=bool)
    lmat[x,y] = True
    lmat_m = np.ma.masked_where(lmat, lmat)
    # Convert the input based breakpoints
    starts_c = [ind[i[0]]-pad for i in cl_def]
    stops_c = [ind[i[1]]+1 for i in cl_def]
    for i in np.arange(len(starts_c)):
        start = starts_c[i]
        stop = stops_c[i]
        if pad==1:
            start_ind = np.arange(start, start+pad)
            stop_ind = np.arange(stop, stop+pad)
        else:
            start_ind = np.arange(start, start+pad)
            stop_ind = np.arange(stop, stop+pad)
            
        if not start<=0 or edge:
            # Draw the top left corner first
            cmat[start_ind, start:stop] = i+1
            cmat[start:stop, start_ind] = i+1
        else:
            # Draw the bottom right corner next
            cmat[stop_ind, :stop+pad] = i+1
            cmat[:stop+pad, stop_ind] = i+1
            continue
        if not stop>=omat.shape[0] or edge:
            # Draw the bottom right corner next
            cmat[stop_ind, start:stop+pad] = i+1
            cmat[start:stop+pad, stop_ind] = i+1
    cmat_m = np.ma.masked_where(cmat==0, cmat)
    return omat, cmat_m, lmat_m, ind

# %%
# %matplotlib inline

# %%
# Set path 
path_root = '/media/yassine/data_disk/Drive/HCP2/Solar_heritability/HCP_subtype/'
pedig_file_ptrn = 'solar_{}_spm_pedigre.csv'
pheno_file_ptrn = 'solar_{}_spm_{}_pheno.csv'

# %%
# Set task and trials
task_names = ['emotion','social','relational','motor','gambling','wm','language']
nb_sbt= 5

# %% [markdown]
# ### Data preprocessing

# %% [markdown]
# #### Merge all pheno files and create cov variable stack

# %%
# create FD covariate for each task
cov_stack_FD = [pd.read_csv(os.path.join(path_root,pheno_file_ptrn.format(x.upper(),nb_sbt))).filter(regex = r'(ID|FD)') for x in task_names ]
cov_stack_FD_df  = functools.reduce(lambda left,right: pd.merge(left,right,on='ID',how='inner'), cov_stack_FD)

# creat standard covariate that aplly to all tasks
cov_stack_stand = [pd.read_csv(os.path.join(path_root,pheno_file_ptrn.format(x.upper(),nb_sbt)))[['ID','Age_in_Yrs',
                                                                                            'Gender',
                                                                                            'BMI']] for x in task_names ]
cov_stack_stand_df = pd.merge(cov_stack_FD_df[['ID']],cov_stack_stand[0],how='left',on='ID')

# create pheno stack
pheno_stack = [pd.read_csv(os.path.join(path_root,pheno_file_ptrn.format(x.upper(),nb_sbt))).filter(regex ='^(?!.*FD)').drop(['Age_in_Yrs',
                                                                                                                              'Gender',
                                                                                                                              'BMI'],axis =1) for x in task_names]
pheno_stack_df  = functools.reduce(lambda left,right: pd.merge(left,right,on='ID',how='inner'), pheno_stack)

# Merge all pheno cov in one file
dfs  = [cov_stack_stand_df,cov_stack_FD_df,pheno_stack_df]
all_pheno_cov = functools.reduce(lambda left,right: pd.merge(left,right,on='ID',how='inner'), dfs)
# save to file
all_pheno_cov.to_csv(os.path.join(path_root,'pleio_all_pheno.csv'),index=False)
## regular expression tutorial https://stackoverflow.com/questions/1687620/regex-match-everything-but

# %% [markdown]
# #### Merge all Pedigree based on Pheno file

# %%
# create pedgree stack
pedigs_stack = [pd.read_csv(os.path.join(path_root,pedig_file_ptrn.format(x.upper()))) for x in task_names ]
pedigs_stack_df = functools.reduce(lambda left,right: pd.merge(left,right,on='ID',how='inner'), pedigs_stack)

# Build a unique pedigree based on Pheno file
IDs= cov_stack_stand_df[['ID']]
df_pedig = IDs.merge(pedigs_stack[0],on='ID',how='left')
df_pedig.count()
# Out:
# ID        726
# fa        726
# mo        726
# sex       726
# mztwin    174
# hhID      726
# dtype: int64

# %%
pedigs_stack[5].count()
# Out:
# ID        859
# fa        859
# mo        859
# sex       859
# mztwin    238
# hhID      859
# dtype: int64

# %%
for ii in range(len(pedigs_stack)):
    pedigs_stack[ii].count()

# %%
# Look for MZ twins missing their co-twin
uniques = list(df_pedig.mztwin.unique())
uniques.pop(0)
twin_counts = [np.sum(df_pedig.mztwin==twin) for twin in uniques]
# for idx, twin in enumerate(uniques):
#     print("{} occurs {} times".format(twin, twin_counts[idx]))

# %%
# create a mask that will kepp only MZ twins missing their co-twin
singles = [True if np.sum(df_pedig.mztwin==row.mztwin)==1 else False for ind, row in df_pedig.iterrows()]

# %%
# Make a copy of the pedigre to avoid missing up with the original data
copy_df_pedig = df_pedig.copy()

# %%
# Select only MZ twins missing their co-twin
df_single_pedig = copy_df_pedig[singles]

# Add "M_" (for missing) to a the single MZ twins
for i, row in df_single_pedig.iterrows():
    df_single_pedig.set_value(i,"ID","M_{}".format(row.ID))
df_single_pedig.count()
# Out:
# ID        48
# fa        48
# mo        48
# sex       48
# mztwin    48
# hhID      48
# dtype: int64

# %%
# Append pedgree with fake co-twin for the missing one
df_pedig_final = copy_df_pedig.append(df_single_pedig)
#df_pedig_final = pedigs_stack[5]
df_pedig_final.count()
# Out:
# ID        774
# fa        774
# mo        774
# sex       774
# mztwin    222
# hhID      774
# dtype: int64

# %%
# save to file
df_pedig_final.to_csv(os.path.join(path_root,'pleio_all_pheno_pedig.csv'),index=False)

# %% [markdown]
# ### Pleiothropy estimate:

# %%
import collections
import multiprocessing

# %%
No_converge = collections.namedtuple('No_converge', [
    'var1',
    'var2',
    'out_dir'
])

# %%
no_converges
# Out:
# [No_converge(var1='EMO_contrast_fear_vs_neut_sub1', var2='EMO_contrast_fear_vs_neut_sub3', out_dir='EMO_contrast_fear_vs_neut_sub1_EMO_contrast_fear_vs_neut_sub3'),
#  No_converge(var1='EMO_contrast_fear_vs_neut_sub1', var2='WM_contrast_places_vs_other_places_sub1', out_dir='EMO_contrast_fear_vs_neut_sub1_WM_contrast_places_vs_other_places_sub1'),
#  No_converge(var1='EMO_contrast_fear_vs_neut_sub3', var2='EMO_contrast_fear_vs_neut_sub1', out_dir='EMO_contrast_fear_vs_neut_sub3_EMO_contrast_fear_vs_neut_sub1'),
#  No_converge(var1='EMO_contrast_fear_vs_neut_sub3', var2='EMO_contrast_fear_vs_neut_sub4', out_dir='EMO_contrast_fear_vs_neut_sub3_EMO_contrast_fear_vs_neut_sub4'),
#  No_converge(var1='EMO_contrast_fear_vs_neut_sub3', var2='SOC_contrast_mental_vs_rnd_sub5', out_dir='EMO_contrast_fear_vs_neut_sub3_SOC_contrast_mental_vs_rnd_sub5'),
#  No_converge(var1='EMO_contrast_fear_vs_neut_sub3', var2='MOT_rh_sub1', out_dir='EMO_contrast_fear_vs_neut_sub3_MOT_rh_sub1'),
#  No_converge(var1='EMO_contrast_fear_vs_neut_sub3', var2='MOT_rh_sub4', out_dir='EMO_contrast_fear_vs_neut_sub3_MOT_rh_sub4'),
#  No_converge(var1='EMO_contrast_fear_vs_neut_sub3', var2='MOT_lh_sub1', out_dir='EMO_contrast_fear_vs_neut_sub3_MOT_lh_sub1'),
#  No_converge(var1='EMO_contrast_fear_vs_neut_sub3', var2='WM_contrast_places_vs_other_places_sub1', out_dir='EMO_contrast_fear_vs_neut_sub3_WM_contrast_places_vs_other_places_sub1'),
#  No_converge(var1='EMO_contrast_fear_vs_neut_sub3', var2='WM_contrast_places_vs_other_places_sub2', out_dir='EMO_contrast_fear_vs_neut_sub3_WM_contrast_places_vs_other_places_sub2'),
#  No_converge(var1='EMO_contrast_fear_vs_neut_sub3', var2='WM_contrast_faces_vs_other_faces_sub3', out_dir='EMO_contrast_fear_vs_neut_sub3_WM_contrast_faces_vs_other_faces_sub3'),
#  No_converge(var1='EMO_contrast_fear_vs_neut_sub3', var2='LAN_story_sub1', out_dir='EMO_contrast_fear_vs_neut_sub3_LAN_story_sub1'),
#  No_converge(var1='EMO_contrast_fear_vs_neut_sub3', var2='LAN_story_sub2', out_dir='EMO_contrast_fear_vs_neut_sub3_LAN_story_sub2'),
#  No_converge(var1='EMO_contrast_fear_vs_neut_sub3', var2='LAN_story_sub3', out_dir='EMO_contrast_fear_vs_neut_sub3_LAN_story_sub3'),
#  No_converge(var1='EMO_contrast_fear_vs_neut_sub3', var2='LAN_story_sub5', out_dir='EMO_contrast_fear_vs_neut_sub3_LAN_story_sub5'),
#  No_converge(var1='EMO_contrast_fear_vs_neut_sub4', var2='EMO_contrast_fear_vs_neut_sub3', out_dir='EMO_contrast_fear_vs_neut_sub4_EMO_contrast_fear_vs_neut_sub3'),
#  No_converge(var1='EMO_contrast_fear_vs_neut_sub4', var2='WM_contrast_places_vs_other_places_sub1', out_dir='EMO_contrast_fear_vs_neut_sub4_WM_contrast_places_vs_other_places_sub1'),
#  No_converge(var1='SOC_mental_sub1', var2='SOC_mental_sub4', out_dir='SOC_mental_sub1_SOC_mental_sub4'),
#  No_converge(var1='SOC_mental_sub1', var2='REL_match_sub1', out_dir='SOC_mental_sub1_REL_match_sub1'),
#  No_converge(var1='SOC_mental_sub1', var2='REL_match_sub2', out_dir='SOC_mental_sub1_REL_match_sub2'),
#  No_converge(var1='SOC_mental_sub1', var2='REL_match_sub4', out_dir='SOC_mental_sub1_REL_match_sub4'),
#  No_converge(var1='SOC_mental_sub1', var2='REL_match_sub5', out_dir='SOC_mental_sub1_REL_match_sub5'),
#  No_converge(var1='SOC_mental_sub1', var2='REL_relation_sub2', out_dir='SOC_mental_sub1_REL_relation_sub2'),
#  No_converge(var1='SOC_mental_sub1', var2='REL_relation_sub4', out_dir='SOC_mental_sub1_REL_relation_sub4'),
#  No_converge(var1='SOC_mental_sub1', var2='REL_relation_sub5', out_dir='SOC_mental_sub1_REL_relation_sub5'),
#  No_converge(var1='SOC_mental_sub1', var2='WM_contrast_places_vs_other_places_sub1', out_dir='SOC_mental_sub1_WM_contrast_places_vs_other_places_sub1'),
#  No_converge(var1='SOC_mental_sub1', var2='WM_contrast_places_vs_other_places_sub4', out_dir='SOC_mental_sub1_WM_contrast_places_vs_other_places_sub4'),
#  No_converge(var1='SOC_mental_sub1', var2='LAN_story_sub1', out_dir='SOC_mental_sub1_LAN_story_sub1'),
#  No_converge(var1='SOC_mental_sub1', var2='LAN_story_sub2', out_dir='SOC_mental_sub1_LAN_story_sub2'),
#  No_converge(var1='SOC_mental_sub1', var2='LAN_story_sub3', out_dir='SOC_mental_sub1_LAN_story_sub3'),
#  No_converge(var1='SOC_mental_sub1', var2='LAN_story_sub4', out_dir='SOC_mental_sub1_LAN_story_sub4'),
#  No_converge(var1='SOC_mental_sub1', var2='LAN_story_sub5', out_dir='SOC_mental_sub1_LAN_story_sub5'),
#  No_converge(var1='SOC_mental_sub3', var2='LAN_story_sub1', out_dir='SOC_mental_sub3_LAN_story_sub1'),
#  No_converge(var1='SOC_mental_sub3', var2='LAN_story_sub2', out_dir='SOC_mental_sub3_LAN_story_sub2'),
#  No_converge(var1='SOC_mental_sub3', var2='LAN_story_sub3', out_dir='SOC_mental_sub3_LAN_story_sub3'),
#  No_converge(var1='SOC_mental_sub3', var2='LAN_story_sub5', out_dir='SOC_mental_sub3_LAN_story_sub5'),
#  No_converge(var1='SOC_mental_sub4', var2='SOC_mental_sub1', out_dir='SOC_mental_sub4_SOC_mental_sub1'),
#  No_converge(var1='SOC_mental_sub4', var2='REL_match_sub1', out_dir='SOC_mental_sub4_REL_match_sub1'),
#  No_converge(var1='SOC_mental_sub4', var2='REL_match_sub2', out_dir='SOC_mental_sub4_REL_match_sub2'),
#  No_converge(var1='SOC_mental_sub4', var2='REL_match_sub4', out_dir='SOC_mental_sub4_REL_match_sub4'),
#  No_converge(var1='SOC_mental_sub4', var2='REL_match_sub5', out_dir='SOC_mental_sub4_REL_match_sub5'),
#  No_converge(var1='SOC_mental_sub4', var2='REL_relation_sub2', out_dir='SOC_mental_sub4_REL_relation_sub2'),
#  No_converge(var1='SOC_mental_sub4', var2='REL_relation_sub5', out_dir='SOC_mental_sub4_REL_relation_sub5'),
#  No_converge(var1='SOC_mental_sub4', var2='LAN_story_sub1', out_dir='SOC_mental_sub4_LAN_story_sub1'),
#  No_converge(var1='SOC_mental_sub4', var2='LAN_story_sub2', out_dir='SOC_mental_sub4_LAN_story_sub2'),
#  No_converge(var1='SOC_mental_sub4', var2='LAN_story_sub3', out_dir='SOC_mental_sub4_LAN_story_sub3'),
#  No_converge(var1='SOC_mental_sub4', var2='LAN_story_sub4', out_dir='SOC_mental_sub4_LAN_story_sub4'),
#  No_converge(var1='SOC_mental_sub4', var2='LAN_story_sub5', out_dir='SOC_mental_sub4_LAN_story_sub5'),
#  No_converge(var1='SOC_mental_sub5', var2='WM_0bk_sub2', out_dir='SOC_mental_sub5_WM_0bk_sub2'),
#  No_converge(var1='SOC_mental_sub5', var2='WM_contrast_places_vs_other_places_sub1', out_dir='SOC_mental_sub5_WM_contrast_places_vs_other_places_sub1'),
#  No_converge(var1='SOC_mental_sub5', var2='LAN_story_sub1', out_dir='SOC_mental_sub5_LAN_story_sub1'),
#  No_converge(var1='SOC_mental_sub5', var2='LAN_story_sub2', out_dir='SOC_mental_sub5_LAN_story_sub2'),
#  No_converge(var1='SOC_mental_sub5', var2='LAN_story_sub3', out_dir='SOC_mental_sub5_LAN_story_sub3'),
#  No_converge(var1='SOC_mental_sub5', var2='LAN_story_sub5', out_dir='SOC_mental_sub5_LAN_story_sub5'),
#  No_converge(var1='SOC_contrast_mental_vs_rnd_sub5', var2='EMO_contrast_fear_vs_neut_sub3', out_dir='SOC_contrast_mental_vs_rnd_sub5_EMO_contrast_fear_vs_neut_sub3'),
#  No_converge(var1='SOC_contrast_mental_vs_rnd_sub5', var2='WM_contrast_places_vs_other_places_sub1', out_dir='SOC_contrast_mental_vs_rnd_sub5_WM_contrast_places_vs_other_places_sub1'),
#  No_converge(var1='SOC_contrast_mental_vs_rnd_sub5', var2='WM_contrast_faces_vs_other_faces_sub3', out_dir='SOC_contrast_mental_vs_rnd_sub5_WM_contrast_faces_vs_other_faces_sub3'),
#  No_converge(var1='SOC_contrast_mental_vs_rnd_sub5', var2='LAN_story_sub1', out_dir='SOC_contrast_mental_vs_rnd_sub5_LAN_story_sub1'),
#  No_converge(var1='SOC_contrast_mental_vs_rnd_sub5', var2='LAN_story_sub2', out_dir='SOC_contrast_mental_vs_rnd_sub5_LAN_story_sub2'),
#  No_converge(var1='SOC_contrast_mental_vs_rnd_sub5', var2='LAN_story_sub3', out_dir='SOC_contrast_mental_vs_rnd_sub5_LAN_story_sub3'),
#  No_converge(var1='SOC_contrast_mental_vs_rnd_sub5', var2='LAN_story_sub5', out_dir='SOC_contrast_mental_vs_rnd_sub5_LAN_story_sub5'),
#  No_converge(var1='REL_match_sub1', var2='SOC_mental_sub1', out_dir='REL_match_sub1_SOC_mental_sub1'),
#  No_converge(var1='REL_match_sub1', var2='SOC_mental_sub4', out_dir='REL_match_sub1_SOC_mental_sub4'),
#  No_converge(var1='REL_match_sub1', var2='REL_match_sub2', out_dir='REL_match_sub1_REL_match_sub2'),
#  No_converge(var1='REL_match_sub1', var2='REL_match_sub4', out_dir='REL_match_sub1_REL_match_sub4'),
#  No_converge(var1='REL_match_sub1', var2='REL_match_sub5', out_dir='REL_match_sub1_REL_match_sub5'),
#  No_converge(var1='REL_match_sub1', var2='REL_relation_sub2', out_dir='REL_match_sub1_REL_relation_sub2'),
#  No_converge(var1='REL_match_sub1', var2='REL_relation_sub4', out_dir='REL_match_sub1_REL_relation_sub4'),
#  No_converge(var1='REL_match_sub1', var2='REL_relation_sub5', out_dir='REL_match_sub1_REL_relation_sub5'),
#  No_converge(var1='REL_match_sub1', var2='MOT_rf_sub1', out_dir='REL_match_sub1_MOT_rf_sub1'),
#  No_converge(var1='REL_match_sub1', var2='MOT_t_sub1', out_dir='REL_match_sub1_MOT_t_sub1'),
#  No_converge(var1='REL_match_sub1', var2='WM_contrast_2bk_vs_0bk_sub2', out_dir='REL_match_sub1_WM_contrast_2bk_vs_0bk_sub2'),
#  No_converge(var1='REL_match_sub1', var2='WM_contrast_2bk_vs_0bk_sub4', out_dir='REL_match_sub1_WM_contrast_2bk_vs_0bk_sub4'),
#  No_converge(var1='REL_match_sub1', var2='WM_contrast_places_vs_other_places_sub1', out_dir='REL_match_sub1_WM_contrast_places_vs_other_places_sub1'),
#  No_converge(var1='REL_match_sub1', var2='WM_contrast_faces_vs_other_faces_sub3', out_dir='REL_match_sub1_WM_contrast_faces_vs_other_faces_sub3'),
#  No_converge(var1='REL_match_sub1', var2='LAN_story_sub1', out_dir='REL_match_sub1_LAN_story_sub1'),
#  No_converge(var1='REL_match_sub1', var2='LAN_story_sub2', out_dir='REL_match_sub1_LAN_story_sub2'),
#  No_converge(var1='REL_match_sub1', var2='LAN_story_sub3', out_dir='REL_match_sub1_LAN_story_sub3'),
#  No_converge(var1='REL_match_sub1', var2='LAN_story_sub5', out_dir='REL_match_sub1_LAN_story_sub5'),
#  No_converge(var1='REL_match_sub2', var2='SOC_mental_sub1', out_dir='REL_match_sub2_SOC_mental_sub1'),
#  No_converge(var1='REL_match_sub2', var2='SOC_mental_sub4', out_dir='REL_match_sub2_SOC_mental_sub4'),
#  No_converge(var1='REL_match_sub2', var2='REL_match_sub1', out_dir='REL_match_sub2_REL_match_sub1'),
#  No_converge(var1='REL_match_sub2', var2='REL_match_sub4', out_dir='REL_match_sub2_REL_match_sub4'),
#  No_converge(var1='REL_match_sub2', var2='REL_relation_sub2', out_dir='REL_match_sub2_REL_relation_sub2'),
#  No_converge(var1='REL_match_sub2', var2='REL_relation_sub4', out_dir='REL_match_sub2_REL_relation_sub4'),
#  No_converge(var1='REL_match_sub2', var2='REL_relation_sub5', out_dir='REL_match_sub2_REL_relation_sub5'),
#  No_converge(var1='REL_match_sub2', var2='MOT_rf_sub1', out_dir='REL_match_sub2_MOT_rf_sub1'),
#  No_converge(var1='REL_match_sub2', var2='MOT_t_sub1', out_dir='REL_match_sub2_MOT_t_sub1'),
#  No_converge(var1='REL_match_sub2', var2='WM_contrast_2bk_vs_0bk_sub2', out_dir='REL_match_sub2_WM_contrast_2bk_vs_0bk_sub2'),
#  No_converge(var1='REL_match_sub2', var2='WM_contrast_2bk_vs_0bk_sub4', out_dir='REL_match_sub2_WM_contrast_2bk_vs_0bk_sub4'),
#  No_converge(var1='REL_match_sub2', var2='WM_contrast_places_vs_other_places_sub1', out_dir='REL_match_sub2_WM_contrast_places_vs_other_places_sub1'),
#  No_converge(var1='REL_match_sub2', var2='WM_contrast_places_vs_other_places_sub4', out_dir='REL_match_sub2_WM_contrast_places_vs_other_places_sub4'),
#  No_converge(var1='REL_match_sub2', var2='WM_contrast_faces_vs_other_faces_sub3', out_dir='REL_match_sub2_WM_contrast_faces_vs_other_faces_sub3'),
#  No_converge(var1='REL_match_sub2', var2='LAN_story_sub1', out_dir='REL_match_sub2_LAN_story_sub1'),
#  No_converge(var1='REL_match_sub2', var2='LAN_story_sub2', out_dir='REL_match_sub2_LAN_story_sub2'),
#  No_converge(var1='REL_match_sub2', var2='LAN_story_sub3', out_dir='REL_match_sub2_LAN_story_sub3'),
#  No_converge(var1='REL_match_sub2', var2='LAN_story_sub5', out_dir='REL_match_sub2_LAN_story_sub5'),
#  No_converge(var1='REL_match_sub4', var2='SOC_mental_sub1', out_dir='REL_match_sub4_SOC_mental_sub1'),
#  No_converge(var1='REL_match_sub4', var2='SOC_mental_sub4', out_dir='REL_match_sub4_SOC_mental_sub4'),
#  No_converge(var1='REL_match_sub4', var2='REL_match_sub1', out_dir='REL_match_sub4_REL_match_sub1'),
#  No_converge(var1='REL_match_sub4', var2='REL_match_sub2', out_dir='REL_match_sub4_REL_match_sub2'),
#  No_converge(var1='REL_match_sub4', var2='REL_match_sub5', out_dir='REL_match_sub4_REL_match_sub5'),
#  No_converge(var1='REL_match_sub4', var2='REL_relation_sub2', out_dir='REL_match_sub4_REL_relation_sub2'),
#  No_converge(var1='REL_match_sub4', var2='REL_relation_sub4', out_dir='REL_match_sub4_REL_relation_sub4'),
#  No_converge(var1='REL_match_sub4', var2='REL_relation_sub5', out_dir='REL_match_sub4_REL_relation_sub5'),
#  No_converge(var1='REL_match_sub4', var2='WM_contrast_places_vs_other_places_sub1', out_dir='REL_match_sub4_WM_contrast_places_vs_other_places_sub1'),
#  No_converge(var1='REL_match_sub4', var2='LAN_story_sub1', out_dir='REL_match_sub4_LAN_story_sub1'),
#  No_converge(var1='REL_match_sub4', var2='LAN_story_sub2', out_dir='REL_match_sub4_LAN_story_sub2'),
#  No_converge(var1='REL_match_sub4', var2='LAN_story_sub3', out_dir='REL_match_sub4_LAN_story_sub3'),
#  No_converge(var1='REL_match_sub4', var2='LAN_story_sub4', out_dir='REL_match_sub4_LAN_story_sub4'),
#  No_converge(var1='REL_match_sub4', var2='LAN_story_sub5', out_dir='REL_match_sub4_LAN_story_sub5'),
#  No_converge(var1='REL_match_sub5', var2='SOC_mental_sub1', out_dir='REL_match_sub5_SOC_mental_sub1'),
#  No_converge(var1='REL_match_sub5', var2='SOC_mental_sub4', out_dir='REL_match_sub5_SOC_mental_sub4'),
#  No_converge(var1='REL_match_sub5', var2='REL_match_sub1', out_dir='REL_match_sub5_REL_match_sub1'),
#  No_converge(var1='REL_match_sub5', var2='REL_match_sub4', out_dir='REL_match_sub5_REL_match_sub4'),
#  No_converge(var1='REL_match_sub5', var2='REL_relation_sub2', out_dir='REL_match_sub5_REL_relation_sub2'),
#  No_converge(var1='REL_match_sub5', var2='REL_relation_sub4', out_dir='REL_match_sub5_REL_relation_sub4'),
#  No_converge(var1='REL_match_sub5', var2='REL_relation_sub5', out_dir='REL_match_sub5_REL_relation_sub5'),
#  No_converge(var1='REL_match_sub5', var2='MOT_rf_sub1', out_dir='REL_match_sub5_MOT_rf_sub1'),
#  No_converge(var1='REL_match_sub5', var2='MOT_rf_sub3', out_dir='REL_match_sub5_MOT_rf_sub3'),
#  No_converge(var1='REL_match_sub5', var2='MOT_t_sub1', out_dir='REL_match_sub5_MOT_t_sub1'),
#  No_converge(var1='REL_match_sub5', var2='WM_contrast_2bk_vs_0bk_sub2', out_dir='REL_match_sub5_WM_contrast_2bk_vs_0bk_sub2'),
#  No_converge(var1='REL_match_sub5', var2='WM_contrast_2bk_vs_0bk_sub4', out_dir='REL_match_sub5_WM_contrast_2bk_vs_0bk_sub4'),
#  No_converge(var1='REL_match_sub5', var2='WM_contrast_places_vs_other_places_sub1', out_dir='REL_match_sub5_WM_contrast_places_vs_other_places_sub1'),
#  No_converge(var1='REL_match_sub5', var2='WM_contrast_faces_vs_other_faces_sub3', out_dir='REL_match_sub5_WM_contrast_faces_vs_other_faces_sub3'),
#  No_converge(var1='REL_match_sub5', var2='LAN_story_sub1', out_dir='REL_match_sub5_LAN_story_sub1'),
#  No_converge(var1='REL_match_sub5', var2='LAN_story_sub2', out_dir='REL_match_sub5_LAN_story_sub2'),
#  No_converge(var1='REL_match_sub5', var2='LAN_story_sub3', out_dir='REL_match_sub5_LAN_story_sub3'),
#  No_converge(var1='REL_match_sub5', var2='LAN_story_sub5', out_dir='REL_match_sub5_LAN_story_sub5'),
#  No_converge(var1='REL_relation_sub1', var2='LAN_story_sub5', out_dir='REL_relation_sub1_LAN_story_sub5'),
#  No_converge(var1='REL_relation_sub2', var2='SOC_mental_sub1', out_dir='REL_relation_sub2_SOC_mental_sub1'),
#  No_converge(var1='REL_relation_sub2', var2='SOC_mental_sub4', out_dir='REL_relation_sub2_SOC_mental_sub4'),
#  No_converge(var1='REL_relation_sub2', var2='REL_match_sub1', out_dir='REL_relation_sub2_REL_match_sub1'),
#  No_converge(var1='REL_relation_sub2', var2='REL_match_sub2', out_dir='REL_relation_sub2_REL_match_sub2'),
#  No_converge(var1='REL_relation_sub2', var2='REL_match_sub4', out_dir='REL_relation_sub2_REL_match_sub4'),
#  No_converge(var1='REL_relation_sub2', var2='REL_match_sub5', out_dir='REL_relation_sub2_REL_match_sub5'),
#  No_converge(var1='REL_relation_sub2', var2='REL_relation_sub4', out_dir='REL_relation_sub2_REL_relation_sub4'),
#  No_converge(var1='REL_relation_sub2', var2='REL_relation_sub5', out_dir='REL_relation_sub2_REL_relation_sub5'),
#  No_converge(var1='REL_relation_sub2', var2='MOT_rh_sub1', out_dir='REL_relation_sub2_MOT_rh_sub1'),
#  No_converge(var1='REL_relation_sub2', var2='MOT_rh_sub4', out_dir='REL_relation_sub2_MOT_rh_sub4'),
#  No_converge(var1='REL_relation_sub2', var2='MOT_rf_sub1', out_dir='REL_relation_sub2_MOT_rf_sub1'),
#  No_converge(var1='REL_relation_sub2', var2='MOT_rf_sub3', out_dir='REL_relation_sub2_MOT_rf_sub3'),
#  No_converge(var1='REL_relation_sub2', var2='MOT_lf_sub1', out_dir='REL_relation_sub2_MOT_lf_sub1'),
#  No_converge(var1='REL_relation_sub2', var2='MOT_lh_sub1', out_dir='REL_relation_sub2_MOT_lh_sub1'),
#  No_converge(var1='REL_relation_sub2', var2='WM_contrast_2bk_vs_0bk_sub2', out_dir='REL_relation_sub2_WM_contrast_2bk_vs_0bk_sub2'),
#  No_converge(var1='REL_relation_sub2', var2='WM_contrast_places_vs_other_places_sub1', out_dir='REL_relation_sub2_WM_contrast_places_vs_other_places_sub1'),
#  No_converge(var1='REL_relation_sub2', var2='WM_contrast_faces_vs_other_faces_sub3', out_dir='REL_relation_sub2_WM_contrast_faces_vs_other_faces_sub3'),
#  No_converge(var1='REL_relation_sub2', var2='LAN_story_sub1', out_dir='REL_relation_sub2_LAN_story_sub1'),
#  No_converge(var1='REL_relation_sub2', var2='LAN_story_sub2', out_dir='REL_relation_sub2_LAN_story_sub2'),
#  No_converge(var1='REL_relation_sub2', var2='LAN_story_sub3', out_dir='REL_relation_sub2_LAN_story_sub3'),
#  No_converge(var1='REL_relation_sub2', var2='LAN_story_sub5', out_dir='REL_relation_sub2_LAN_story_sub5'),
#  No_converge(var1='REL_relation_sub3', var2='REL_contrast_relation_vs_match_sub3', out_dir='REL_relation_sub3_REL_contrast_relation_vs_match_sub3'),
#  No_converge(var1='REL_relation_sub4', var2='SOC_mental_sub1', out_dir='REL_relation_sub4_SOC_mental_sub1'),
#  No_converge(var1='REL_relation_sub4', var2='REL_match_sub1', out_dir='REL_relation_sub4_REL_match_sub1'),
#  No_converge(var1='REL_relation_sub4', var2='REL_match_sub2', out_dir='REL_relation_sub4_REL_match_sub2'),
#  No_converge(var1='REL_relation_sub4', var2='REL_match_sub4', out_dir='REL_relation_sub4_REL_match_sub4'),
#  No_converge(var1='REL_relation_sub4', var2='REL_match_sub5', out_dir='REL_relation_sub4_REL_match_sub5'),
#  No_converge(var1='REL_relation_sub4', var2='REL_relation_sub2', out_dir='REL_relation_sub4_REL_relation_sub2'),
#  No_converge(var1='REL_relation_sub4', var2='REL_relation_sub5', out_dir='REL_relation_sub4_REL_relation_sub5'),
#  No_converge(var1='REL_relation_sub4', var2='MOT_rh_sub1', out_dir='REL_relation_sub4_MOT_rh_sub1'),
#  No_converge(var1='REL_relation_sub4', var2='MOT_rh_sub4', out_dir='REL_relation_sub4_MOT_rh_sub4'),
#  No_converge(var1='REL_relation_sub4', var2='MOT_rf_sub1', out_dir='REL_relation_sub4_MOT_rf_sub1'),
#  No_converge(var1='REL_relation_sub4', var2='WM_contrast_places_vs_other_places_sub1', out_dir='REL_relation_sub4_WM_contrast_places_vs_other_places_sub1'),
#  No_converge(var1='REL_relation_sub4', var2='WM_contrast_faces_vs_other_faces_sub3', out_dir='REL_relation_sub4_WM_contrast_faces_vs_other_faces_sub3'),
#  No_converge(var1='REL_relation_sub4', var2='LAN_story_sub1', out_dir='REL_relation_sub4_LAN_story_sub1'),
#  No_converge(var1='REL_relation_sub4', var2='LAN_story_sub2', out_dir='REL_relation_sub4_LAN_story_sub2'),
#  No_converge(var1='REL_relation_sub4', var2='LAN_story_sub3', out_dir='REL_relation_sub4_LAN_story_sub3'),
#  No_converge(var1='REL_relation_sub4', var2='LAN_story_sub5', out_dir='REL_relation_sub4_LAN_story_sub5'),
#  No_converge(var1='REL_relation_sub5', var2='SOC_mental_sub1', out_dir='REL_relation_sub5_SOC_mental_sub1'),
#  No_converge(var1='REL_relation_sub5', var2='SOC_mental_sub4', out_dir='REL_relation_sub5_SOC_mental_sub4'),
#  No_converge(var1='REL_relation_sub5', var2='REL_match_sub1', out_dir='REL_relation_sub5_REL_match_sub1'),
#  No_converge(var1='REL_relation_sub5', var2='REL_match_sub2', out_dir='REL_relation_sub5_REL_match_sub2'),
#  No_converge(var1='REL_relation_sub5', var2='REL_match_sub4', out_dir='REL_relation_sub5_REL_match_sub4'),
#  No_converge(var1='REL_relation_sub5', var2='REL_match_sub5', out_dir='REL_relation_sub5_REL_match_sub5'),
#  No_converge(var1='REL_relation_sub5', var2='REL_relation_sub2', out_dir='REL_relation_sub5_REL_relation_sub2'),
#  No_converge(var1='REL_relation_sub5', var2='REL_relation_sub4', out_dir='REL_relation_sub5_REL_relation_sub4'),
#  No_converge(var1='REL_relation_sub5', var2='MOT_rh_sub1', out_dir='REL_relation_sub5_MOT_rh_sub1'),
#  No_converge(var1='REL_relation_sub5', var2='MOT_rh_sub4', out_dir='REL_relation_sub5_MOT_rh_sub4'),
#  No_converge(var1='REL_relation_sub5', var2='MOT_rf_sub1', out_dir='REL_relation_sub5_MOT_rf_sub1'),
#  No_converge(var1='REL_relation_sub5', var2='MOT_rf_sub3', out_dir='REL_relation_sub5_MOT_rf_sub3'),
#  No_converge(var1='REL_relation_sub5', var2='MOT_lf_sub1', out_dir='REL_relation_sub5_MOT_lf_sub1'),
#  No_converge(var1='REL_relation_sub5', var2='MOT_lh_sub1', out_dir='REL_relation_sub5_MOT_lh_sub1'),
#  No_converge(var1='REL_relation_sub5', var2='WM_contrast_2bk_vs_0bk_sub2', out_dir='REL_relation_sub5_WM_contrast_2bk_vs_0bk_sub2'),
#  No_converge(var1='REL_relation_sub5', var2='WM_contrast_places_vs_other_places_sub1', out_dir='REL_relation_sub5_WM_contrast_places_vs_other_places_sub1'),
#  No_converge(var1='REL_relation_sub5', var2='WM_contrast_faces_vs_other_faces_sub3', out_dir='REL_relation_sub5_WM_contrast_faces_vs_other_faces_sub3'),
#  No_converge(var1='REL_relation_sub5', var2='LAN_story_sub1', out_dir='REL_relation_sub5_LAN_story_sub1'),
#  No_converge(var1='REL_relation_sub5', var2='LAN_story_sub2', out_dir='REL_relation_sub5_LAN_story_sub2'),
#  No_converge(var1='REL_relation_sub5', var2='LAN_story_sub3', out_dir='REL_relation_sub5_LAN_story_sub3'),
#  No_converge(var1='REL_relation_sub5', var2='LAN_story_sub5', out_dir='REL_relation_sub5_LAN_story_sub5'),
#  No_converge(var1='REL_contrast_relation_vs_match_sub1', var2='WM_contrast_places_vs_other_places_sub2', out_dir='REL_contrast_relation_vs_match_sub1_WM_contrast_places_vs_other_places_sub2'),
#  No_converge(var1='MOT_rh_sub1', var2='EMO_contrast_fear_vs_neut_sub3', out_dir='MOT_rh_sub1_EMO_contrast_fear_vs_neut_sub3'),
#  No_converge(var1='MOT_rh_sub1', var2='REL_relation_sub2', out_dir='MOT_rh_sub1_REL_relation_sub2'),
#  No_converge(var1='MOT_rh_sub1', var2='REL_relation_sub4', out_dir='MOT_rh_sub1_REL_relation_sub4'),
#  No_converge(var1='MOT_rh_sub1', var2='REL_relation_sub5', out_dir='MOT_rh_sub1_REL_relation_sub5'),
#  No_converge(var1='MOT_rh_sub1', var2='MOT_rh_sub4', out_dir='MOT_rh_sub1_MOT_rh_sub4'),
#  No_converge(var1='MOT_rh_sub1', var2='MOT_t_sub1', out_dir='MOT_rh_sub1_MOT_t_sub1'),
#  No_converge(var1='MOT_rh_sub1', var2='MOT_lh_sub1', out_dir='MOT_rh_sub1_MOT_lh_sub1'),
#  No_converge(var1='MOT_rh_sub1', var2='WM_contrast_places_vs_other_places_sub1', out_dir='MOT_rh_sub1_WM_contrast_places_vs_other_places_sub1'),
#  No_converge(var1='MOT_rh_sub1', var2='LAN_story_sub1', out_dir='MOT_rh_sub1_LAN_story_sub1'),
#  No_converge(var1='MOT_rh_sub1', var2='LAN_story_sub2', out_dir='MOT_rh_sub1_LAN_story_sub2'),
#  No_converge(var1='MOT_rh_sub1', var2='LAN_story_sub3', out_dir='MOT_rh_sub1_LAN_story_sub3'),
#  No_converge(var1='MOT_rh_sub1', var2='LAN_story_sub5', out_dir='MOT_rh_sub1_LAN_story_sub5'),
#  No_converge(var1='MOT_rh_sub4', var2='EMO_contrast_fear_vs_neut_sub3', out_dir='MOT_rh_sub4_EMO_contrast_fear_vs_neut_sub3'),
#  No_converge(var1='MOT_rh_sub4', var2='REL_relation_sub2', out_dir='MOT_rh_sub4_REL_relation_sub2'),
#  No_converge(var1='MOT_rh_sub4', var2='REL_relation_sub4', out_dir='MOT_rh_sub4_REL_relation_sub4'),
#  No_converge(var1='MOT_rh_sub4', var2='REL_relation_sub5', out_dir='MOT_rh_sub4_REL_relation_sub5'),
#  No_converge(var1='MOT_rh_sub4', var2='MOT_rh_sub1', out_dir='MOT_rh_sub4_MOT_rh_sub1'),
#  No_converge(var1='MOT_rh_sub4', var2='MOT_lh_sub1', out_dir='MOT_rh_sub4_MOT_lh_sub1'),
#  No_converge(var1='MOT_rh_sub4', var2='MOT_lh_sub4', out_dir='MOT_rh_sub4_MOT_lh_sub4'),
#  No_converge(var1='MOT_rh_sub4', var2='WM_contrast_tools_vs_other_tools_sub5', out_dir='MOT_rh_sub4_WM_contrast_tools_vs_other_tools_sub5'),
#  No_converge(var1='MOT_rh_sub4', var2='WM_contrast_places_vs_other_places_sub1', out_dir='MOT_rh_sub4_WM_contrast_places_vs_other_places_sub1'),
#  No_converge(var1='MOT_rh_sub4', var2='WM_contrast_faces_vs_other_faces_sub4', out_dir='MOT_rh_sub4_WM_contrast_faces_vs_other_faces_sub4'),
#  No_converge(var1='MOT_rh_sub4', var2='LAN_story_sub1', out_dir='MOT_rh_sub4_LAN_story_sub1'),
#  No_converge(var1='MOT_rh_sub4', var2='LAN_story_sub2', out_dir='MOT_rh_sub4_LAN_story_sub2'),
#  No_converge(var1='MOT_rh_sub4', var2='LAN_story_sub3', out_dir='MOT_rh_sub4_LAN_story_sub3'),
#  No_converge(var1='MOT_rh_sub4', var2='LAN_story_sub5', out_dir='MOT_rh_sub4_LAN_story_sub5'),
#  No_converge(var1='MOT_rh_sub5', var2='WM_contrast_faces_vs_other_faces_sub4', out_dir='MOT_rh_sub5_WM_contrast_faces_vs_other_faces_sub4'),
#  No_converge(var1='MOT_rf_sub1', var2='REL_match_sub1', out_dir='MOT_rf_sub1_REL_match_sub1'),
#  No_converge(var1='MOT_rf_sub1', var2='REL_match_sub2', out_dir='MOT_rf_sub1_REL_match_sub2'),
#  No_converge(var1='MOT_rf_sub1', var2='REL_match_sub5', out_dir='MOT_rf_sub1_REL_match_sub5'),
#  No_converge(var1='MOT_rf_sub1', var2='REL_relation_sub2', out_dir='MOT_rf_sub1_REL_relation_sub2'),
#  No_converge(var1='MOT_rf_sub1', var2='REL_relation_sub4', out_dir='MOT_rf_sub1_REL_relation_sub4'),
#  No_converge(var1='MOT_rf_sub1', var2='REL_relation_sub5', out_dir='MOT_rf_sub1_REL_relation_sub5'),
#  No_converge(var1='MOT_rf_sub3', var2='REL_match_sub5', out_dir='MOT_rf_sub3_REL_match_sub5'),
#  No_converge(var1='MOT_rf_sub3', var2='REL_relation_sub2', out_dir='MOT_rf_sub3_REL_relation_sub2'),
#  No_converge(var1='MOT_rf_sub3', var2='REL_relation_sub5', out_dir='MOT_rf_sub3_REL_relation_sub5'),
#  No_converge(var1='MOT_rf_sub3', var2='WM_contrast_faces_vs_other_faces_sub4', out_dir='MOT_rf_sub3_WM_contrast_faces_vs_other_faces_sub4'),
#  No_converge(var1='MOT_t_sub1', var2='REL_match_sub1', out_dir='MOT_t_sub1_REL_match_sub1'),
#  No_converge(var1='MOT_t_sub1', var2='REL_match_sub2', out_dir='MOT_t_sub1_REL_match_sub2'),
#  No_converge(var1='MOT_t_sub1', var2='REL_match_sub5', out_dir='MOT_t_sub1_REL_match_sub5'),
#  No_converge(var1='MOT_t_sub1', var2='MOT_rh_sub1', out_dir='MOT_t_sub1_MOT_rh_sub1'),
#  No_converge(var1='MOT_t_sub1', var2='WM_contrast_places_vs_other_places_sub1', out_dir='MOT_t_sub1_WM_contrast_places_vs_other_places_sub1'),
#  No_converge(var1='MOT_t_sub1', var2='LAN_story_sub1', out_dir='MOT_t_sub1_LAN_story_sub1'),
#  No_converge(var1='MOT_t_sub1', var2='LAN_story_sub2', out_dir='MOT_t_sub1_LAN_story_sub2'),
#  No_converge(var1='MOT_t_sub1', var2='LAN_story_sub3', out_dir='MOT_t_sub1_LAN_story_sub3'),
#  No_converge(var1='MOT_t_sub1', var2='LAN_story_sub5', out_dir='MOT_t_sub1_LAN_story_sub5'),
#  No_converge(var1='MOT_lf_sub1', var2='REL_relation_sub2', out_dir='MOT_lf_sub1_REL_relation_sub2'),
#  No_converge(var1='MOT_lf_sub1', var2='REL_relation_sub5', out_dir='MOT_lf_sub1_REL_relation_sub5'),
#  No_converge(var1='MOT_lh_sub1', var2='EMO_contrast_fear_vs_neut_sub3', out_dir='MOT_lh_sub1_EMO_contrast_fear_vs_neut_sub3'),
#  No_converge(var1='MOT_lh_sub1', var2='REL_relation_sub2', out_dir='MOT_lh_sub1_REL_relation_sub2'),
#  No_converge(var1='MOT_lh_sub1', var2='REL_relation_sub5', out_dir='MOT_lh_sub1_REL_relation_sub5'),
#  No_converge(var1='MOT_lh_sub1', var2='MOT_rh_sub1', out_dir='MOT_lh_sub1_MOT_rh_sub1'),
#  No_converge(var1='MOT_lh_sub1', var2='MOT_rh_sub4', out_dir='MOT_lh_sub1_MOT_rh_sub4'),
#  No_converge(var1='MOT_lh_sub1', var2='WM_contrast_places_vs_other_places_sub2', out_dir='MOT_lh_sub1_WM_contrast_places_vs_other_places_sub2'),
#  No_converge(var1='MOT_lh_sub1', var2='LAN_story_sub1', out_dir='MOT_lh_sub1_LAN_story_sub1'),
#  No_converge(var1='MOT_lh_sub1', var2='LAN_story_sub2', out_dir='MOT_lh_sub1_LAN_story_sub2'),
#  No_converge(var1='MOT_lh_sub1', var2='LAN_story_sub3', out_dir='MOT_lh_sub1_LAN_story_sub3'),
#  No_converge(var1='MOT_lh_sub1', var2='LAN_story_sub5', out_dir='MOT_lh_sub1_LAN_story_sub5'),
#  No_converge(var1='MOT_lh_sub4', var2='MOT_rh_sub4', out_dir='MOT_lh_sub4_MOT_rh_sub4'),
#  No_converge(var1='GAM_contrast_win_vs_loss_sub2', var2='GAM_win_sub1', out_dir='GAM_contrast_win_vs_loss_sub2_GAM_win_sub1'),
#  No_converge(var1='GAM_loss_sub1', var2='WM_contrast_places_vs_other_places_sub4', out_dir='GAM_loss_sub1_WM_contrast_places_vs_other_places_sub4'),
#  No_converge(var1='GAM_win_sub4', var2='WM_0bk_sub2', out_dir='GAM_win_sub4_WM_0bk_sub2'),
#  No_converge(var1='WM_contrast_tools_vs_other_tools_sub1', var2='WM_2bk_sub1', out_dir='WM_contrast_tools_vs_other_tools_sub1_WM_2bk_sub1'),
#  No_converge(var1='WM_contrast_tools_vs_other_tools_sub2', var2='WM_contrast_tools_vs_other_tools_sub4', out_dir='WM_contrast_tools_vs_other_tools_sub2_WM_contrast_tools_vs_other_tools_sub4'),
#  No_converge(var1='WM_contrast_tools_vs_other_tools_sub2', var2='WM_contrast_faces_vs_other_faces_sub4', out_dir='WM_contrast_tools_vs_other_tools_sub2_WM_contrast_faces_vs_other_faces_sub4'),
#  No_converge(var1='WM_contrast_tools_vs_other_tools_sub3', var2='WM_contrast_places_vs_other_places_sub4', out_dir='WM_contrast_tools_vs_other_tools_sub3_WM_contrast_places_vs_other_places_sub4'),
#  No_converge(var1='WM_contrast_tools_vs_other_tools_sub4', var2='WM_2bk_sub5', out_dir='WM_contrast_tools_vs_other_tools_sub4_WM_2bk_sub5'),
#  No_converge(var1='WM_contrast_tools_vs_other_tools_sub5', var2='WM_2bk_sub4', out_dir='WM_contrast_tools_vs_other_tools_sub5_WM_2bk_sub4'),
#  No_converge(var1='WM_contrast_tools_vs_other_tools_sub5', var2='WM_contrast_2bk_vs_0bk_sub4', out_dir='WM_contrast_tools_vs_other_tools_sub5_WM_contrast_2bk_vs_0bk_sub4'),
#  No_converge(var1='WM_contrast_tools_vs_other_tools_sub5', var2='WM_0bk_sub3', out_dir='WM_contrast_tools_vs_other_tools_sub5_WM_0bk_sub3'),
#  No_converge(var1='WM_contrast_tools_vs_other_tools_sub5', var2='WM_contrast_places_vs_other_places_sub2', out_dir='WM_contrast_tools_vs_other_tools_sub5_WM_contrast_places_vs_other_places_sub2'),
#  No_converge(var1='WM_2bk_sub1', var2='WM_contrast_places_vs_other_places_sub4', out_dir='WM_2bk_sub1_WM_contrast_places_vs_other_places_sub4'),
#  No_converge(var1='WM_2bk_sub1', var2='WM_contrast_faces_vs_other_faces_sub4', out_dir='WM_2bk_sub1_WM_contrast_faces_vs_other_faces_sub4'),
#  No_converge(var1='WM_2bk_sub2', var2='WM_0bk_sub2', out_dir='WM_2bk_sub2_WM_0bk_sub2'),
#  No_converge(var1='WM_2bk_sub3', var2='WM_contrast_tools_vs_other_tools_sub5', out_dir='WM_2bk_sub3_WM_contrast_tools_vs_other_tools_sub5'),
#  No_converge(var1='WM_2bk_sub3', var2='WM_2bk_sub1', out_dir='WM_2bk_sub3_WM_2bk_sub1'),
#  No_converge(var1='WM_2bk_sub3', var2='WM_contrast_places_vs_other_places_sub4', out_dir='WM_2bk_sub3_WM_contrast_places_vs_other_places_sub4'),
#  No_converge(var1='WM_2bk_sub3', var2='WM_contrast_places_vs_other_places_sub5', out_dir='WM_2bk_sub3_WM_contrast_places_vs_other_places_sub5'),
#  No_converge(var1='WM_contrast_2bk_vs_0bk_sub2', var2='REL_match_sub1', out_dir='WM_contrast_2bk_vs_0bk_sub2_REL_match_sub1'),
#  No_converge(var1='WM_contrast_2bk_vs_0bk_sub2', var2='REL_match_sub2', out_dir='WM_contrast_2bk_vs_0bk_sub2_REL_match_sub2'),
#  No_converge(var1='WM_contrast_2bk_vs_0bk_sub2', var2='REL_match_sub5', out_dir='WM_contrast_2bk_vs_0bk_sub2_REL_match_sub5'),
#  No_converge(var1='WM_contrast_2bk_vs_0bk_sub2', var2='REL_relation_sub2', out_dir='WM_contrast_2bk_vs_0bk_sub2_REL_relation_sub2'),
#  No_converge(var1='WM_contrast_2bk_vs_0bk_sub2', var2='REL_relation_sub5', out_dir='WM_contrast_2bk_vs_0bk_sub2_REL_relation_sub5'),
#  No_converge(var1='WM_contrast_2bk_vs_0bk_sub2', var2='WM_contrast_2bk_vs_0bk_sub5', out_dir='WM_contrast_2bk_vs_0bk_sub2_WM_contrast_2bk_vs_0bk_sub5'),
#  No_converge(var1='WM_contrast_2bk_vs_0bk_sub2', var2='LAN_story_sub5', out_dir='WM_contrast_2bk_vs_0bk_sub2_LAN_story_sub5'),
#  No_converge(var1='WM_contrast_2bk_vs_0bk_sub4', var2='REL_match_sub1', out_dir='WM_contrast_2bk_vs_0bk_sub4_REL_match_sub1'),
#  No_converge(var1='WM_contrast_2bk_vs_0bk_sub4', var2='REL_match_sub2', out_dir='WM_contrast_2bk_vs_0bk_sub4_REL_match_sub2'),
#  No_converge(var1='WM_contrast_2bk_vs_0bk_sub4', var2='REL_match_sub5', out_dir='WM_contrast_2bk_vs_0bk_sub4_REL_match_sub5'),
#  No_converge(var1='WM_0bk_sub2', var2='SOC_mental_sub1', out_dir='WM_0bk_sub2_SOC_mental_sub1'),
#  No_converge(var1='WM_0bk_sub2', var2='SOC_mental_sub3', out_dir='WM_0bk_sub2_SOC_mental_sub3'),
#  No_converge(var1='WM_0bk_sub2', var2='GAM_contrast_win_vs_loss_sub1', out_dir='WM_0bk_sub2_GAM_contrast_win_vs_loss_sub1'),
#  No_converge(var1='WM_0bk_sub2', var2='WM_contrast_tools_vs_other_tools_sub2', out_dir='WM_0bk_sub2_WM_contrast_tools_vs_other_tools_sub2'),
#  No_converge(var1='WM_0bk_sub2', var2='WM_contrast_tools_vs_other_tools_sub3', out_dir='WM_0bk_sub2_WM_contrast_tools_vs_other_tools_sub3'),
#  No_converge(var1='WM_0bk_sub2', var2='WM_contrast_2bk_vs_0bk_sub4', out_dir='WM_0bk_sub2_WM_contrast_2bk_vs_0bk_sub4'),
#  No_converge(var1='WM_0bk_sub2', var2='WM_0bk_sub4', out_dir='WM_0bk_sub2_WM_0bk_sub4'),
#  No_converge(var1='WM_0bk_sub2', var2='WM_contrast_places_vs_other_places_sub5', out_dir='WM_0bk_sub2_WM_contrast_places_vs_other_places_sub5'),
#  No_converge(var1='WM_0bk_sub5', var2='LAN_story_sub1', out_dir='WM_0bk_sub5_LAN_story_sub1'),
#  No_converge(var1='WM_0bk_sub5', var2='LAN_story_sub2', out_dir='WM_0bk_sub5_LAN_story_sub2'),
#  No_converge(var1='WM_0bk_sub5', var2='LAN_story_sub5', out_dir='WM_0bk_sub5_LAN_story_sub5'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub1', var2='EMO_contrast_fear_vs_neut_sub1', out_dir='WM_contrast_places_vs_other_places_sub1_EMO_contrast_fear_vs_neut_sub1'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub1', var2='EMO_contrast_fear_vs_neut_sub3', out_dir='WM_contrast_places_vs_other_places_sub1_EMO_contrast_fear_vs_neut_sub3'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub1', var2='EMO_contrast_fear_vs_neut_sub4', out_dir='WM_contrast_places_vs_other_places_sub1_EMO_contrast_fear_vs_neut_sub4'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub1', var2='SOC_mental_sub1', out_dir='WM_contrast_places_vs_other_places_sub1_SOC_mental_sub1'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub1', var2='SOC_mental_sub5', out_dir='WM_contrast_places_vs_other_places_sub1_SOC_mental_sub5'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub1', var2='SOC_contrast_mental_vs_rnd_sub5', out_dir='WM_contrast_places_vs_other_places_sub1_SOC_contrast_mental_vs_rnd_sub5'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub1', var2='REL_match_sub1', out_dir='WM_contrast_places_vs_other_places_sub1_REL_match_sub1'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub1', var2='REL_match_sub2', out_dir='WM_contrast_places_vs_other_places_sub1_REL_match_sub2'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub1', var2='REL_match_sub4', out_dir='WM_contrast_places_vs_other_places_sub1_REL_match_sub4'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub1', var2='REL_match_sub5', out_dir='WM_contrast_places_vs_other_places_sub1_REL_match_sub5'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub1', var2='REL_relation_sub2', out_dir='WM_contrast_places_vs_other_places_sub1_REL_relation_sub2'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub1', var2='REL_relation_sub4', out_dir='WM_contrast_places_vs_other_places_sub1_REL_relation_sub4'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub1', var2='REL_relation_sub5', out_dir='WM_contrast_places_vs_other_places_sub1_REL_relation_sub5'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub1', var2='MOT_rh_sub1', out_dir='WM_contrast_places_vs_other_places_sub1_MOT_rh_sub1'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub1', var2='MOT_rh_sub4', out_dir='WM_contrast_places_vs_other_places_sub1_MOT_rh_sub4'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub1', var2='MOT_t_sub1', out_dir='WM_contrast_places_vs_other_places_sub1_MOT_t_sub1'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub1', var2='WM_contrast_faces_vs_other_faces_sub3', out_dir='WM_contrast_places_vs_other_places_sub1_WM_contrast_faces_vs_other_faces_sub3'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub1', var2='LAN_story_sub1', out_dir='WM_contrast_places_vs_other_places_sub1_LAN_story_sub1'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub1', var2='LAN_story_sub2', out_dir='WM_contrast_places_vs_other_places_sub1_LAN_story_sub2'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub1', var2='LAN_story_sub3', out_dir='WM_contrast_places_vs_other_places_sub1_LAN_story_sub3'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub1', var2='LAN_story_sub5', out_dir='WM_contrast_places_vs_other_places_sub1_LAN_story_sub5'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub2', var2='REL_relation_sub3', out_dir='WM_contrast_places_vs_other_places_sub2_REL_relation_sub3'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub2', var2='MOT_rh_sub3', out_dir='WM_contrast_places_vs_other_places_sub2_MOT_rh_sub3'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub2', var2='MOT_lh_sub4', out_dir='WM_contrast_places_vs_other_places_sub2_MOT_lh_sub4'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub2', var2='WM_contrast_tools_vs_other_tools_sub1', out_dir='WM_contrast_places_vs_other_places_sub2_WM_contrast_tools_vs_other_tools_sub1'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub2', var2='WM_contrast_tools_vs_other_tools_sub3', out_dir='WM_contrast_places_vs_other_places_sub2_WM_contrast_tools_vs_other_tools_sub3'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub2', var2='WM_contrast_tools_vs_other_tools_sub4', out_dir='WM_contrast_places_vs_other_places_sub2_WM_contrast_tools_vs_other_tools_sub4'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub3', var2='WM_contrast_tools_vs_other_tools_sub5', out_dir='WM_contrast_places_vs_other_places_sub3_WM_contrast_tools_vs_other_tools_sub5'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub4', var2='SOC_contrast_mental_vs_rnd_sub2', out_dir='WM_contrast_places_vs_other_places_sub4_SOC_contrast_mental_vs_rnd_sub2'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub4', var2='REL_contrast_relation_vs_match_sub2', out_dir='WM_contrast_places_vs_other_places_sub4_REL_contrast_relation_vs_match_sub2'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub4', var2='WM_contrast_body_vs_other_body_sub2', out_dir='WM_contrast_places_vs_other_places_sub4_WM_contrast_body_vs_other_body_sub2'),
#  No_converge(var1='WM_contrast_places_vs_other_places_sub4', var2='WM_0bk_sub4', out_dir='WM_contrast_places_vs_other_places_sub4_WM_0bk_sub4'),
#  No_converge(var1='WM_contrast_faces_vs_other_faces_sub1', var2='WM_0bk_sub4', out_dir='WM_contrast_faces_vs_other_faces_sub1_WM_0bk_sub4'),
#  No_converge(var1='WM_contrast_faces_vs_other_faces_sub1', var2='WM_contrast_faces_vs_other_faces_sub2', out_dir='WM_contrast_faces_vs_other_faces_sub1_WM_contrast_faces_vs_other_faces_sub2'),
#  No_converge(var1='WM_contrast_faces_vs_other_faces_sub3', var2='EMO_contrast_fear_vs_neut_sub3', out_dir='WM_contrast_faces_vs_other_faces_sub3_EMO_contrast_fear_vs_neut_sub3'),
#  No_converge(var1='WM_contrast_faces_vs_other_faces_sub3', var2='SOC_contrast_mental_vs_rnd_sub5', out_dir='WM_contrast_faces_vs_other_faces_sub3_SOC_contrast_mental_vs_rnd_sub5'),
#  No_converge(var1='WM_contrast_faces_vs_other_faces_sub3', var2='REL_match_sub1', out_dir='WM_contrast_faces_vs_other_faces_sub3_REL_match_sub1'),
#  No_converge(var1='WM_contrast_faces_vs_other_faces_sub3', var2='REL_match_sub2', out_dir='WM_contrast_faces_vs_other_faces_sub3_REL_match_sub2'),
#  No_converge(var1='WM_contrast_faces_vs_other_faces_sub3', var2='REL_match_sub5', out_dir='WM_contrast_faces_vs_other_faces_sub3_REL_match_sub5'),
#  No_converge(var1='WM_contrast_faces_vs_other_faces_sub3', var2='REL_relation_sub2', out_dir='WM_contrast_faces_vs_other_faces_sub3_REL_relation_sub2'),
#  No_converge(var1='WM_contrast_faces_vs_other_faces_sub3', var2='REL_relation_sub4', out_dir='WM_contrast_faces_vs_other_faces_sub3_REL_relation_sub4'),
#  No_converge(var1='WM_contrast_faces_vs_other_faces_sub3', var2='REL_relation_sub5', out_dir='WM_contrast_faces_vs_other_faces_sub3_REL_relation_sub5'),
#  No_converge(var1='WM_contrast_faces_vs_other_faces_sub3', var2='WM_contrast_places_vs_other_places_sub1', out_dir='WM_contrast_faces_vs_other_faces_sub3_WM_contrast_places_vs_other_places_sub1'),
#  No_converge(var1='WM_contrast_faces_vs_other_faces_sub3', var2='LAN_story_sub1', out_dir='WM_contrast_faces_vs_other_faces_sub3_LAN_story_sub1'),
#  No_converge(var1='WM_contrast_faces_vs_other_faces_sub3', var2='LAN_story_sub2', out_dir='WM_contrast_faces_vs_other_faces_sub3_LAN_story_sub2'),
#  No_converge(var1='WM_contrast_faces_vs_other_faces_sub3', var2='LAN_story_sub3', out_dir='WM_contrast_faces_vs_other_faces_sub3_LAN_story_sub3'),
#  No_converge(var1='WM_contrast_faces_vs_other_faces_sub3', var2='LAN_story_sub5', out_dir='WM_contrast_faces_vs_other_faces_sub3_LAN_story_sub5'),
#  No_converge(var1='WM_contrast_faces_vs_other_faces_sub4', var2='WM_2bk_sub3', out_dir='WM_contrast_faces_vs_other_faces_sub4_WM_2bk_sub3'),
#  No_converge(var1='LAN_story_sub1', var2='EMO_contrast_fear_vs_neut_sub3', out_dir='LAN_story_sub1_EMO_contrast_fear_vs_neut_sub3'),
#  No_converge(var1='LAN_story_sub1', var2='SOC_mental_sub1', out_dir='LAN_story_sub1_SOC_mental_sub1'),
#  No_converge(var1='LAN_story_sub1', var2='SOC_mental_sub3', out_dir='LAN_story_sub1_SOC_mental_sub3'),
#  No_converge(var1='LAN_story_sub1', var2='SOC_mental_sub4', out_dir='LAN_story_sub1_SOC_mental_sub4'),
#  No_converge(var1='LAN_story_sub1', var2='SOC_mental_sub5', out_dir='LAN_story_sub1_SOC_mental_sub5'),
#  No_converge(var1='LAN_story_sub1', var2='SOC_contrast_mental_vs_rnd_sub5', out_dir='LAN_story_sub1_SOC_contrast_mental_vs_rnd_sub5'),
#  No_converge(var1='LAN_story_sub1', var2='REL_match_sub1', out_dir='LAN_story_sub1_REL_match_sub1'),
#  No_converge(var1='LAN_story_sub1', var2='REL_match_sub2', out_dir='LAN_story_sub1_REL_match_sub2'),
#  No_converge(var1='LAN_story_sub1', var2='REL_match_sub4', out_dir='LAN_story_sub1_REL_match_sub4'),
#  No_converge(var1='LAN_story_sub1', var2='REL_match_sub5', out_dir='LAN_story_sub1_REL_match_sub5'),
#  No_converge(var1='LAN_story_sub1', var2='REL_relation_sub2', out_dir='LAN_story_sub1_REL_relation_sub2'),
#  No_converge(var1='LAN_story_sub1', var2='REL_relation_sub4', out_dir='LAN_story_sub1_REL_relation_sub4'),
#  No_converge(var1='LAN_story_sub1', var2='REL_relation_sub5', out_dir='LAN_story_sub1_REL_relation_sub5'),
#  No_converge(var1='LAN_story_sub1', var2='MOT_rh_sub1', out_dir='LAN_story_sub1_MOT_rh_sub1'),
#  No_converge(var1='LAN_story_sub1', var2='MOT_rh_sub4', out_dir='LAN_story_sub1_MOT_rh_sub4'),
#  No_converge(var1='LAN_story_sub1', var2='MOT_t_sub1', out_dir='LAN_story_sub1_MOT_t_sub1'),
#  No_converge(var1='LAN_story_sub1', var2='MOT_lh_sub1', out_dir='LAN_story_sub1_MOT_lh_sub1'),
#  No_converge(var1='LAN_story_sub1', var2='WM_0bk_sub5', out_dir='LAN_story_sub1_WM_0bk_sub5'),
#  No_converge(var1='LAN_story_sub1', var2='WM_contrast_places_vs_other_places_sub1', out_dir='LAN_story_sub1_WM_contrast_places_vs_other_places_sub1'),
#  No_converge(var1='LAN_story_sub1', var2='WM_contrast_faces_vs_other_faces_sub3', out_dir='LAN_story_sub1_WM_contrast_faces_vs_other_faces_sub3'),
#  No_converge(var1='LAN_story_sub1', var2='LAN_story_sub2', out_dir='LAN_story_sub1_LAN_story_sub2'),
#  No_converge(var1='LAN_story_sub1', var2='LAN_story_sub3', out_dir='LAN_story_sub1_LAN_story_sub3'),
#  No_converge(var1='LAN_story_sub1', var2='LAN_story_sub4', out_dir='LAN_story_sub1_LAN_story_sub4'),
#  No_converge(var1='LAN_story_sub1', var2='LAN_story_sub5', out_dir='LAN_story_sub1_LAN_story_sub5'),
#  No_converge(var1='LAN_story_sub2', var2='EMO_contrast_fear_vs_neut_sub3', out_dir='LAN_story_sub2_EMO_contrast_fear_vs_neut_sub3'),
#  No_converge(var1='LAN_story_sub2', var2='SOC_mental_sub1', out_dir='LAN_story_sub2_SOC_mental_sub1'),
#  No_converge(var1='LAN_story_sub2', var2='SOC_mental_sub3', out_dir='LAN_story_sub2_SOC_mental_sub3'),
#  No_converge(var1='LAN_story_sub2', var2='SOC_mental_sub4', out_dir='LAN_story_sub2_SOC_mental_sub4'),
#  No_converge(var1='LAN_story_sub2', var2='SOC_mental_sub5', out_dir='LAN_story_sub2_SOC_mental_sub5'),
#  No_converge(var1='LAN_story_sub2', var2='SOC_contrast_mental_vs_rnd_sub5', out_dir='LAN_story_sub2_SOC_contrast_mental_vs_rnd_sub5'),
#  No_converge(var1='LAN_story_sub2', var2='REL_match_sub1', out_dir='LAN_story_sub2_REL_match_sub1'),
#  No_converge(var1='LAN_story_sub2', var2='REL_match_sub2', out_dir='LAN_story_sub2_REL_match_sub2'),
#  No_converge(var1='LAN_story_sub2', var2='REL_match_sub4', out_dir='LAN_story_sub2_REL_match_sub4'),
#  No_converge(var1='LAN_story_sub2', var2='REL_match_sub5', out_dir='LAN_story_sub2_REL_match_sub5'),
#  No_converge(var1='LAN_story_sub2', var2='REL_relation_sub2', out_dir='LAN_story_sub2_REL_relation_sub2'),
#  No_converge(var1='LAN_story_sub2', var2='REL_relation_sub4', out_dir='LAN_story_sub2_REL_relation_sub4'),
#  No_converge(var1='LAN_story_sub2', var2='REL_relation_sub5', out_dir='LAN_story_sub2_REL_relation_sub5'),
#  No_converge(var1='LAN_story_sub2', var2='MOT_rh_sub1', out_dir='LAN_story_sub2_MOT_rh_sub1'),
#  No_converge(var1='LAN_story_sub2', var2='MOT_rh_sub4', out_dir='LAN_story_sub2_MOT_rh_sub4'),
#  No_converge(var1='LAN_story_sub2', var2='MOT_t_sub1', out_dir='LAN_story_sub2_MOT_t_sub1'),
#  No_converge(var1='LAN_story_sub2', var2='MOT_lh_sub1', out_dir='LAN_story_sub2_MOT_lh_sub1'),
#  No_converge(var1='LAN_story_sub2', var2='WM_0bk_sub5', out_dir='LAN_story_sub2_WM_0bk_sub5'),
#  No_converge(var1='LAN_story_sub2', var2='WM_contrast_places_vs_other_places_sub1', out_dir='LAN_story_sub2_WM_contrast_places_vs_other_places_sub1'),
#  No_converge(var1='LAN_story_sub2', var2='WM_contrast_faces_vs_other_faces_sub3', out_dir='LAN_story_sub2_WM_contrast_faces_vs_other_faces_sub3'),
#  No_converge(var1='LAN_story_sub2', var2='LAN_story_sub1', out_dir='LAN_story_sub2_LAN_story_sub1'),
#  No_converge(var1='LAN_story_sub2', var2='LAN_story_sub3', out_dir='LAN_story_sub2_LAN_story_sub3'),
#  No_converge(var1='LAN_story_sub2', var2='LAN_story_sub4', out_dir='LAN_story_sub2_LAN_story_sub4'),
#  No_converge(var1='LAN_story_sub2', var2='LAN_story_sub5', out_dir='LAN_story_sub2_LAN_story_sub5'),
#  No_converge(var1='LAN_story_sub3', var2='EMO_contrast_fear_vs_neut_sub3', out_dir='LAN_story_sub3_EMO_contrast_fear_vs_neut_sub3'),
#  No_converge(var1='LAN_story_sub3', var2='SOC_mental_sub1', out_dir='LAN_story_sub3_SOC_mental_sub1'),
#  No_converge(var1='LAN_story_sub3', var2='SOC_mental_sub3', out_dir='LAN_story_sub3_SOC_mental_sub3'),
#  No_converge(var1='LAN_story_sub3', var2='SOC_mental_sub4', out_dir='LAN_story_sub3_SOC_mental_sub4'),
#  No_converge(var1='LAN_story_sub3', var2='SOC_mental_sub5', out_dir='LAN_story_sub3_SOC_mental_sub5'),
#  No_converge(var1='LAN_story_sub3', var2='SOC_contrast_mental_vs_rnd_sub5', out_dir='LAN_story_sub3_SOC_contrast_mental_vs_rnd_sub5'),
#  No_converge(var1='LAN_story_sub3', var2='REL_match_sub1', out_dir='LAN_story_sub3_REL_match_sub1'),
#  No_converge(var1='LAN_story_sub3', var2='REL_match_sub2', out_dir='LAN_story_sub3_REL_match_sub2'),
#  No_converge(var1='LAN_story_sub3', var2='REL_match_sub4', out_dir='LAN_story_sub3_REL_match_sub4'),
#  No_converge(var1='LAN_story_sub3', var2='REL_match_sub5', out_dir='LAN_story_sub3_REL_match_sub5'),
#  No_converge(var1='LAN_story_sub3', var2='REL_relation_sub2', out_dir='LAN_story_sub3_REL_relation_sub2'),
#  No_converge(var1='LAN_story_sub3', var2='REL_relation_sub4', out_dir='LAN_story_sub3_REL_relation_sub4'),
#  No_converge(var1='LAN_story_sub3', var2='REL_relation_sub5', out_dir='LAN_story_sub3_REL_relation_sub5'),
#  No_converge(var1='LAN_story_sub3', var2='MOT_rh_sub1', out_dir='LAN_story_sub3_MOT_rh_sub1'),
#  No_converge(var1='LAN_story_sub3', var2='MOT_rh_sub4', out_dir='LAN_story_sub3_MOT_rh_sub4'),
#  No_converge(var1='LAN_story_sub3', var2='MOT_t_sub1', out_dir='LAN_story_sub3_MOT_t_sub1'),
#  No_converge(var1='LAN_story_sub3', var2='MOT_lh_sub1', out_dir='LAN_story_sub3_MOT_lh_sub1'),
#  No_converge(var1='LAN_story_sub3', var2='GAM_contrast_win_vs_loss_sub1', out_dir='LAN_story_sub3_GAM_contrast_win_vs_loss_sub1'),
#  No_converge(var1='LAN_story_sub3', var2='WM_contrast_places_vs_other_places_sub1', out_dir='LAN_story_sub3_WM_contrast_places_vs_other_places_sub1'),
#  No_converge(var1='LAN_story_sub3', var2='WM_contrast_faces_vs_other_faces_sub3', out_dir='LAN_story_sub3_WM_contrast_faces_vs_other_faces_sub3'),
#  No_converge(var1='LAN_story_sub3', var2='LAN_story_sub1', out_dir='LAN_story_sub3_LAN_story_sub1'),
#  No_converge(var1='LAN_story_sub3', var2='LAN_story_sub2', out_dir='LAN_story_sub3_LAN_story_sub2'),
#  No_converge(var1='LAN_story_sub3', var2='LAN_story_sub4', out_dir='LAN_story_sub3_LAN_story_sub4'),
#  No_converge(var1='LAN_story_sub3', var2='LAN_story_sub5', out_dir='LAN_story_sub3_LAN_story_sub5'),
#  No_converge(var1='LAN_story_sub4', var2='SOC_mental_sub1', out_dir='LAN_story_sub4_SOC_mental_sub1'),
#  No_converge(var1='LAN_story_sub4', var2='SOC_mental_sub4', out_dir='LAN_story_sub4_SOC_mental_sub4'),
#  No_converge(var1='LAN_story_sub4', var2='REL_match_sub4', out_dir='LAN_story_sub4_REL_match_sub4'),
#  No_converge(var1='LAN_story_sub4', var2='LAN_story_sub1', out_dir='LAN_story_sub4_LAN_story_sub1'),
#  No_converge(var1='LAN_story_sub4', var2='LAN_story_sub2', out_dir='LAN_story_sub4_LAN_story_sub2'),
#  No_converge(var1='LAN_story_sub4', var2='LAN_story_sub3', out_dir='LAN_story_sub4_LAN_story_sub3'),
#  No_converge(var1='LAN_story_sub4', var2='LAN_story_sub5', out_dir='LAN_story_sub4_LAN_story_sub5'),
#  No_converge(var1='LAN_story_sub5', var2='EMO_contrast_fear_vs_neut_sub3', out_dir='LAN_story_sub5_EMO_contrast_fear_vs_neut_sub3'),
#  No_converge(var1='LAN_story_sub5', var2='SOC_mental_sub1', out_dir='LAN_story_sub5_SOC_mental_sub1'),
#  No_converge(var1='LAN_story_sub5', var2='SOC_mental_sub3', out_dir='LAN_story_sub5_SOC_mental_sub3'),
#  No_converge(var1='LAN_story_sub5', var2='SOC_mental_sub4', out_dir='LAN_story_sub5_SOC_mental_sub4'),
#  No_converge(var1='LAN_story_sub5', var2='SOC_mental_sub5', out_dir='LAN_story_sub5_SOC_mental_sub5'),
#  No_converge(var1='LAN_story_sub5', var2='SOC_contrast_mental_vs_rnd_sub5', out_dir='LAN_story_sub5_SOC_contrast_mental_vs_rnd_sub5'),
#  No_converge(var1='LAN_story_sub5', var2='REL_match_sub1', out_dir='LAN_story_sub5_REL_match_sub1'),
#  No_converge(var1='LAN_story_sub5', var2='REL_match_sub2', out_dir='LAN_story_sub5_REL_match_sub2'),
#  No_converge(var1='LAN_story_sub5', var2='REL_match_sub4', out_dir='LAN_story_sub5_REL_match_sub4'),
#  No_converge(var1='LAN_story_sub5', var2='REL_match_sub5', out_dir='LAN_story_sub5_REL_match_sub5'),
#  No_converge(var1='LAN_story_sub5', var2='REL_relation_sub1', out_dir='LAN_story_sub5_REL_relation_sub1'),
#  No_converge(var1='LAN_story_sub5', var2='REL_relation_sub2', out_dir='LAN_story_sub5_REL_relation_sub2'),
#  No_converge(var1='LAN_story_sub5', var2='REL_relation_sub4', out_dir='LAN_story_sub5_REL_relation_sub4'),
#  No_converge(var1='LAN_story_sub5', var2='REL_relation_sub5', out_dir='LAN_story_sub5_REL_relation_sub5'),
#  No_converge(var1='LAN_story_sub5', var2='MOT_rh_sub1', out_dir='LAN_story_sub5_MOT_rh_sub1'),
#  No_converge(var1='LAN_story_sub5', var2='MOT_rh_sub4', out_dir='LAN_story_sub5_MOT_rh_sub4'),
#  No_converge(var1='LAN_story_sub5', var2='MOT_t_sub1', out_dir='LAN_story_sub5_MOT_t_sub1'),
#  No_converge(var1='LAN_story_sub5', var2='MOT_lh_sub1', out_dir='LAN_story_sub5_MOT_lh_sub1'),
#  No_converge(var1='LAN_story_sub5', var2='WM_contrast_2bk_vs_0bk_sub2', out_dir='LAN_story_sub5_WM_contrast_2bk_vs_0bk_sub2'),
#  No_converge(var1='LAN_story_sub5', var2='WM_0bk_sub5', out_dir='LAN_story_sub5_WM_0bk_sub5'),
#  No_converge(var1='LAN_story_sub5', var2='WM_contrast_places_vs_other_places_sub1', out_dir='LAN_story_sub5_WM_contrast_places_vs_other_places_sub1'),
#  No_converge(var1='LAN_story_sub5', var2='WM_contrast_faces_vs_other_faces_sub3', out_dir='LAN_story_sub5_WM_contrast_faces_vs_other_faces_sub3'),
#  No_converge(var1='LAN_story_sub5', var2='LAN_story_sub1', out_dir='LAN_story_sub5_LAN_story_sub1'),
#  No_converge(var1='LAN_story_sub5', var2='LAN_story_sub2', out_dir='LAN_story_sub5_LAN_story_sub2'),
#  No_converge(var1='LAN_story_sub5', var2='LAN_story_sub3', out_dir='LAN_story_sub5_LAN_story_sub3'),
#  No_converge(var1='LAN_story_sub5', var2='LAN_story_sub4', out_dir='LAN_story_sub5_LAN_story_sub4')]

# %%
scientists.append(Scientist(name='Ada Lovelac3', born=1815))

# %%
RohG= np.eye(len(pheno_stack_df.columns.drop('ID')))
RohG_pval_0 = np.eye(len(pheno_stack_df.columns.drop('ID')))
RohG_pval_1 = np.eye(len(pheno_stack_df.columns.drop('ID')))
RohE= np.eye(len(pheno_stack_df.columns.drop('ID')))
RohE_pval = np.eye(len(pheno_stack_df.columns.drop('ID')))
count = 0
No_converge = collections.namedtuple('No_converge', [
    'var1',
    'var2',
    'out_dir'
])
no_converges = []
pedig_f = os.path.join(path_root,'pleio_all_pheno_pedig.csv')
for ix_pheno_1, pheno_1 in enumerate(pheno_stack_df.columns.drop('ID')):
    for ix_pheno_2, pheno_2 in enumerate(pheno_stack_df.columns.drop('ID')):
        if pheno_1  == pheno_2:
            continue
        df_pheno = pheno_stack_df[['ID',pheno_1,pheno_2]]
        cov_1 = '{}_FD_scrubbed_mean'.format(pheno_1.split('_')[0])
        cov_2 = '{}_FD_scrubbed_mean'.format(pheno_2.split('_')[0])
        df_cov = cov_stack_FD_df[['ID',cov_1,cov_2]]
        pheno_cov_stack = [df_pheno,df_cov,cov_stack_stand_df]
        # merge pheno cov
        pheno_cov_df = functools.reduce(lambda left,right: pd.merge(left,right,on='ID',how='inner'), 
                                        pheno_cov_stack)
        # save it
        pheno_cov_df.to_csv(os.path.join(path_root,'pheno_cov_tmp.csv'),index=False)
        pheno_f= os.path.join(path_root,'pheno_cov_tmp.csv')
        #run pleio script
        out_dir = '{}_{}'.format(pheno_1,pheno_2)
#         subp.run(['bash', os.path.join(path_root,'pleio_run.sh'),
#                   out_dir,pedig_f,pheno_f,pheno_1,pheno_2,cov_1,cov_2])
        
        # collect result from log file
        #number_lines = sum(1 for line in open(os.path.join(path_root,out_dir,'solar_pleio.out')))
        fp = open(os.path.join(path_root,out_dir,'solar_pleio.out'))
        for i,line in enumerate(fp):
            if 'CONVERGENCE FAILURE' in line:
                print(out_dir)
                print(line)
                count+=1
                no_converges.append(No_converge(var1 = pheno_1,var2 = pheno_2,out_dir = out_dir ))
                break
            if 'RhoE is ' in line:
                RohE[ix_pheno_1,ix_pheno_2] = float(line.strip('\n').split(' ')[3])
                RohE_pval[ix_pheno_1,ix_pheno_2] = float(line.strip('\n').split(' ')[-1])
            if 'RhoG is ' in line:
                RohG[ix_pheno_1,ix_pheno_2] = float(line.strip('\n').split(' ')[-1])
                #print(out_dir)
                #print(line.strip('\t ').strip('\n'))
            if 'RhoG different from zero' in line:
                RohG_pval_0[ix_pheno_1,ix_pheno_2] = float(line.strip('\n').split(' ')[-1])
                #print(line.strip('\t '))
            if 'RhoG different from -1.0' in line:
                RohG_pval_1[ix_pheno_1,ix_pheno_2] = float(line.strip('\n').split(' ')[-1])
                break
            elif 'RhoG different from 1.0' in line:
                RohG_pval_1[ix_pheno_1,ix_pheno_2] = float(line.strip('\n').split(' ')[-1])
                break
# Out:
# EMO_contrast_fear_vs_neut_sub1_EMO_contrast_fear_vs_neut_sub3
# CONVERGENCE FAILURE
#
# EMO_contrast_fear_vs_neut_sub1_WM_contrast_places_vs_other_places_sub1
# CONVERGENCE FAILURE
#
# EMO_contrast_fear_vs_neut_sub3_EMO_contrast_fear_vs_neut_sub1
# CONVERGENCE FAILURE
#
# EMO_contrast_fear_vs_neut_sub3_EMO_contrast_fear_vs_neut_sub4
# CONVERGENCE FAILURE
#
# EMO_contrast_fear_vs_neut_sub3_SOC_contrast_mental_vs_rnd_sub5
# CONVERGENCE FAILURE
#
# EMO_contrast_fear_vs_neut_sub3_MOT_rh_sub1
# CONVERGENCE FAILURE
#
# EMO_contrast_fear_vs_neut_sub3_MOT_rh_sub4
# CONVERGENCE FAILURE
#
# EMO_contrast_fear_vs_neut_sub3_MOT_lh_sub1
# CONVERGENCE FAILURE
#
# EMO_contrast_fear_vs_neut_sub3_WM_contrast_places_vs_other_places_sub1
# CONVERGENCE FAILURE
#
# EMO_contrast_fear_vs_neut_sub3_WM_contrast_places_vs_other_places_sub2
# CONVERGENCE FAILURE
#
# EMO_contrast_fear_vs_neut_sub3_WM_contrast_faces_vs_other_faces_sub3
# CONVERGENCE FAILURE
#
# EMO_contrast_fear_vs_neut_sub3_LAN_story_sub1
# CONVERGENCE FAILURE
#
# EMO_contrast_fear_vs_neut_sub3_LAN_story_sub2
# CONVERGENCE FAILURE
#
# EMO_contrast_fear_vs_neut_sub3_LAN_story_sub3
# CONVERGENCE FAILURE
#
# EMO_contrast_fear_vs_neut_sub3_LAN_story_sub5
# CONVERGENCE FAILURE
#
# EMO_contrast_fear_vs_neut_sub4_EMO_contrast_fear_vs_neut_sub3
# CONVERGENCE FAILURE
#
# EMO_contrast_fear_vs_neut_sub4_WM_contrast_places_vs_other_places_sub1
# CONVERGENCE FAILURE
#
# SOC_mental_sub1_SOC_mental_sub4
# CONVERGENCE FAILURE
#
# SOC_mental_sub1_REL_match_sub1
# CONVERGENCE FAILURE
#
# SOC_mental_sub1_REL_match_sub2
# CONVERGENCE FAILURE
#
# SOC_mental_sub1_REL_match_sub4
# CONVERGENCE FAILURE
#
# SOC_mental_sub1_REL_match_sub5
# CONVERGENCE FAILURE
#
# SOC_mental_sub1_REL_relation_sub2
# CONVERGENCE FAILURE
#
# SOC_mental_sub1_REL_relation_sub4
# CONVERGENCE FAILURE
#
# SOC_mental_sub1_REL_relation_sub5
# CONVERGENCE FAILURE
#
# SOC_mental_sub1_WM_contrast_places_vs_other_places_sub1
# CONVERGENCE FAILURE
#
# SOC_mental_sub1_WM_contrast_places_vs_other_places_sub4
# CONVERGENCE FAILURE
#
# SOC_mental_sub1_LAN_story_sub1
# CONVERGENCE FAILURE
#
# SOC_mental_sub1_LAN_story_sub2
# CONVERGENCE FAILURE
#
# SOC_mental_sub1_LAN_story_sub3
# CONVERGENCE FAILURE
#
# SOC_mental_sub1_LAN_story_sub4
# CONVERGENCE FAILURE
#
# SOC_mental_sub1_LAN_story_sub5
# CONVERGENCE FAILURE
#
# SOC_mental_sub3_LAN_story_sub1
# CONVERGENCE FAILURE
#
# SOC_mental_sub3_LAN_story_sub2
# CONVERGENCE FAILURE
#
# SOC_mental_sub3_LAN_story_sub3
# CONVERGENCE FAILURE
#
# SOC_mental_sub3_LAN_story_sub5
# CONVERGENCE FAILURE
#
# SOC_mental_sub4_SOC_mental_sub1
# CONVERGENCE FAILURE
#
# SOC_mental_sub4_REL_match_sub1
# CONVERGENCE FAILURE
#
# SOC_mental_sub4_REL_match_sub2
# CONVERGENCE FAILURE
#
# SOC_mental_sub4_REL_match_sub4
# CONVERGENCE FAILURE
#
# SOC_mental_sub4_REL_match_sub5
# CONVERGENCE FAILURE
#
# SOC_mental_sub4_REL_relation_sub2
# CONVERGENCE FAILURE
#
# SOC_mental_sub4_REL_relation_sub5
# CONVERGENCE FAILURE
#
# SOC_mental_sub4_LAN_story_sub1
# CONVERGENCE FAILURE
#
# SOC_mental_sub4_LAN_story_sub2
# CONVERGENCE FAILURE
#
# SOC_mental_sub4_LAN_story_sub3
# CONVERGENCE FAILURE
#
# SOC_mental_sub4_LAN_story_sub4
# CONVERGENCE FAILURE
#
# SOC_mental_sub4_LAN_story_sub5
# CONVERGENCE FAILURE
#
# SOC_mental_sub5_WM_0bk_sub2
# CONVERGENCE FAILURE
#
# SOC_mental_sub5_WM_contrast_places_vs_other_places_sub1
# CONVERGENCE FAILURE
#
# SOC_mental_sub5_LAN_story_sub1
# CONVERGENCE FAILURE
#
# SOC_mental_sub5_LAN_story_sub2
# CONVERGENCE FAILURE
#
# SOC_mental_sub5_LAN_story_sub3
# CONVERGENCE FAILURE
#
# SOC_mental_sub5_LAN_story_sub5
# CONVERGENCE FAILURE
#
# SOC_contrast_mental_vs_rnd_sub5_EMO_contrast_fear_vs_neut_sub3
# CONVERGENCE FAILURE
#
# SOC_contrast_mental_vs_rnd_sub5_WM_contrast_places_vs_other_places_sub1
# CONVERGENCE FAILURE
#
# SOC_contrast_mental_vs_rnd_sub5_WM_contrast_faces_vs_other_faces_sub3
# CONVERGENCE FAILURE
#
# SOC_contrast_mental_vs_rnd_sub5_LAN_story_sub1
# CONVERGENCE FAILURE
#
# SOC_contrast_mental_vs_rnd_sub5_LAN_story_sub2
# CONVERGENCE FAILURE
#
# SOC_contrast_mental_vs_rnd_sub5_LAN_story_sub3
# CONVERGENCE FAILURE
#
# SOC_contrast_mental_vs_rnd_sub5_LAN_story_sub5
# CONVERGENCE FAILURE
#
# REL_match_sub1_SOC_mental_sub1
# CONVERGENCE FAILURE
#
# REL_match_sub1_SOC_mental_sub4
# CONVERGENCE FAILURE
#
# REL_match_sub1_REL_match_sub2
# CONVERGENCE FAILURE
#
# REL_match_sub1_REL_match_sub4
# CONVERGENCE FAILURE
#
# REL_match_sub1_REL_match_sub5
# CONVERGENCE FAILURE
#
# REL_match_sub1_REL_relation_sub2
# CONVERGENCE FAILURE
#
# REL_match_sub1_REL_relation_sub4
# CONVERGENCE FAILURE
#
# REL_match_sub1_REL_relation_sub5
# CONVERGENCE FAILURE
#
# REL_match_sub1_MOT_rf_sub1
# CONVERGENCE FAILURE
#
# REL_match_sub1_MOT_t_sub1
# CONVERGENCE FAILURE
#
# REL_match_sub1_WM_contrast_2bk_vs_0bk_sub2
# CONVERGENCE FAILURE
#
# REL_match_sub1_WM_contrast_2bk_vs_0bk_sub4
# CONVERGENCE FAILURE
#
# REL_match_sub1_WM_contrast_places_vs_other_places_sub1
# CONVERGENCE FAILURE
#
# REL_match_sub1_WM_contrast_faces_vs_other_faces_sub3
# CONVERGENCE FAILURE
#
# REL_match_sub1_LAN_story_sub1
# CONVERGENCE FAILURE
#
# REL_match_sub1_LAN_story_sub2
# CONVERGENCE FAILURE
#
# REL_match_sub1_LAN_story_sub3
# CONVERGENCE FAILURE
#
# REL_match_sub1_LAN_story_sub5
# CONVERGENCE FAILURE
#
# REL_match_sub2_SOC_mental_sub1
# CONVERGENCE FAILURE
#
# REL_match_sub2_SOC_mental_sub4
# CONVERGENCE FAILURE
#
# REL_match_sub2_REL_match_sub1
# CONVERGENCE FAILURE
#
# REL_match_sub2_REL_match_sub4
# CONVERGENCE FAILURE
#
# REL_match_sub2_REL_relation_sub2
# CONVERGENCE FAILURE
#
# REL_match_sub2_REL_relation_sub4
# CONVERGENCE FAILURE
#
# REL_match_sub2_REL_relation_sub5
# CONVERGENCE FAILURE
#
# REL_match_sub2_MOT_rf_sub1
# CONVERGENCE FAILURE
#
# REL_match_sub2_MOT_t_sub1
# CONVERGENCE FAILURE
#
# REL_match_sub2_WM_contrast_2bk_vs_0bk_sub2
# CONVERGENCE FAILURE
#
# REL_match_sub2_WM_contrast_2bk_vs_0bk_sub4
# CONVERGENCE FAILURE
#
# REL_match_sub2_WM_contrast_places_vs_other_places_sub1
# CONVERGENCE FAILURE
#
# REL_match_sub2_WM_contrast_places_vs_other_places_sub4
# CONVERGENCE FAILURE
#
# REL_match_sub2_WM_contrast_faces_vs_other_faces_sub3
# CONVERGENCE FAILURE
#
# REL_match_sub2_LAN_story_sub1
# CONVERGENCE FAILURE
#
# REL_match_sub2_LAN_story_sub2
# CONVERGENCE FAILURE
#
# REL_match_sub2_LAN_story_sub3
# CONVERGENCE FAILURE
#
# REL_match_sub2_LAN_story_sub5
# CONVERGENCE FAILURE
#
# REL_match_sub4_SOC_mental_sub1
# CONVERGENCE FAILURE
#
# REL_match_sub4_SOC_mental_sub4
# CONVERGENCE FAILURE
#
# REL_match_sub4_REL_match_sub1
# CONVERGENCE FAILURE
#
# REL_match_sub4_REL_match_sub2
# CONVERGENCE FAILURE
#
# REL_match_sub4_REL_match_sub5
# CONVERGENCE FAILURE
#
# REL_match_sub4_REL_relation_sub2
# CONVERGENCE FAILURE
#
# REL_match_sub4_REL_relation_sub4
# CONVERGENCE FAILURE
#
# REL_match_sub4_REL_relation_sub5
# CONVERGENCE FAILURE
#
# REL_match_sub4_WM_contrast_places_vs_other_places_sub1
# CONVERGENCE FAILURE
#
# REL_match_sub4_LAN_story_sub1
# CONVERGENCE FAILURE
#
# REL_match_sub4_LAN_story_sub2
# CONVERGENCE FAILURE
#
# REL_match_sub4_LAN_story_sub3
# CONVERGENCE FAILURE
#
# REL_match_sub4_LAN_story_sub4
# CONVERGENCE FAILURE
#
# REL_match_sub4_LAN_story_sub5
# CONVERGENCE FAILURE
#
# REL_match_sub5_SOC_mental_sub1
# CONVERGENCE FAILURE
#
# REL_match_sub5_SOC_mental_sub4
# CONVERGENCE FAILURE
#
# REL_match_sub5_REL_match_sub1
# CONVERGENCE FAILURE
#
# REL_match_sub5_REL_match_sub4
# CONVERGENCE FAILURE
#
# REL_match_sub5_REL_relation_sub2
# CONVERGENCE FAILURE
#
# REL_match_sub5_REL_relation_sub4
# CONVERGENCE FAILURE
#
# REL_match_sub5_REL_relation_sub5
# CONVERGENCE FAILURE
#
# REL_match_sub5_MOT_rf_sub1
# CONVERGENCE FAILURE
#
# REL_match_sub5_MOT_rf_sub3
# CONVERGENCE FAILURE
#
# REL_match_sub5_MOT_t_sub1
# CONVERGENCE FAILURE
#
# REL_match_sub5_WM_contrast_2bk_vs_0bk_sub2
# CONVERGENCE FAILURE
#
# REL_match_sub5_WM_contrast_2bk_vs_0bk_sub4
# CONVERGENCE FAILURE
#
# REL_match_sub5_WM_contrast_places_vs_other_places_sub1
# CONVERGENCE FAILURE
#
# REL_match_sub5_WM_contrast_faces_vs_other_faces_sub3
# CONVERGENCE FAILURE
#
# REL_match_sub5_LAN_story_sub1
# CONVERGENCE FAILURE
#
# REL_match_sub5_LAN_story_sub2
# CONVERGENCE FAILURE
#
# REL_match_sub5_LAN_story_sub3
# CONVERGENCE FAILURE
#
# REL_match_sub5_LAN_story_sub5
# CONVERGENCE FAILURE
#
# REL_relation_sub1_LAN_story_sub5
# CONVERGENCE FAILURE
#
# REL_relation_sub2_SOC_mental_sub1
# CONVERGENCE FAILURE
#
# REL_relation_sub2_SOC_mental_sub4
# CONVERGENCE FAILURE
#
# REL_relation_sub2_REL_match_sub1
# CONVERGENCE FAILURE
#
# REL_relation_sub2_REL_match_sub2
# CONVERGENCE FAILURE
#
# REL_relation_sub2_REL_match_sub4
# CONVERGENCE FAILURE
#
# REL_relation_sub2_REL_match_sub5
# CONVERGENCE FAILURE
#
# REL_relation_sub2_REL_relation_sub4
# CONVERGENCE FAILURE
#
# REL_relation_sub2_REL_relation_sub5
# CONVERGENCE FAILURE
#
# REL_relation_sub2_MOT_rh_sub1
# CONVERGENCE FAILURE
#
# REL_relation_sub2_MOT_rh_sub4
# CONVERGENCE FAILURE
#
# REL_relation_sub2_MOT_rf_sub1
# CONVERGENCE FAILURE
#
# REL_relation_sub2_MOT_rf_sub3
# CONVERGENCE FAILURE
#
# REL_relation_sub2_MOT_lf_sub1
# CONVERGENCE FAILURE
# REL_relation_sub2_MOT_lh_sub1
# CONVERGENCE FAILURE
#
# REL_relation_sub2_WM_contrast_2bk_vs_0bk_sub2
# CONVERGENCE FAILURE
#
# REL_relation_sub2_WM_contrast_places_vs_other_places_sub1
# CONVERGENCE FAILURE
#
# REL_relation_sub2_WM_contrast_faces_vs_other_faces_sub3
# CONVERGENCE FAILURE
#
# REL_relation_sub2_LAN_story_sub1
# CONVERGENCE FAILURE
#
# REL_relation_sub2_LAN_story_sub2
# CONVERGENCE FAILURE
#
# REL_relation_sub2_LAN_story_sub3
# CONVERGENCE FAILURE
#
# REL_relation_sub2_LAN_story_sub5
# CONVERGENCE FAILURE
#
# REL_relation_sub3_REL_contrast_relation_vs_match_sub3
# CONVERGENCE FAILURE
#
# REL_relation_sub4_SOC_mental_sub1
# CONVERGENCE FAILURE
#
# REL_relation_sub4_REL_match_sub1
# CONVERGENCE FAILURE
#
# REL_relation_sub4_REL_match_sub2
# CONVERGENCE FAILURE
#
# REL_relation_sub4_REL_match_sub4
# CONVERGENCE FAILURE
#
# REL_relation_sub4_REL_match_sub5
# CONVERGENCE FAILURE
#
# REL_relation_sub4_REL_relation_sub2
# CONVERGENCE FAILURE
#
# REL_relation_sub4_REL_relation_sub5
# CONVERGENCE FAILURE
#
# REL_relation_sub4_MOT_rh_sub1
# CONVERGENCE FAILURE
#
# REL_relation_sub4_MOT_rh_sub4
# CONVERGENCE FAILURE
#
# REL_relation_sub4_MOT_rf_sub1
# CONVERGENCE FAILURE
#
# REL_relation_sub4_WM_contrast_places_vs_other_places_sub1
# CONVERGENCE FAILURE
#
# REL_relation_sub4_WM_contrast_faces_vs_other_faces_sub3
# CONVERGENCE FAILURE
#
# REL_relation_sub4_LAN_story_sub1
# CONVERGENCE FAILURE
#
# REL_relation_sub4_LAN_story_sub2
# CONVERGENCE FAILURE
#
# REL_relation_sub4_LAN_story_sub3
# CONVERGENCE FAILURE
#
# REL_relation_sub4_LAN_story_sub5
# CONVERGENCE FAILURE
#
# REL_relation_sub5_SOC_mental_sub1
# CONVERGENCE FAILURE
#
# REL_relation_sub5_SOC_mental_sub4
# CONVERGENCE FAILURE
#
# REL_relation_sub5_REL_match_sub1
# CONVERGENCE FAILURE
#
# REL_relation_sub5_REL_match_sub2
# CONVERGENCE FAILURE
#
# REL_relation_sub5_REL_match_sub4
# CONVERGENCE FAILURE
#
# REL_relation_sub5_REL_match_sub5
# CONVERGENCE FAILURE
#
# REL_relation_sub5_REL_relation_sub2
# CONVERGENCE FAILURE
#
# REL_relation_sub5_REL_relation_sub4
# CONVERGENCE FAILURE
#
# REL_relation_sub5_MOT_rh_sub1
# CONVERGENCE FAILURE
#
# REL_relation_sub5_MOT_rh_sub4
# CONVERGENCE FAILURE
#
# REL_relation_sub5_MOT_rf_sub1
# CONVERGENCE FAILURE
#
# REL_relation_sub5_MOT_rf_sub3
# CONVERGENCE FAILURE
#
# REL_relation_sub5_MOT_lf_sub1
# CONVERGENCE FAILURE
#
# REL_relation_sub5_MOT_lh_sub1
# CONVERGENCE FAILURE
#
# REL_relation_sub5_WM_contrast_2bk_vs_0bk_sub2
# CONVERGENCE FAILURE
#
# REL_relation_sub5_WM_contrast_places_vs_other_places_sub1
# CONVERGENCE FAILURE
#
# REL_relation_sub5_WM_contrast_faces_vs_other_faces_sub3
# CONVERGENCE FAILURE
#
# REL_relation_sub5_LAN_story_sub1
# CONVERGENCE FAILURE
#
# REL_relation_sub5_LAN_story_sub2
# CONVERGENCE FAILURE
#
# REL_relation_sub5_LAN_story_sub3
# CONVERGENCE FAILURE
#
# REL_relation_sub5_LAN_story_sub5
# CONVERGENCE FAILURE
#
# REL_contrast_relation_vs_match_sub1_WM_contrast_places_vs_other_places_sub2
# CONVERGENCE FAILURE
#
# MOT_rh_sub1_EMO_contrast_fear_vs_neut_sub3
# CONVERGENCE FAILURE
#
# MOT_rh_sub1_REL_relation_sub2
# CONVERGENCE FAILURE
#
# MOT_rh_sub1_REL_relation_sub4
# CONVERGENCE FAILURE
#
# MOT_rh_sub1_REL_relation_sub5
# CONVERGENCE FAILURE
#
# MOT_rh_sub1_MOT_rh_sub4
# CONVERGENCE FAILURE
#
# MOT_rh_sub1_MOT_t_sub1
# CONVERGENCE FAILURE
#
# MOT_rh_sub1_MOT_lh_sub1
# CONVERGENCE FAILURE
#
# MOT_rh_sub1_WM_contrast_places_vs_other_places_sub1
# CONVERGENCE FAILURE
#
# MOT_rh_sub1_LAN_story_sub1
# CONVERGENCE FAILURE
#
# MOT_rh_sub1_LAN_story_sub2
# CONVERGENCE FAILURE
#
# MOT_rh_sub1_LAN_story_sub3
# CONVERGENCE FAILURE
#
# MOT_rh_sub1_LAN_story_sub5
# CONVERGENCE FAILURE
#
# MOT_rh_sub4_EMO_contrast_fear_vs_neut_sub3
# CONVERGENCE FAILURE
#
# MOT_rh_sub4_REL_relation_sub2
# CONVERGENCE FAILURE
#
# MOT_rh_sub4_REL_relation_sub4
# CONVERGENCE FAILURE
#
# MOT_rh_sub4_REL_relation_sub5
# CONVERGENCE FAILURE
#
# MOT_rh_sub4_MOT_rh_sub1
# CONVERGENCE FAILURE
#
# MOT_rh_sub4_MOT_lh_sub1
# CONVERGENCE FAILURE
#
# MOT_rh_sub4_MOT_lh_sub4
# CONVERGENCE FAILURE
#
# MOT_rh_sub4_WM_contrast_tools_vs_other_tools_sub5
# CONVERGENCE FAILURE
#
# MOT_rh_sub4_WM_contrast_places_vs_other_places_sub1
# CONVERGENCE FAILURE
#
# MOT_rh_sub4_WM_contrast_faces_vs_other_faces_sub4
# CONVERGENCE FAILURE
#
# MOT_rh_sub4_LAN_story_sub1
# CONVERGENCE FAILURE
#
# MOT_rh_sub4_LAN_story_sub2
# CONVERGENCE FAILURE
#
# MOT_rh_sub4_LAN_story_sub3
# CONVERGENCE FAILURE
#
# MOT_rh_sub4_LAN_story_sub5
# CONVERGENCE FAILURE
#
# MOT_rh_sub5_WM_contrast_faces_vs_other_faces_sub4
# CONVERGENCE FAILURE
#
# MOT_rf_sub1_REL_match_sub1
# CONVERGENCE FAILURE
#
# MOT_rf_sub1_REL_match_sub2
# CONVERGENCE FAILURE
#
# MOT_rf_sub1_REL_match_sub5
# CONVERGENCE FAILURE
#
# MOT_rf_sub1_REL_relation_sub2
# CONVERGENCE FAILURE
#
# MOT_rf_sub1_REL_relation_sub4
# CONVERGENCE FAILURE
#
# MOT_rf_sub1_REL_relation_sub5
# CONVERGENCE FAILURE
#
# MOT_rf_sub3_REL_match_sub5
# CONVERGENCE FAILURE
#
# MOT_rf_sub3_REL_relation_sub2
# CONVERGENCE FAILURE
#
# MOT_rf_sub3_REL_relation_sub5
# CONVERGENCE FAILURE
#
# MOT_rf_sub3_WM_contrast_faces_vs_other_faces_sub4
# CONVERGENCE FAILURE
#
# MOT_t_sub1_REL_match_sub1
# CONVERGENCE FAILURE
#
# MOT_t_sub1_REL_match_sub2
# CONVERGENCE FAILURE
#
# MOT_t_sub1_REL_match_sub5
# CONVERGENCE FAILURE
#
# MOT_t_sub1_MOT_rh_sub1
# CONVERGENCE FAILURE
#
# MOT_t_sub1_WM_contrast_places_vs_other_places_sub1
# CONVERGENCE FAILURE
#
# MOT_t_sub1_LAN_story_sub1
# CONVERGENCE FAILURE
#
# MOT_t_sub1_LAN_story_sub2
# CONVERGENCE FAILURE
#
# MOT_t_sub1_LAN_story_sub3
# CONVERGENCE FAILURE
#
# MOT_t_sub1_LAN_story_sub5
# CONVERGENCE FAILURE
#
# MOT_lf_sub1_REL_relation_sub2
# CONVERGENCE FAILURE
#
# MOT_lf_sub1_REL_relation_sub5
# CONVERGENCE FAILURE
#
# MOT_lh_sub1_EMO_contrast_fear_vs_neut_sub3
# CONVERGENCE FAILURE
#
# MOT_lh_sub1_REL_relation_sub2
# CONVERGENCE FAILURE
#
# MOT_lh_sub1_REL_relation_sub5
# CONVERGENCE FAILURE
#
# MOT_lh_sub1_MOT_rh_sub1
# CONVERGENCE FAILURE
#
# MOT_lh_sub1_MOT_rh_sub4
# CONVERGENCE FAILURE
#
# MOT_lh_sub1_WM_contrast_places_vs_other_places_sub2
# CONVERGENCE FAILURE
#
# MOT_lh_sub1_LAN_story_sub1
# CONVERGENCE FAILURE
#
# MOT_lh_sub1_LAN_story_sub2
# CONVERGENCE FAILURE
#
# MOT_lh_sub1_LAN_story_sub3
# CONVERGENCE FAILURE
#
# MOT_lh_sub1_LAN_story_sub5
# CONVERGENCE FAILURE
#
# MOT_lh_sub4_MOT_rh_sub4
# CONVERGENCE FAILURE
#
# GAM_contrast_win_vs_loss_sub2_GAM_win_sub1
# CONVERGENCE FAILURE
#
# GAM_loss_sub1_WM_contrast_places_vs_other_places_sub4
# CONVERGENCE FAILURE
#
# GAM_win_sub4_WM_0bk_sub2
# CONVERGENCE FAILURE
#
# WM_contrast_tools_vs_other_tools_sub1_WM_2bk_sub1
# CONVERGENCE FAILURE
#
# WM_contrast_tools_vs_other_tools_sub2_WM_contrast_tools_vs_other_tools_sub4
# CONVERGENCE FAILURE
#
# WM_contrast_tools_vs_other_tools_sub2_WM_contrast_faces_vs_other_faces_sub4
# CONVERGENCE FAILURE
#
# WM_contrast_tools_vs_other_tools_sub3_WM_contrast_places_vs_other_places_sub4
# CONVERGENCE FAILURE
#
# WM_contrast_tools_vs_other_tools_sub4_WM_2bk_sub5
# CONVERGENCE FAILURE
#
# WM_contrast_tools_vs_other_tools_sub5_WM_2bk_sub4
# CONVERGENCE FAILURE
#
# WM_contrast_tools_vs_other_tools_sub5_WM_contrast_2bk_vs_0bk_sub4
# CONVERGENCE FAILURE
#
# WM_contrast_tools_vs_other_tools_sub5_WM_0bk_sub3
# CONVERGENCE FAILURE
#
# WM_contrast_tools_vs_other_tools_sub5_WM_contrast_places_vs_other_places_sub2
# CONVERGENCE FAILURE
#
# WM_2bk_sub1_WM_contrast_places_vs_other_places_sub4
# CONVERGENCE FAILURE
#
# WM_2bk_sub1_WM_contrast_faces_vs_other_faces_sub4
# CONVERGENCE FAILURE
#
# WM_2bk_sub2_WM_0bk_sub2
# CONVERGENCE FAILURE
#
# WM_2bk_sub3_WM_contrast_tools_vs_other_tools_sub5
# CONVERGENCE FAILURE
#
# WM_2bk_sub3_WM_2bk_sub1
# CONVERGENCE FAILURE
#
# WM_2bk_sub3_WM_contrast_places_vs_other_places_sub4
# CONVERGENCE FAILURE
#
# WM_2bk_sub3_WM_contrast_places_vs_other_places_sub5
# CONVERGENCE FAILURE
#
# WM_contrast_2bk_vs_0bk_sub2_REL_match_sub1
# CONVERGENCE FAILURE
#
# WM_contrast_2bk_vs_0bk_sub2_REL_match_sub2
# CONVERGENCE FAILURE
#
# WM_contrast_2bk_vs_0bk_sub2_REL_match_sub5
# CONVERGENCE FAILURE
#
# WM_contrast_2bk_vs_0bk_sub2_REL_relation_sub2
# CONVERGENCE FAILURE
#
# WM_contrast_2bk_vs_0bk_sub2_REL_relation_sub5
# CONVERGENCE FAILURE
#
# WM_contrast_2bk_vs_0bk_sub2_WM_contrast_2bk_vs_0bk_sub5
# CONVERGENCE FAILURE
#
# WM_contrast_2bk_vs_0bk_sub2_LAN_story_sub5
# CONVERGENCE FAILURE
#
# WM_contrast_2bk_vs_0bk_sub4_REL_match_sub1
# CONVERGENCE FAILURE
#
# WM_contrast_2bk_vs_0bk_sub4_REL_match_sub2
# CONVERGENCE FAILURE
#
# WM_contrast_2bk_vs_0bk_sub4_REL_match_sub5
# CONVERGENCE FAILURE
#
# WM_0bk_sub2_SOC_mental_sub1
# CONVERGENCE FAILURE
#
# WM_0bk_sub2_SOC_mental_sub3
# CONVERGENCE FAILURE
#
# WM_0bk_sub2_GAM_contrast_win_vs_loss_sub1
# CONVERGENCE FAILURE
#
# WM_0bk_sub2_WM_contrast_tools_vs_other_tools_sub2
# CONVERGENCE FAILURE
#
# WM_0bk_sub2_WM_contrast_tools_vs_other_tools_sub3
# CONVERGENCE FAILURE
#
# WM_0bk_sub2_WM_contrast_2bk_vs_0bk_sub4
# CONVERGENCE FAILURE
#
# WM_0bk_sub2_WM_0bk_sub4
# CONVERGENCE FAILURE
#
# WM_0bk_sub2_WM_contrast_places_vs_other_places_sub5
# CONVERGENCE FAILURE
# WM_0bk_sub5_LAN_story_sub1
# CONVERGENCE FAILURE
#
# WM_0bk_sub5_LAN_story_sub2
# CONVERGENCE FAILURE
#
# WM_0bk_sub5_LAN_story_sub5
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub1_EMO_contrast_fear_vs_neut_sub1
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub1_EMO_contrast_fear_vs_neut_sub3
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub1_EMO_contrast_fear_vs_neut_sub4
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub1_SOC_mental_sub1
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub1_SOC_mental_sub5
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub1_SOC_contrast_mental_vs_rnd_sub5
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub1_REL_match_sub1
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub1_REL_match_sub2
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub1_REL_match_sub4
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub1_REL_match_sub5
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub1_REL_relation_sub2
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub1_REL_relation_sub4
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub1_REL_relation_sub5
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub1_MOT_rh_sub1
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub1_MOT_rh_sub4
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub1_MOT_t_sub1
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub1_WM_contrast_faces_vs_other_faces_sub3
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub1_LAN_story_sub1
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub1_LAN_story_sub2
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub1_LAN_story_sub3
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub1_LAN_story_sub5
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub2_REL_relation_sub3
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub2_MOT_rh_sub3
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub2_MOT_lh_sub4
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub2_WM_contrast_tools_vs_other_tools_sub1
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub2_WM_contrast_tools_vs_other_tools_sub3
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub2_WM_contrast_tools_vs_other_tools_sub4
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub3_WM_contrast_tools_vs_other_tools_sub5
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub4_SOC_contrast_mental_vs_rnd_sub2
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub4_REL_contrast_relation_vs_match_sub2
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub4_WM_contrast_body_vs_other_body_sub2
# CONVERGENCE FAILURE
#
# WM_contrast_places_vs_other_places_sub4_WM_0bk_sub4
# CONVERGENCE FAILURE
#
# WM_contrast_faces_vs_other_faces_sub1_WM_0bk_sub4
# CONVERGENCE FAILURE
#
# WM_contrast_faces_vs_other_faces_sub1_WM_contrast_faces_vs_other_faces_sub2
# CONVERGENCE FAILURE
#
# WM_contrast_faces_vs_other_faces_sub3_EMO_contrast_fear_vs_neut_sub3
# CONVERGENCE FAILURE
#
# WM_contrast_faces_vs_other_faces_sub3_SOC_contrast_mental_vs_rnd_sub5
# CONVERGENCE FAILURE
#
# WM_contrast_faces_vs_other_faces_sub3_REL_match_sub1
# CONVERGENCE FAILURE
#
# WM_contrast_faces_vs_other_faces_sub3_REL_match_sub2
# CONVERGENCE FAILURE
#
# WM_contrast_faces_vs_other_faces_sub3_REL_match_sub5
# CONVERGENCE FAILURE
#
# WM_contrast_faces_vs_other_faces_sub3_REL_relation_sub2
# CONVERGENCE FAILURE
#
# WM_contrast_faces_vs_other_faces_sub3_REL_relation_sub4
# CONVERGENCE FAILURE
#
# WM_contrast_faces_vs_other_faces_sub3_REL_relation_sub5
# CONVERGENCE FAILURE
#
# WM_contrast_faces_vs_other_faces_sub3_WM_contrast_places_vs_other_places_sub1
# CONVERGENCE FAILURE
#
# WM_contrast_faces_vs_other_faces_sub3_LAN_story_sub1
# CONVERGENCE FAILURE
#
# WM_contrast_faces_vs_other_faces_sub3_LAN_story_sub2
# CONVERGENCE FAILURE
#
# WM_contrast_faces_vs_other_faces_sub3_LAN_story_sub3
# CONVERGENCE FAILURE
#
# WM_contrast_faces_vs_other_faces_sub3_LAN_story_sub5
# CONVERGENCE FAILURE
#
# WM_contrast_faces_vs_other_faces_sub4_WM_2bk_sub3
# CONVERGENCE FAILURE
#
# LAN_story_sub1_EMO_contrast_fear_vs_neut_sub3
# CONVERGENCE FAILURE
#
# LAN_story_sub1_SOC_mental_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub1_SOC_mental_sub3
# CONVERGENCE FAILURE
#
# LAN_story_sub1_SOC_mental_sub4
# CONVERGENCE FAILURE
#
# LAN_story_sub1_SOC_mental_sub5
# CONVERGENCE FAILURE
#
# LAN_story_sub1_SOC_contrast_mental_vs_rnd_sub5
# CONVERGENCE FAILURE
#
# LAN_story_sub1_REL_match_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub1_REL_match_sub2
# CONVERGENCE FAILURE
#
# LAN_story_sub1_REL_match_sub4
# CONVERGENCE FAILURE
#
# LAN_story_sub1_REL_match_sub5
# CONVERGENCE FAILURE
#
# LAN_story_sub1_REL_relation_sub2
# CONVERGENCE FAILURE
#
# LAN_story_sub1_REL_relation_sub4
# CONVERGENCE FAILURE
#
# LAN_story_sub1_REL_relation_sub5
# CONVERGENCE FAILURE
#
# LAN_story_sub1_MOT_rh_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub1_MOT_rh_sub4
# CONVERGENCE FAILURE
#
# LAN_story_sub1_MOT_t_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub1_MOT_lh_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub1_WM_0bk_sub5
# CONVERGENCE FAILURE
#
# LAN_story_sub1_WM_contrast_places_vs_other_places_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub1_WM_contrast_faces_vs_other_faces_sub3
# CONVERGENCE FAILURE
#
# LAN_story_sub1_LAN_story_sub2
# CONVERGENCE FAILURE
#
# LAN_story_sub1_LAN_story_sub3
# CONVERGENCE FAILURE
#
# LAN_story_sub1_LAN_story_sub4
# CONVERGENCE FAILURE
#
# LAN_story_sub1_LAN_story_sub5
# CONVERGENCE FAILURE
#
# LAN_story_sub2_EMO_contrast_fear_vs_neut_sub3
# CONVERGENCE FAILURE
#
# LAN_story_sub2_SOC_mental_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub2_SOC_mental_sub3
# CONVERGENCE FAILURE
#
# LAN_story_sub2_SOC_mental_sub4
# CONVERGENCE FAILURE
#
# LAN_story_sub2_SOC_mental_sub5
# CONVERGENCE FAILURE
#
# LAN_story_sub2_SOC_contrast_mental_vs_rnd_sub5
# CONVERGENCE FAILURE
#
# LAN_story_sub2_REL_match_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub2_REL_match_sub2
# CONVERGENCE FAILURE
#
# LAN_story_sub2_REL_match_sub4
# CONVERGENCE FAILURE
#
# LAN_story_sub2_REL_match_sub5
# CONVERGENCE FAILURE
#
# LAN_story_sub2_REL_relation_sub2
# CONVERGENCE FAILURE
#
# LAN_story_sub2_REL_relation_sub4
# CONVERGENCE FAILURE
#
# LAN_story_sub2_REL_relation_sub5
# CONVERGENCE FAILURE
#
# LAN_story_sub2_MOT_rh_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub2_MOT_rh_sub4
# CONVERGENCE FAILURE
#
# LAN_story_sub2_MOT_t_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub2_MOT_lh_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub2_WM_0bk_sub5
# CONVERGENCE FAILURE
#
# LAN_story_sub2_WM_contrast_places_vs_other_places_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub2_WM_contrast_faces_vs_other_faces_sub3
# CONVERGENCE FAILURE
#
# LAN_story_sub2_LAN_story_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub2_LAN_story_sub3
# CONVERGENCE FAILURE
#
# LAN_story_sub2_LAN_story_sub4
# CONVERGENCE FAILURE
#
# LAN_story_sub2_LAN_story_sub5
# CONVERGENCE FAILURE
#
# LAN_story_sub3_EMO_contrast_fear_vs_neut_sub3
# CONVERGENCE FAILURE
#
# LAN_story_sub3_SOC_mental_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub3_SOC_mental_sub3
# CONVERGENCE FAILURE
#
# LAN_story_sub3_SOC_mental_sub4
# CONVERGENCE FAILURE
#
# LAN_story_sub3_SOC_mental_sub5
# CONVERGENCE FAILURE
#
# LAN_story_sub3_SOC_contrast_mental_vs_rnd_sub5
# CONVERGENCE FAILURE
#
# LAN_story_sub3_REL_match_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub3_REL_match_sub2
# CONVERGENCE FAILURE
#
# LAN_story_sub3_REL_match_sub4
# CONVERGENCE FAILURE
#
# LAN_story_sub3_REL_match_sub5
# CONVERGENCE FAILURE
#
# LAN_story_sub3_REL_relation_sub2
# CONVERGENCE FAILURE
#
# LAN_story_sub3_REL_relation_sub4
# CONVERGENCE FAILURE
#
# LAN_story_sub3_REL_relation_sub5
# CONVERGENCE FAILURE
#
# LAN_story_sub3_MOT_rh_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub3_MOT_rh_sub4
# CONVERGENCE FAILURE
#
# LAN_story_sub3_MOT_t_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub3_MOT_lh_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub3_GAM_contrast_win_vs_loss_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub3_WM_contrast_places_vs_other_places_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub3_WM_contrast_faces_vs_other_faces_sub3
# CONVERGENCE FAILURE
#
# LAN_story_sub3_LAN_story_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub3_LAN_story_sub2
# CONVERGENCE FAILURE
#
# LAN_story_sub3_LAN_story_sub4
# CONVERGENCE FAILURE
#
# LAN_story_sub3_LAN_story_sub5
# CONVERGENCE FAILURE
#
# LAN_story_sub4_SOC_mental_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub4_SOC_mental_sub4
# CONVERGENCE FAILURE
#
# LAN_story_sub4_REL_match_sub4
# CONVERGENCE FAILURE
#
# LAN_story_sub4_LAN_story_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub4_LAN_story_sub2
# CONVERGENCE FAILURE
#
# LAN_story_sub4_LAN_story_sub3
# CONVERGENCE FAILURE
#
# LAN_story_sub4_LAN_story_sub5
# CONVERGENCE FAILURE
#
# LAN_story_sub5_EMO_contrast_fear_vs_neut_sub3
# CONVERGENCE FAILURE
#
# LAN_story_sub5_SOC_mental_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub5_SOC_mental_sub3
# CONVERGENCE FAILURE
#
# LAN_story_sub5_SOC_mental_sub4
# CONVERGENCE FAILURE
#
# LAN_story_sub5_SOC_mental_sub5
# CONVERGENCE FAILURE
#
# LAN_story_sub5_SOC_contrast_mental_vs_rnd_sub5
# CONVERGENCE FAILURE
#
# LAN_story_sub5_REL_match_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub5_REL_match_sub2
# CONVERGENCE FAILURE
#
# LAN_story_sub5_REL_match_sub4
# CONVERGENCE FAILURE
#
# LAN_story_sub5_REL_match_sub5
# CONVERGENCE FAILURE
#
# LAN_story_sub5_REL_relation_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub5_REL_relation_sub2
# CONVERGENCE FAILURE
#
# LAN_story_sub5_REL_relation_sub4
# CONVERGENCE FAILURE
#
# LAN_story_sub5_REL_relation_sub5
# CONVERGENCE FAILURE
#
# LAN_story_sub5_MOT_rh_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub5_MOT_rh_sub4
# CONVERGENCE FAILURE
#
# LAN_story_sub5_MOT_t_sub1
# CONVERGENCE FAILURE
# LAN_story_sub5_MOT_lh_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub5_WM_contrast_2bk_vs_0bk_sub2
# CONVERGENCE FAILURE
#
# LAN_story_sub5_WM_0bk_sub5
# CONVERGENCE FAILURE
#
# LAN_story_sub5_WM_contrast_places_vs_other_places_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub5_WM_contrast_faces_vs_other_faces_sub3
# CONVERGENCE FAILURE
#
# LAN_story_sub5_LAN_story_sub1
# CONVERGENCE FAILURE
#
# LAN_story_sub5_LAN_story_sub2
# CONVERGENCE FAILURE
#
# LAN_story_sub5_LAN_story_sub3
# CONVERGENCE FAILURE
#
# LAN_story_sub5_LAN_story_sub4
# CONVERGENCE FAILURE

# %%
[no_converges[ii].var1 for ii in range(len(no_converges)) if no_converges[ii].out_dir == 'EMO_contrast_fear_vs_neut_sub3_WM_contrast_places_vs_other_places_sub2' ]
# Out:
# ['EMO_contrast_fear_vs_neut_sub3']

# %%
# save all matrix to file
np.save(os.path.join(path_root, 'RhoG'), RohG)
np.save(os.path.join(path_root, 'RhoG_pval_0'), RohG_pval_0)
np.save(os.path.join(path_root, 'RhoG_pval_1'), RohG_pval_1)
np.save(os.path.join(path_root, 'RhoE'), RohE)
np.save(os.path.join(path_root, 'RhoE_pval'), RohE_pval)

# %%
count
# Out:
# 442

# %%
# compute FD
from statsmodels.sandbox.stats import multicomp as smi

# %%
RohG_p_vec = RohG_pval_0[np.triu_indices(len(RohG_pval_0),1)]
RohG_p_vec[RohG_p_vec == 0]=1

# %%
RohG_p_vec_fd = smi.multipletests(RohG_p_vec, alpha=0.05, method='fdr_bh')

# %%
RohG_p_fd= np.eye(len(RohG_pval_0))
for row,col,val in zip(np.triu_indices(len(RohG_pval_0),1)[0],
                       np.triu_indices(len(RohG_pval_0),1)[1],
                       -np.log10(RohG_p_vec_fd[1])):
    RohG_p_fd[row,col]=val

# %%
i_lower = np.tril_indices(len(RohG_pval_0), -1)
RohG_p_fd[i_lower] = RohG_p_fd.T[i_lower]

# %%
# hierachical clustering
svec = RohG[np.triu_indices(len(RohG),1)]
dist = 1 - svec
n_sbt = 3
link = scl.hierarchy.linkage(dist, method='ward')
part = scl.hierarchy.fcluster(link, n_sbt, criterion='maxclust')
order = scl.hierarchy.dendrogram(link, no_plot=True)['leaves']
plt.figure(figsize=(15, 5))
dn = scl.hierarchy.dendrogram(link)

# %%
# Plot the distance matrix again, but now ordered by hierarchy
use_columns = pheno_stack_df.columns.drop('ID')
label_ord = [use_columns[ord] for ord in order]
gsp = gs.GridSpec(1, 10)
f = plt.figure(figsize=(25,25))
ax = f.add_subplot(gsp[0,:9])
axcl = f.add_subplot(gsp[0,9])
p = ax.imshow(RohG[order, :][:, order],cmap =nlp.cm.cold_hot,interpolation='none')
tmp = ax.set_yticks(range(len(use_columns)))
tmp = ax.set_yticklabels(label_ord)
tmp = ax.set_xticks(range(len(use_columns)))
tmp = ax.set_xticklabels(label_ord, rotation=90)
tmp = f.colorbar(p, cax=axcl)
tmp = f.suptitle('Distance Matrix')

# %%
# Order clustered correlation matrix
RohG_clust = RohG[order, :][:, order]
RohG_fd_clust = RohG_p_fd[order, :][:, order]
pco = part[order]

# Set start/stop boxes positions
cuts = [(np.min(np.argwhere(pco==i)), np.max(np.argwhere(pco==i)))for i in np.unique(pco)]

# Set color code
s2_colors = ["#f6afed",
             "#514c82"]

s3_colors = ["#f6afed",
             "#ec8b00",
             "#514c82"]

s4_colors = ["#f6afed",
             "#ec8b00",
             "#514c82",
             "#beb146"]

s5_colors = ["#cb5362",
            "#6ea84e",
            "#9d6cc1",
            "#bb873c",
            "#3fadaf"]

s6_colors = ["#cc5452",
            "#50ac72",
            "#c45ca2",
            "#929d3d",
            "#7879cd",
            "#c8803e"]

s7_colors = ["#bf61bb",
            "#60a75b",
            "#746cc9",
            "#b1963f",
            "#5aa4d1",
            "#cb623f",
            "#c8567a"]

s8_colors = ["#beb146",
             "#8f62ca",
             "#61af4b",
             "#c75d9c",
             "#4bb092",
             "#cb5253",
             "#6b8bcd",
             "#cb7d3e"]

s9_colors = ["#beb146",
             "#8f62ca",
             "#61af4b",
             "#c75d9c",
             "#4bb092",
             "#cb5253",
             "#6b8bcd",
             "#cb7d3e",
             "#717833"]


s10_colors =["#8562cc",
            "#60b14d",
            "#c361aa",
            "#bab241",
            "#688bcd",
            "#cd5136",
            "#4bb092",
            "#ca586f",
            "#717e37",
            "#c58443"]


lin2 = LinearSegmentedColormap.from_list(name='s2',
                                         colors = s2_colors,
                                         N=n_sbt)
lin3 = LinearSegmentedColormap.from_list(name='s3',
                                         colors = s3_colors,
                                         N=n_sbt)
lin4 = LinearSegmentedColormap.from_list(name='s4',
                                         colors = s4_colors,
                                         N=n_sbt)
lin5 = LinearSegmentedColormap.from_list(name='s5',
                                         colors = s5_colors,
                                         N=n_sbt)
lin6 = LinearSegmentedColormap.from_list(name='s6',
                                         colors = s6_colors,
                                         N=n_sbt)
lin7 = LinearSegmentedColormap.from_list(name='s7',
                                         colors = s7_colors,
                                         N=n_sbt)
lin8 = LinearSegmentedColormap.from_list(name='s8',
                                         colors = s8_colors,
                                         N=n_sbt)
lin9 = LinearSegmentedColormap.from_list(name='s9',
                                         colors = s9_colors,
                                         N=n_sbt)
lin10 = LinearSegmentedColormap.from_list(name='s10',
                                          colors = s10_colors,
                                          N=n_sbt)

# %%
# make strtucture to store different colors parameters
struc = {}
struc["2"]={}
struc["2"]["lin"] = lin2
struc["2"]["s_colors"] = s2_colors
struc["3"]={}
struc["3"]["lin"] = lin3
struc["3"]["s_colors"] = s3_colors
struc["4"]={}
struc["4"]["lin"] = lin4
struc["4"]["s_colors"] = s4_colors
struc["5"]={}
struc["5"]["lin"] = lin5
struc["5"]["s_colors"] = s5_colors
struc["6"]={}
struc["6"]["lin"] = lin6
struc["6"]["s_colors"] = s6_colors
struc["7"]={}
struc["7"]["lin"] = lin7
struc["7"]["s_colors"] = s7_colors
struc["8"]={}
struc["8"]["lin"] = lin8
struc["8"]["s_colors"] = s8_colors
struc["9"]={}
struc["9"]["lin"] = lin9
struc["9"]["s_colors"] = s9_colors
struc["10"]={}
struc["10"]["lin"] = lin10
struc["10"]["s_colors"] = s10_colors

# %%
# Generate boxes
mat, cmat, lmat, ind = make_boxes(RohG_clust, cuts, 2)
mat_fd, cmat_fd, lmat_fd, ind_fd = make_boxes(RohG_fd_clust, cuts, 2)

# %%
# Set figure
f = plt.figure(figsize=(25,25))
ax = f.add_subplot(gsp[0,:9])
axcl = f.add_subplot(gsp[0,9])
p = ax.imshow(mat, cmap=plt.cm.Spectral_r,interpolation='none', vmin=-1, vmax=1)
tmp = ax.imshow(lmat, cmap=plt.cm.Greys_r,interpolation='none')
tmp = ax.imshow(lmat, cmap=plt.cm.Greys, alpha=1,interpolation='none')
tmp = ax.imshow(cmat, cmap=struc[str(n_sbt)]['lin'],interpolation='none')
tmp = ax.set_yticks(ind)
tmp = ax.set_yticklabels(label_ord)
tmp = ax.set_xticks(ind)
tmp = ax.set_xticklabels(label_ord, rotation=90)
# set labels colors
#colors = [s3_colors[i-1] for i in pco]
colors = [struc[str(n_sbt)]['s_colors'][i-1] for i in pco]
for xtick,ytick,color in zip(ax.get_xticklabels(),ax.get_yticklabels(),colors):
    xtick.set_color(color)
    ytick.set_color(color)
tmp = f.colorbar(p, cax=axcl)
tmp = f.suptitle('re-ordered correlation matrix')
#f.savefig(os.path.join(path_root,'Figures/associations/pheno_clustered.svg'))

# %%
# Set figure
f = plt.figure(figsize=(25,25))
ax = f.add_subplot(gsp[0,:9])
axcl = f.add_subplot(gsp[0,9])
p = ax.imshow(mat_fd, cmap=plt.cm.Spectral_r,interpolation='none',vmin=0,vmax=10)
tmp = ax.imshow(lmat_fd, cmap=plt.cm.Greys_r,interpolation='none')
tmp = ax.imshow(lmat_fd, cmap=plt.cm.Greys, alpha=1,interpolation='none')
tmp = ax.imshow(cmat_fd, cmap=struc[str(n_sbt)]['lin'],interpolation='none')
tmp = ax.set_yticks(ind_fd)
tmp = ax.set_yticklabels(label_ord)
tmp = ax.set_xticks(ind_fd)
tmp = ax.set_xticklabels(label_ord, rotation=90)
# set labels colors
#colors = [s3_colors[i-1] for i in pco]
colors = [struc[str(n_sbt)]['s_colors'][i-1] for i in pco]
for xtick,ytick,color in zip(ax.get_xticklabels(),ax.get_yticklabels(),colors):
    xtick.set_color(color)
    ytick.set_color(color)
tmp = f.colorbar(p, cax=axcl)
tmp = f.suptitle('re-ordered correlation matrix')
#f.savefig(os.path.join(path_root,'Figures/associations/pheno_clustered.svg'))

# %%
fp = open(os.path.join(path_root,out_dir,'solar_pleio.out'))

# %%
line
# Out:
# 'CONVERGENCE FAILURE\n'

# %%
fp = open(os.path.join(path_root,out_dir,'solar_pleio.out'))
for i,line in enumerate(fp):
    if 'RhoG is ' in line:
        print(out_dir)
        print(line)
        break

# %%
fp = open(os.path.join(path_root,out_dir,'solar_pleio.out'))
for i,line in enumerate(fp):
    if 'RhoG is ' in line:
        print(out_dir)
        print(line)
        break
    elif 'CONVERGENCE FAILURE' in line:
        print(out_dir)
        print(line)
        break
fp.close()
# Out:
# LAN_story_sub5_LAN_story_sub4
# CONVERGENCE FAILURE

# %%
float(line.strip('\n').split(' ')[-1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-f993070b54c1> in <module>()
# ----> 1 float(line.strip('\n').split(' ')[-1])
#
# ValueError: could not convert string to float: 'FAILURE'

# %%
fp = open(os.path.join(path_root,out_dir,'solar_pleio.out'))

# %%
fp = open(os.path.join(path_root,out_dir,'solar_pleio.out'))

# %%
for i,line in enumerate(fp):
    if 'RhoG is ' in line:
        print(line)
# Out:
# 			 RhoG is 1.0000000

# %%
line
# Out:
# '\tFinal models are named poly, spor\n'

# %%
number_lines = sum(1 for line in open(os.path.join(path_root,out_dir,'solar_pleio.out')))

# %%
number_lines
# Out:
# 32

# %%
fp = open(os.path.join(path_root,out_dir,'solar_pleio.out'))
for i,line in enumerate(fp):
    if i == 75 :
        print(line)
        break
fp.close()
# Out:
# 			 RhoG is 0.4423606

# %%
float(line.strip('\n').split(' ')[-1])
# Out:
# 0.4423606

# %%
line.find('a')
# Out:
# 4

# %%
# !ls path_root
# Out:
# ls: cannot access 'path_root': No such file or directory

# %%
input = ['Duration', 'F0', 'F1', 'F2', 'F3']

# %%
dict(zip(input, range(len(input))))
# Out:
# {'Duration': 0, 'F0': 1, 'F1': 2, 'F2': 3, 'F3': 4}

# %%
#custom function for key sorting element
import re

def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    '''
    alist.sort(key=natural_keys) sorts in human order
    http://nedbatchelder.com/blog/200712/human_sorting.html
    (See Toothy's implementation in the comments)
    '''
    return [ atoi(c) for c in re.split('(\d+)', text) ]

# %%
# Set up the paths 
path_root = '/media/yassine/data_disk/Drive/HCP2/'
#path_root = "/home/yassinebha/Drive/HCP/"
subt_path = os.path.join(path_root,"subtypes_scores/26-10-2016/subtype_5_spm_RELATIONAL_18-Oct-2017/")
net_path = os.path.join(path_root,"subtypes_scores/26-10-2016/subtype_5_spm_RELATIONAL_18-Oct-2017/networks/")
out_path = os.path.join(path_root,"Solar_heritability/HCP_subtype/")

# %%
nb_sbt = natural_keys(subt_path)[9]
# task name
task_name = natural_keys(subt_path)[10][5:-1].lower()

# %%
task_name
# Out:
# 'relational'

# %%
# Set up files name
sbt_name_pattern = "sbt_weights_net_{}.csv"
pheno_path = os.path.join(path_root,"subtypes_scores/26-10-2016/pheno/hcp_pheno_{}_raw.csv".format(task_name))
solar_script = 'fcd_solar_h2r_test.sh'
pheno_save = 'solar_{}_spm_pheno.csv'.format(task_name.upper())
pedig_save = 'solar_{}_spm_pedigre.csv'.format(task_name.upper())
solar_out = 'subtype_5_{}_{}'.format(task_name,time.strftime("%d-%m-%Y"))
h2r_out_file = 'h2r_solar_{}_spm_{}.csv'
## Solar covariates
solar_cov = '    cov FD_scrubbed_mean Gender'

# %%
# List of network names
list_trial = os.listdir(net_path)
list_trial
# Out:
# ['match', 'relation', 'contrast_relation_vs_match']

# %%
# Loop over each network and build weight file
for index, trial_name in enumerate(list_trial):
    file_path = os.path.join(net_path, trial_name, sbt_name_pattern.format(trial_name))
    if not os.path.exists(file_path):
        print("Hello, {} does not exist".format(file_path))
    
    tmp_weights = pd.read_csv(file_path)
    # Rename first column
    tmp_weights.rename(columns={" ":"Subject"}, inplace=True)
    tmp_weights.Subject = tmp_weights.Subject.str.strip(" ")
    
    rename_dict = dict()
    for colname in tmp_weights.columns:
        if colname == "Subject":
            continue
        else:
            new_name = "{}_{}".format(trial_name, colname)
            # Get rid of trailing whitespace
            new_name = new_name.strip(" ")
            rename_dict[colname] = new_name

    tmp_weights.rename(columns=rename_dict, inplace=True)
    
    if index==0:
        dataframe = tmp_weights
    else:
        dataframe = pd.merge(dataframe, tmp_weights, on="Subject", how="inner")

# %%
dataframe.head()
# Out:
#      Subject  match_sub1  match_sub2  match_sub3  match_sub4  match_sub5  \
# 0  HCP100206      -0.229       0.219      -0.148      -0.105       0.234
# 1  HCP100307       0.737      -0.722       0.357       0.410      -0.714
# 2  HCP100408      -0.488       0.503      -0.347      -0.236       0.471
# 3  HCP100610      -0.119       0.126      -0.048      -0.120       0.136
# 4  HCP101006      -0.267       0.253      -0.158      -0.143       0.285
#
#    relation_sub1  relation_sub2  relation_sub3  relation_sub4  relation_sub5  \
# 0          0.268          0.313         -0.199          0.263         -0.318
# 1         -0.259         -0.727          0.296         -0.696          0.734
# 2          0.038          0.641         -0.208          0.655         -0.638
# 3         -0.220          0.261         -0.109          0.379         -0.262
# 4          0.088          0.527         -0.241          0.518         -0.518
#
#    contrast_relation_vs_match_sub1  contrast_relation_vs_match_sub2  \
# 0                           -0.090                            0.085
# 1                            0.237                            0.104
# 2                           -0.226                           -0.286
# 3                           -0.229                           -0.504
# 4                           -0.184                           -0.061
#
#    contrast_relation_vs_match_sub3  contrast_relation_vs_match_sub4  \
# 0                           -0.041                           -0.085
# 1                           -0.205                           -0.050
# 2                            0.366                            0.141
# 3                            0.424                            0.446
# 4                            0.125                            0.036
#
#    contrast_relation_vs_match_sub5
# 0                            0.141
# 1                           -0.181
# 2                            0.122
# 3                            0.027
# 4                            0.154

# %%
dataframe.Subject.describe()
# Out:
# count           764
# unique          764
# top       HCP308129
# freq              1
# Name: Subject, dtype: object

# %%
# Load pheno file
file_weight = dataframe
file_pheno = pd.read_csv(pheno_path)

# %%
file_pheno.head()
# Out:
#   Unnamed: 0     FD_RL  FD_scrubbed_RL     FD_LR  FD_scrubbed_LR  \
# 0  HCP100206  0.098646        0.091387  0.118289        0.118289
# 1  HCP100307  0.108372        0.108372  0.098514        0.098514
# 2  HCP100408  0.113633        0.113633  0.145309        0.145309
# 3  HCP100610  0.184109        0.184109  0.170573        0.160610
# 4  HCP101006  0.146478        0.146478  0.152041        0.148402
#
#    FD_scrubbed_mean   FD_mean    Subject  Age_in_Yrs  Gender     ...      \
# 0          0.104838  0.108467  HCP100206        27.0     1.0     ...
# 1          0.103443  0.103443  HCP100307        27.0     2.0     ...
# 2          0.129471  0.129471  HCP100408        33.0     1.0     ...
# 3          0.172360  0.177341  HCP100610        27.0     1.0     ...
# 4          0.147440  0.149260  HCP101006        35.0     2.0     ...
#
#   Cluster_1 Cluster_2  Cluster_3  Cluster_4  Cluster_5  Cluster_6  Cluster_7  \
# 0 -0.344595  1.283574   0.052662   1.436342   0.706008  -0.510366   1.975280
# 1 -0.639736  0.522789  -0.952467  -0.713226  -0.559144  -0.140952  -0.703027
# 2  1.173656  0.092160  -0.521888  -0.034026  -0.109229   0.221359  -0.589268
# 3  0.891096 -0.361182  -0.881930  -0.386394  -0.575076  -0.197974   0.203063
# 4  0.608381  0.037740   0.055531  -0.883482  -0.383174  -0.309221  -0.753780
#
#    Cluster_8  Cluster_9  Cluster_10
# 0   1.294323  -0.025888   -0.203825
# 1   0.229112   0.097581   -0.444702
# 2   0.357483  -0.039443    0.095913
# 3   0.618868   0.491618    1.343114
# 4  -1.183212   0.031989   -0.494022
#
# [5 rows x 26 columns]

# %%
file_pheno.Subject.describe()
# Out:
# count           797
# unique          797
# top       HCP567961
# freq              1
# Name: Subject, dtype: object

# %%
# Select a subset of variable
file_pheno_subset = file_pheno[["Subject","Age_in_Yrs","Gender","BMI","FD_mean","FD_scrubbed_mean"]]
file_pheno_subset.head()
# Out:
#      Subject  Age_in_Yrs  Gender    BMI   FD_mean  FD_scrubbed_mean
# 0  HCP100206        27.0     1.0  26.64  0.108467          0.104838
# 1  HCP100307        27.0     2.0  22.96  0.103443          0.103443
# 2  HCP100408        33.0     1.0  27.75  0.129471          0.129471
# 3  HCP100610        27.0     1.0  36.91  0.177341          0.172360
# 4  HCP101006        35.0     2.0  30.27  0.149260          0.147440

# %%
# Replace gender M=1 and F=2
#file_pheno_subset.Gender.replace({'M':1,'F':2}, inplace=True)
#file_pheno_subset.head()

# %%
file_pheno_subset[["Subject"]].describe()
# Out:
#           Subject
# count         797
# unique        797
# top     HCP567961
# freq            1

# %%
file_weight[["Subject"]].describe()
# Out:
#           Subject
# count         764
# unique        764
# top     HCP308129
# freq            1

# %%
# Merge weight with subset of pheno variables
merged_weight_pheno = pd.merge(file_weight, file_pheno_subset, on='Subject', how='left')
# Replace 'Subject' by 'ID'
merged_weight_pheno.rename(columns={'Subject':'ID'},inplace=True)
merged_weight_pheno.head()
# Out:
#           ID  match_sub1  match_sub2  match_sub3  match_sub4  match_sub5  \
# 0  HCP100206      -0.229       0.219      -0.148      -0.105       0.234
# 1  HCP100307       0.737      -0.722       0.357       0.410      -0.714
# 2  HCP100408      -0.488       0.503      -0.347      -0.236       0.471
# 3  HCP100610      -0.119       0.126      -0.048      -0.120       0.136
# 4  HCP101006      -0.267       0.253      -0.158      -0.143       0.285
#
#    relation_sub1  relation_sub2  relation_sub3  relation_sub4  \
# 0          0.268          0.313         -0.199          0.263
# 1         -0.259         -0.727          0.296         -0.696
# 2          0.038          0.641         -0.208          0.655
# 3         -0.220          0.261         -0.109          0.379
# 4          0.088          0.527         -0.241          0.518
#
#          ...         contrast_relation_vs_match_sub1  \
# 0        ...                                  -0.090
# 1        ...                                   0.237
# 2        ...                                  -0.226
# 3        ...                                  -0.229
# 4        ...                                  -0.184
#
#    contrast_relation_vs_match_sub2  contrast_relation_vs_match_sub3  \
# 0                            0.085                           -0.041
# 1                            0.104                           -0.205
# 2                           -0.286                            0.366
# 3                           -0.504                            0.424
# 4                           -0.061                            0.125
#
#    contrast_relation_vs_match_sub4  contrast_relation_vs_match_sub5  \
# 0                           -0.085                            0.141
# 1                           -0.050                           -0.181
# 2                            0.141                            0.122
# 3                            0.446                            0.027
# 4                            0.036                            0.154
#
#    Age_in_Yrs  Gender    BMI   FD_mean  FD_scrubbed_mean
# 0        27.0     1.0  26.64  0.108467          0.104838
# 1        27.0     2.0  22.96  0.103443          0.103443
# 2        33.0     1.0  27.75  0.129471          0.129471
# 3        27.0     1.0  36.91  0.177341          0.172360
# 4        35.0     2.0  30.27  0.149260          0.147440
#
# [5 rows x 21 columns]

# %%
merged_weight_pheno.ID.describe()
# Out:
# count           764
# unique          764
# top       HCP308129
# freq              1
# Name: ID, dtype: object

# %%
# Check if there is empty value in BMI
sum(merged_weight_pheno.BMI.isnull())
# Out:
# 0

# %%
# Save the merged file
merged_weight_pheno.to_csv(os.path.join(out_path,pheno_save), index=False)

# %%
os.path.join(out_path,pheno_save)
# Out:
# '/media/yassine/data_disk/Drive/HCP2/Solar_heritability/HCP_subtype/solar_RELATIONAL_spm_pheno.csv'

# %% [markdown]
# ## Build trait file

# %%
## build trait file
# Remove not neaded traits
list_trait = merged_weight_pheno.columns.tolist()
new_list = [trait for trait in list_trait if trait not in ['ID','Age_in_Yrs','Gender']]
new_list
# Out:
# ['match_sub1',
#  'match_sub2',
#  'match_sub3',
#  'match_sub4',
#  'match_sub5',
#  'relation_sub1',
#  'relation_sub2',
#  'relation_sub3',
#  'relation_sub4',
#  'relation_sub5',
#  'contrast_relation_vs_match_sub1',
#  'contrast_relation_vs_match_sub2',
#  'contrast_relation_vs_match_sub3',
#  'contrast_relation_vs_match_sub4',
#  'contrast_relation_vs_match_sub5',
#  'BMI',
#  'FD_mean',
#  'FD_scrubbed_mean']

# %%
# Save trait file
file_out = open(os.path.join(out_path,"trait_file"), 'w')
for item in new_list:
    file_out.write("%s\n" % item)
file_out.close()

# %% [markdown]
# ## Build Pedigree file

# %%
# Select a subset of variable from pheno file
file_pheno_pedig = file_pheno[["Subject","Twin_Stat","Zygosity","Mother_ID","Gender"]]
file_pheno_pedig.head()
# Out:
#      Subject Twin_Stat Zygosity  Mother_ID  Gender
# 0  HCP100206   NotTwin  NotTwin    56037.0     1.0
# 1  HCP100307      Twin    NotMZ    51488.0     2.0
# 2  HCP100408      Twin       MZ    51730.0     1.0
# 3  HCP100610      Twin    NotMZ    52813.0     1.0
# 4  HCP101006      Twin       MZ    51283.0     2.0

# %%
file_pheno_pedig.Subject.describe()
# Out:
# count           797
# unique          797
# top       HCP567961
# freq              1
# Name: Subject, dtype: object

# %%
# Build pedigre : ID , mo, fo, hhID, mztwins,sex
mother_id = ["mo_{}".format(row.Mother_ID) for ind, row in file_pheno_pedig.iterrows()]
father_id = ["fa_{}".format(row.Mother_ID) for ind, row in file_pheno_pedig.iterrows()]
household_id = ["hh_{}".format(row.Mother_ID) for ind, row in file_pheno_pedig.iterrows()]
twin_id = ["pair_{}".format(row.Mother_ID) if row.Zygosity == "MZ" else "" for ind, row in file_pheno_pedig.iterrows()]

# %%
# write into new data frame
df_pedig = pd.DataFrame()
df_pedig["ID"] = file_pheno_pedig.Subject
df_pedig["fa"] = father_id
df_pedig["mo"] = mother_id
df_pedig["sex"] = file_pheno_pedig.Gender.astype(int)
df_pedig["mztwin"] = twin_id
df_pedig["hhID"] = household_id


print("head")
display(df_pedig.head())
print("tail")
display(df_pedig.tail())
df_pedig.count()
# Out:
# head
#           ID          fa          mo  sex        mztwin        hhID
# 0  HCP100206  fa_56037.0  mo_56037.0    1                hh_56037.0
# 1  HCP100307  fa_51488.0  mo_51488.0    2                hh_51488.0
# 2  HCP100408  fa_51730.0  mo_51730.0    1  pair_51730.0  hh_51730.0
# 3  HCP100610  fa_52813.0  mo_52813.0    1                hh_52813.0
# 4  HCP101006  fa_51283.0  mo_51283.0    2  pair_51283.0  hh_51283.0
# tail
#             ID          fa          mo  sex mztwin        hhID
# 792  HCP992673  fa_56143.0  mo_56143.0    2         hh_56143.0
# 793  HCP992774  fa_51345.0  mo_51345.0    1         hh_51345.0
# 794  HCP993675  fa_55800.0  mo_55800.0    2         hh_55800.0
# 795  HCP994273  fa_52364.0  mo_52364.0    1         hh_52364.0
# 796  HCP996782  fa_51541.0  mo_51541.0    2         hh_51541.0
# ID        797
# fa        797
# mo        797
# sex       797
# mztwin    797
# hhID      797
# dtype: int64

# %%
# Look for MZ twins missing their co-twin
uniques = list(df_pedig.mztwin.unique())
uniques.pop(0)
twin_counts = [np.sum(df_pedig.mztwin==twin) for twin in uniques]
#for idx, twin in enumerate(uniques):
    #print("{} occurs {} times".format(twin, twin_counts[idx]))

# %%
# create a mask that will kepp only MZ twins missing their co-twin
singles = [True if np.sum(df_pedig.mztwin==row.mztwin)==1 else False for ind, row in df_pedig.iterrows()]

# %%
# Make a copy of the pedigre to avoid missing up with the original data
copy_df_pedig = df_pedig.copy()

# %%
# Select only MZ twins missing their co-twin
df_single_pedig = copy_df_pedig[singles]

# Add "M_" (for missing) to a the single MZ twins
for i, row in df_single_pedig.iterrows():
    df_single_pedig.set_value(i,"ID","M_{}".format(row.ID))
display(df_single_pedig.head())
df_single_pedig.count()
# Out:
#              ID          fa          mo  sex        mztwin        hhID
# 37  M_HCP110007  fa_54572.0  mo_54572.0    2  pair_54572.0  hh_54572.0
# 55  M_HCP114823  fa_52925.0  mo_52925.0    2  pair_52925.0  hh_52925.0
# 82  M_HCP122317  fa_51802.0  mo_51802.0    1  pair_51802.0  hh_51802.0
# 87  M_HCP123824  fa_56022.0  mo_56022.0    1  pair_56022.0  hh_56022.0
# 90  M_HCP124422  fa_51529.0  mo_51529.0    2  pair_51529.0  hh_51529.0
# ID        43
# fa        43
# mo        43
# sex       43
# mztwin    43
# hhID      43
# dtype: int64

# %%
# Append pedgree with fake co-twin for the missing one
df_pedig_final = copy_df_pedig.append(df_single_pedig)
df_pedig_final.head()
# Out:
#           ID          fa          mo  sex        mztwin        hhID
# 0  HCP100206  fa_56037.0  mo_56037.0    1                hh_56037.0
# 1  HCP100307  fa_51488.0  mo_51488.0    2                hh_51488.0
# 2  HCP100408  fa_51730.0  mo_51730.0    1  pair_51730.0  hh_51730.0
# 3  HCP100610  fa_52813.0  mo_52813.0    1                hh_52813.0
# 4  HCP101006  fa_51283.0  mo_51283.0    2  pair_51283.0  hh_51283.0

# %%
df_pedig_final.tail()
# Out:
#               ID          fa          mo  sex        mztwin        hhID
# 689  M_HCP769064  fa_52803.0  mo_52803.0    1  pair_52803.0  hh_52803.0
# 716  M_HCP835657  fa_52137.0  mo_52137.0    2  pair_52137.0  hh_52137.0
# 718  M_HCP837964  fa_52875.0  mo_52875.0    2  pair_52875.0  hh_52875.0
# 760  M_HCP904044  fa_51290.0  mo_51290.0    2  pair_51290.0  hh_51290.0
# 784  M_HCP972566  fa_56077.0  mo_56077.0    2  pair_56077.0  hh_56077.0

# %%
df_pedig_final.count()
# Out:
# ID        840
# fa        840
# mo        840
# sex       840
# mztwin    840
# hhID      840
# dtype: int64

# %%
# Save the pedigree file
df_pedig_final.to_csv(os.path.join(out_path,pedig_save), index=False)

# %% [markdown]
# ## Run SOLAR heritability estimate

# %%
# %%bash -s "$out_path" "$solar_cov" "$solar_script"
# cd $1 #cd to out_path
# #sufix=$(echo $2 | sed -e 's/ /_/g') # add a suffix of covariate
# sed -i "104s/.*/$2/" $3 # feed the covariate to solar script
# sed -i "52s~.*~$1phi2.gz~" $3 # put the right path for the simlink
# sed -i "53s~.*~$1pedindex.out~" $3
# sed -i "54s~.*~$1pedindex.cde~" $3
# sed -i "55s~.*~$1se_univ_polygen.tcl~" $3

# %%
# %%bash -s "$out_path" "$pedig_save"
# cd $1
# solar <<INTERNAL_SOLAR_SCRIPT
# load pedi $2
# pedigree classes -full
# INTERNAL_SOLAR_SCRIPT
# Out:
# SOLAR Eclipse version 8.1.1 (General), last updated on December 12, 2017
# Copyright (c) 1995-2017 Texas Biomedical Research Institute
# Enter help for help, exit to exit, doc to browse documentation.
#
# Unloading current pedigree data ...
# Loading pedigree data from the file solar_RELATIONAL_spm_pedigre.csv ...
# ::::::::::::::
# mibdrel.tab
# ::::::::::::::
#
#     NPairs  Relationship
#   ========  ===========================================
#       1568  Self
#        117  Identical sib pair
#       1680  Parent-offspring
#        586  Siblings
#        364  Unrelated

# %%
# %%bash -s "$out_path" "$pheno_save" "$solar_out"
# cd $1
# #if [ ! -d $3 ]; then
# #   mkdir $3
# #fi
# solar <<INTERNAL_SOLAR_SCRIPT
# load pheno $2
# INTERNAL_SOLAR_SCRIPT
# bash fcd_solar_h2r_test.sh trait_file $3 $1$2
# for i in $3/Set-*; do bash $i/run_all.sh ; done
# Out:
# SOLAR Eclipse version 8.1.1 (General), last updated on December 12, 2017
# Copyright (c) 1995-2017 Texas Biomedical Research Institute
# Enter help for help, exit to exit, doc to browse documentation.
#
# Creating output directories...
# 00017 : Set-17 : FD_scrubbed_mean
# All done.

# %% [markdown]
# ## Results

# %%
out_herit = pd.read_csv(os.path.join(out_path,solar_out,"se_out.out"),sep="\t",header=None)
out_herit_df =  pd.DataFrame()

data = pd.DataFrame({"Trait": out_herit[2],"H2r": out_herit[4],"P": out_herit[7],"CovVarianceExpl": out_herit[9]})
out_herit_df = data[["Trait","H2r","P","CovVarianceExpl"]].sort_values(['Trait'], ascending=[True]).reset_index(drop=True)
out_herit_df
# Out:
#                                    Trait       H2r             P  \
# 0                   BMI_norm              0.596150  1.609180e-13
# 1                   FD_mean_norm          0.243918  1.196360e-02
# 2   contrast_relation_vs_match_sub1_norm  0.097465  7.622840e-02
# 3   contrast_relation_vs_match_sub2_norm  0.152053  2.540930e-02
# 4   contrast_relation_vs_match_sub3_norm  0.142514  2.119550e-02
# 5   contrast_relation_vs_match_sub4_norm  0.100051  1.037657e-01
# 6   contrast_relation_vs_match_sub5_norm  0.086781  1.056090e-01
# 7                   match_sub1_norm       0.483234  3.688557e-14
# 8                   match_sub2_norm       0.484474  3.813450e-14
# 9                   match_sub3_norm       0.354013  3.000000e-07
# 10                  match_sub4_norm       0.525551  5.417273e-17
# 11                  match_sub5_norm       0.492009  9.739519e-15
# 12                  relation_sub1_norm    0.472168  1.227643e-11
# 13                  relation_sub2_norm    0.533172  2.732563e-17
# 14                  relation_sub3_norm    0.472334  7.745835e-14
# 15                  relation_sub4_norm    0.519555  2.138912e-16
# 16                  relation_sub5_norm    0.536545  1.899087e-17
#
#     CovVarianceExpl
# 0          0.296816
# 1          0.850358
# 2          0.000103
# 3          0.001910
# 4          0.000619
# 5          0.000110
# 6          0.000263
# 7         -0.000043
# 8         -0.000057
# 9          0.010470
# 10         0.002827
# 11         0.000043
# 12         0.006879
# 13         0.000072
# 14         0.000185
# 15         0.000209
# 16        -0.000013

# %%
# remove unwanted Variables
out_herit_df_clean = out_herit_df[~out_herit_df['Trait'].str.strip().isin(['BMI_norm','FD_mean_norm','FD_scrubbed_mean_norm'])]

# %%
# FDR
from statsmodels.sandbox.stats import multicomp as smi
pcorr_vec = smi.multipletests(out_herit_df_clean['P'], alpha=0.05, method='fdr_bh')
out_herit_df_clean.insert(3,'FDR',pcorr_vec[1])
out_herit_df_clean.insert(4,'FDR_log10',-np.log10(pcorr_vec[1]))

# %%
out_herit_df_clean
# Out:
#                                    Trait       H2r             P  \
# 2   contrast_relation_vs_match_sub1_norm  0.097465  7.622840e-02
# 3   contrast_relation_vs_match_sub2_norm  0.152053  2.540930e-02
# 4   contrast_relation_vs_match_sub3_norm  0.142514  2.119550e-02
# 5   contrast_relation_vs_match_sub4_norm  0.100051  1.037657e-01
# 6   contrast_relation_vs_match_sub5_norm  0.086781  1.056090e-01
# 7                   match_sub1_norm       0.483234  3.688557e-14
# 8                   match_sub2_norm       0.484474  3.813450e-14
# 9                   match_sub3_norm       0.354013  3.000000e-07
# 10                  match_sub4_norm       0.525551  5.417273e-17
# 11                  match_sub5_norm       0.492009  9.739519e-15
# 12                  relation_sub1_norm    0.472168  1.227643e-11
# 13                  relation_sub2_norm    0.533172  2.732563e-17
# 14                  relation_sub3_norm    0.472334  7.745835e-14
# 15                  relation_sub4_norm    0.519555  2.138912e-16
# 16                  relation_sub5_norm    0.536545  1.899087e-17
#
#              FDR  FDR_log10  CovVarianceExpl
# 2   8.795585e-02   1.055735         0.000103
# 3   3.176162e-02   1.498097         0.001910
# 4   2.890295e-02   1.539058         0.000619
# 5   1.056090e-01   0.976299         0.000110
# 6   1.056090e-01   0.976299         0.000263
# 7   8.171679e-14  13.087689        -0.000043
# 8   8.171679e-14  13.087689        -0.000057
# 9   4.500000e-07   6.346787         0.010470
# 10  2.708637e-16  15.567249         0.002827
# 11  2.921856e-14  13.534341         0.000043
# 12  2.046072e-11  10.689079         0.006879
# 13  2.049422e-16  15.688369         0.000072
# 14  1.452344e-13  12.837930         0.000185
# 15  8.020920e-16  15.095776         0.000209
# 16  2.049422e-16  15.688369        -0.000013

# %%
# Loop over trait and create heritability table for radar plot
#drop_list = ['BMI','FD_mean','FD_scrubbed_mean','Handedness']
#list_new = [x for x in new_list if x not in drop_list ]

# %%
## Loop over trait and create heritability table for radar plot
#list_trial = [xx.replace('-','_') for xx in list_trial]

list_sbt = ['sub1','sub2','sub3','sub4','sub5']
for trait_herit in list_trial:
    mask_df = [x[:-10] == trait_herit for x in out_herit_df_clean.Trait.str.strip()]
    out_herit_select = out_herit_df_clean[['Trait','H2r']][mask_df]
    # extract trial
    column_net = [' '.join(row['Trait'].split('_')[0:-2]) for ind,row in out_herit_select[['Trait']].iterrows()]
    out_herit_select.loc[:,'Trial'] = column_net
    # extract subtype
    column_subt = [row['Trait'].split('_')[-2].strip() for ind,row in out_herit_select[['Trait']].iterrows()]
    out_herit_select.loc[:,'Subt'] = column_subt
    out_herit_clean = out_herit_select[['Trial','Subt','H2r']]
    # Pivot table
    out_herit_final = out_herit_clean.pivot(index='Trial',columns='Subt',values='H2r')
    out_herit_final.index.name=None
    out_herit_final.rename(index={column_net[1]: 'H2R'},inplace= True)
    #put 0 for non for empty heritabity
    for ii in list_sbt:
        if ii not in out_herit_final.columns.get_values():
            out_herit_final.loc[:,ii]=0
    out_herit_final=out_herit_final[list_sbt]
    out_herit_final.to_csv(os.path.join(out_path,solar_out,h2r_out_file.format(task_name,trait_herit)))
    # H2R bar plot
    fig,ax = plt.subplots(figsize=(5, 4))
    y_pos = np.arange(len(out_herit_final.columns))
    ax.bar(y_pos,out_herit_final.ix['H2R'],color="#7ca343",alpha=0.4,align = 'center',width=0.85)
    ax.set_xticks(y_pos)
    ax.set_xticklabels(list_sbt)
    ax.set_ylim(0,1)
    ax.set_ylabel('H2R')
    #ax.grid(False)
    plt.title('{} task {}'.format(task_name,trait_herit))
    plt.show()
    fig.savefig(os.path.join(subt_path,"{}_barplot_heritability.svg".format(trait_herit)))
    display(out_herit_final)
# Out:
# Subt      sub1      sub2      sub3      sub4      sub5
# H2R   0.483234  0.484474  0.354013  0.525551  0.492009
# Subt      sub1      sub2      sub3      sub4      sub5
# H2R   0.472168  0.533172  0.472334  0.519555  0.536545
# Subt      sub1      sub2      sub3      sub4      sub5
# H2R   0.097465  0.152053  0.142514  0.100051  0.086781

# %%
##### R section #########

# %%
# first on terminal install cairo : "sudo apt install libcairo2-dev"
# devtools::install_github("hadley/svglite")
# devtools::install_github("ricardo-bion/ggradar", dependencies=TRUE)
import warnings
warnings.filterwarnings('ignore')

# %%
# %%R
# library(ggradar)
# suppressPackageStartupMessages(library(dplyr))
# library(scales)
# require("ggplot2")

# %%
# %%R -i out_path,solar_out,task_name,list_trial,path_root
# for (ii in list_trial) {
#     MyData <- read.csv(file=paste(out_path,solar_out,"/h2r_solar_",task_name,'_spm_',ii,'.csv',sep = ''))
#     # plot radar
#     image=ggradar(MyData, grid.min = 0,
#                   grid.mid = 0.5,
#                   grid.max = 1,
#                   axis.label.size = 4,
#                   grid.label.size = 5 ,
#                   legend.text.size =5) +
#     theme(legend.text = element_text(size = 12),plot.title = element_text( face="bold",size = 12)) +
#     ggtitle(paste(' \n  ',toupper(ii),sep = ''))
#     ggsave(file=paste(path_root,"subtypes_scores/26-10-2016/subtype_5_spm_RELATIONAL_18-Oct-2017/" ,ii,"_heritability.svg",sep = ''), plot=image, width=10, height=8)
#     print(image)
#      }
