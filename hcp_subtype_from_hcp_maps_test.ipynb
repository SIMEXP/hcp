# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec as gs

# %%
# %matplotlib inline

# %%
all_contrast = '/media/yassine/data_disk/data/HCP/fMRI_EMOTION/tfMRI_EMOTION_hp200_s4_level2_MSMAll.feat/139435_tfMRI_EMOTION_level2_hp200_s4_MSMAll.dscalar.nii'
mask = '/media/yassine/data_disk/data/HCP/fMRI_EMOTION/tfMRI_EMOTION_hp200_s4_level2_MSMAll.feat/GrayordinatesStats/cope1.feat/mask.dtseries.nii'
file = '/media/yassine/data_disk/data/HCP/fMRI_EMOTION/tfMRI_EMOTION_hp200_s4_level2_MSMAll.feat/GrayordinatesStats/cope1.feat/cope1.dtseries.nii'

# %%
vec_all = nib.load(all_contrast).get_data()
vec = nib.load(file).get_data()
mask = nib.load(mask).get_data()
# Out:
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1

# %%
np.array(vec_all)[...,:-50]
# Out:
# array([[-2.5348115 ,  0.64227134, -0.14848299, ...,  0.74138564,
#          0.54215336, -0.26486841],
#        [-2.59632754, -0.06017875,  1.18788385, ..., -0.18631105,
#         -0.14057268,  0.21054164],
#        [-0.2498852 ,  1.10516584, -1.99026883, ...,  1.44761884,
#          1.05710936, -0.74658221],
#        [ 2.5348115 , -0.64227134,  0.14848299, ..., -0.74138564,
#         -0.54215336,  0.26486841],
#        [ 2.59632754,  0.06017875, -1.18788385, ...,  0.18631105,
#          0.14057268, -0.21054164],
#        [ 0.2498852 , -1.10516584,  1.99026883, ..., -1.44761884,
#         -1.05710936,  0.74658221]], dtype=float32)

# %%
gsp = gs.GridSpec(10, 20)
f = plt.figure(figsize=(30,10))
ax = f.add_subplot(gsp[:,:18])
#axcl = f.add_subplot(gsp[1:9,19])
p = ax.matshow(np.array(vec_all)[...,:-50],aspect='auto',cmap ='jet',vmin=-2, vmax=2)

# %%
vec_all.shape
# Out:
# (6, 91282)

# %%
# Out:
# (91281,)
